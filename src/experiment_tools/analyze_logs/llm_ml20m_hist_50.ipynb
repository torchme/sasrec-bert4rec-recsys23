# %%
# %cd ../../../
# Out:
# /Users/nseverin/MyData/Projects
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from collections import defaultdict
import re
import numpy as np
import pandas as pd

def open_text(filename): 
    with open(filename) as f:
        return f.read()


def parse_file_llm(log_data):
    # Regex patterns
    config_pattern = re.compile(r"experiments(.+?\.yaml)")
    epoch_pattern = re.compile(r"Epoch: (\d+)/\d+ \| Train Total Loss: ([\d.]+)")
    metrics_pattern = re.compile(r"(Validation|Test) Metrics: ({.+?})")
    
    # Parse the log
    results = defaultdict(lambda: {"validation_metrics": [], "test_metrics": []})
    current_config = None
        
    for line in log_data.splitlines():
        config_match = config_pattern.search(line)
        if config_match:
            current_config = config_match.group(1)
        
        epoch_match = epoch_pattern.search(line)
        if epoch_match:
            print(epoch_match)
            epoch_num = int(epoch_match.group(1))
            loss = float(epoch_match.group(2))
        
        metrics_match = metrics_pattern.search(line)
        if metrics_match and current_config:
            metric_type = metrics_match.group(1).lower()  # "validation" or "test"
            metrics = eval(metrics_match.group(2))  # Convert string to dict
            results[current_config][f"{metric_type}_metrics"].append({"epoch": epoch_num, "loss": loss, **metrics})
    return results


def find_max(results, config, metric='NDCG@10'):
    def get_dct_epoch(lst, epoch):
        for x in lst:
            if x['epoch'] == epoch:
                return x
        return lst[-1]
        # raise Exception()
    
    def postprocess(lst):
        res = []
        for dct in lst:
            res.append({
                'NDCG@10': round(dct['NDCG@10'], 5),
                'Recall@10': round(dct['Recall@10'], 5),
                'epoch': dct['epoch']
            })
        return res
    
    best_val_dct = None
    for dct in results[config]['validation_metrics']:
        if best_val_dct is None:
            best_val_dct = dct
        elif dct[metric] > best_val_dct[metric]:
            best_val_dct = dct
    
    best_val_epoch = best_val_dct['epoch']
    
    return {
        'test': postprocess([get_dct_epoch(results[config]['test_metrics'], best_val_epoch)]),
        'validation': postprocess([best_val_dct]),
    }


PARAMS = ["config_file", "weighting_scheme", "alpha", "fine_tune_epoch", 'reconstruct_loss', "reconstruction_layer", 'weight_scale', 'use_down_scale','use_upscale','multi_profile','multi_profile_aggr_scheme','scale_guide_loss','user_profile_embeddings_files']


def create_dataframe(exp_data_with_max_val):
    # List to store extracted experiment data
    data = []
    
    # Parse experiment results
    for config_path, metrics in exp_data_with_max_val.items():
        # Extract config details from the filename
        config_file = config_path.split("/")[-1]  # Get only the filename
        config_name = config_file.replace(".yaml", "").replace('--1', '-4').lstrip('sasrec-').split("-")
        
        
        # {weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml
        weighting_scheme = (config_name[0])
        alpha = float(config_name[1])
        fine_tune_epoch = int(float(config_name[2]))
        reconstruct_loss = (config_name[3])
        reconstruction_layer = int(config_name[4])
        weight_scale = float(config_name[5])
        use_down_scale = (config_name[6])
        use_upscale = (config_name[7])
        multi_profile = (config_name[8])
        multi_profile_aggr_scheme = (config_name[9])
        scale_guide_loss = (config_name[10])
        user_profile_embeddings_files = (config_name[11])
        seed = int(config_name[12])
        
        # Extract validation and test metrics
        val_metrics = metrics.get("validation", [{}])[0]
        test_metrics = metrics.get("test", [{}])[0]
    
        # Append extracted values to data list
        data.append([
            config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale,use_upscale,multi_profile,multi_profile_aggr_scheme,scale_guide_loss,user_profile_embeddings_files,seed,
            val_metrics.get("NDCG@10", None), val_metrics.get("Recall@10", None), val_metrics.get("epoch", None),
            test_metrics.get("NDCG@10", None), test_metrics.get("Recall@10", None), test_metrics.get("epoch", None)
        ])
    
    # Create DataFrame
    columns = PARAMS + ['seed',
        "val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10", "test_epoch"
        ]
    
    df = pd.DataFrame(data, columns=columns)
    return df


def apply_seed_info(df):
    df['params'] = df.apply(lambda row: tuple([row[param] for param in PARAMS[1:]]), axis=1)
    params2seeds = {}
    for params, seed in zip(df['params'], df['seed']):
        if params not in params2seeds:
            params2seeds[params] = []
        params2seeds[params].append(seed)
    df['all_seeds'] = df.apply(lambda row: (params2seeds[row['params']]), axis=1)
    return df

# %%
len('{weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml'.split('-'))
# Out:
# 13

# %%
MODEL_NAME = 'sasrec'
DATASET = 'ml20m'
EXPERIMENT_NAME = 'ml20m_history_50_50'
SEED_FOLDER = 'other_seed'
SPLIT_NAME = 'history_50_50'
MODE = 'LLM'


local_directory = f"experiments-2_0/results/{MODEL_NAME}/{DATASET}/{EXPERIMENT_NAME}" 

seed_folders = ['other_seed']

# %%
import os


results = {}
for seed_folder in seed_folders:
    cur_folder = os.path.join(local_directory, seed_folder)
    for file in os.listdir(cur_folder):
        log_data = open_text(f'{cur_folder}/{file}')
        cur_results = parse_file_llm(log_data)
        # if cur_results['simple']['validation_metrics'] == []:
        #     continue
        results.update(cur_results)
    
    
exp_data_with_max_val = {}
for config in results:
    exp_data_with_max_val[config] = find_max(results, config, metric='NDCG@10')
exp_data_with_max_val.keys()
# Out:
# <re.Match object; span=(0, 39), match='Epoch: 1/200 | Train Total Loss: 7.6948'>
# <re.Match object; span=(0, 39), match='Epoch: 2/200 | Train Total Loss: 7.2912'>
# <re.Match object; span=(0, 39), match='Epoch: 3/200 | Train Total Loss: 7.1692'>
# <re.Match object; span=(0, 39), match='Epoch: 4/200 | Train Total Loss: 7.0715'>
# <re.Match object; span=(0, 39), match='Epoch: 5/200 | Train Total Loss: 7.0162'>
# <re.Match object; span=(0, 39), match='Epoch: 6/200 | Train Total Loss: 7.0059'>
# <re.Match object; span=(0, 39), match='Epoch: 7/200 | Train Total Loss: 6.8713'>
# <re.Match object; span=(0, 39), match='Epoch: 8/200 | Train Total Loss: 6.7805'>
# <re.Match object; span=(0, 39), match='Epoch: 9/200 | Train Total Loss: 6.8784'>
# <re.Match object; span=(0, 40), match='Epoch: 10/200 | Train Total Loss: 6.8403'>
# <re.Match object; span=(0, 40), match='Epoch: 11/200 | Train Total Loss: 6.7073'>
# <re.Match object; span=(0, 40), match='Epoch: 12/200 | Train Total Loss: 6.8083'>
# <re.Match object; span=(0, 40), match='Epoch: 13/200 | Train Total Loss: 6.8554'>
2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.4-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.6-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/ml20m/ml20m_history_50_50/other_seed/exponential-0.5-30-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml'])

# %%
df = create_dataframe(exp_data_with_max_val)
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'ttention' else 'attention')
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'xponential' else 'exponential')
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 0   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 1   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 2   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 3   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 4   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 5   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 6   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 7   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 8   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 9   exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 10  exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 11  exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 12  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
# 13  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
# 14  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
# 15  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
# 16  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
# 17  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 0                30              MSE                     3           0.1
# 1                30              MSE                     3           0.1
# 2                30              MSE                     3           0.1
# 3                30              MSE                     3           0.1
# 4                30              MSE                     3           0.1
# 5                30              MSE                     3           0.1
# 6                30              MSE                     3           0.1
# 7                30              MSE                     3           0.1
# 8                30              MSE                     3           0.1
# 9                30             RMSE                     3           0.1
# 10               30             RMSE                     3           0.1
# 11               30             RMSE                     3           0.1
# 12               30             RMSE                     3           0.1
# 13               30             RMSE                     3           0.1
# 14               30             RMSE                     3           0.1
# 15               30             RMSE                     3           0.1
# 16               30             RMSE                     3           0.1
# 17               30             RMSE                     3           0.1
#
#    use_down_scale use_upscale multi_profile multi_profile_aggr_scheme  \
# 0            True       False         False                      mean
# 1            True       False         False                      mean
# 2            True       False         False                      mean
# 3            True       False         False                      mean
# 4            True       False         False                      mean
# 5            True       False         False                      mean
# 6            True       False         False                      mean
# 7            True       False         False                      mean
# 8            True       False         False                      mean
# 9            True       False         False                      mean
# 10           True       False         False                      mean
# 11           True       False         False                      mean
# 12           True       False         False                      mean
# 13           True       False         False                      mean
# 14           True       False         False                      mean
# 15           True       False         False                      mean
# 16           True       False         False                      mean
# 17           True       False         False                      mean
#
#    scale_guide_loss  user_profile_embeddings_files  seed  val_NDCG@10  \
# 0              True  gemma_short_large_umap_single     1      0.04612
# 1              True  gemma_short_large_umap_single   256      0.13015
# 2              True  gemma_short_large_umap_single    42      0.17791
# 3              True  gemma_short_large_umap_single     1      0.16993
# 4              True  gemma_short_large_umap_single   256      0.04947
# 5              True  gemma_short_large_umap_single    42      0.16949
# 6              True  gemma_short_large_umap_single     1      0.17904
# 7              True  gemma_short_large_umap_single   256      0.04562
# 8              True  gemma_short_large_umap_single    42      0.13856
# 9              True  gemma_short_large_umap_single     1      0.17927
# 10             True  gemma_short_large_umap_single   256      0.17789
# 11             True  gemma_short_large_umap_single    42      0.17882
# 12             True  gemma_short_large_umap_single     1      0.04487
# 13             True  gemma_short_large_umap_single   256      0.17107
# 14             True  gemma_short_large_umap_single    42      0.17592
# 15             True  gemma_short_large_umap_single     1      0.17351
# 16             True  gemma_short_large_umap_single   256      0.17614
# 17             True  gemma_short_large_umap_single    42      0.17837
#
#     val_Recall@10  val_epoch  test_NDCG@10  test_Recall@10  test_epoch
# 0         0.09035        199       0.01891         0.03956         199
# 1         0.22384        200       0.04367         0.08049         200
# 2         0.28534        200       0.04961         0.08544         200
# 3         0.27304        199       0.04831         0.08084         199
# 4         0.08910        197       0.01862         0.03837         197
# 5         0.27344        200       0.04615         0.07974         200
# 6         0.28521        195       0.04556         0.07702         195
# 7         0.08892        194       0.02122         0.04472         194
# 8         0.23449        200       0.04488         0.08049         200
# 9         0.28677        200       0.05308         0.09038         200
# 10        0.28521        190       0.04894         0.08322         190
# 11        0.28477        196       0.04642         0.08099         196
# 12        0.08705        195       0.02017         0.04259         195
# 13        0.27255        199       0.04749         0.08124         199
# 14        0.27955        184       0.04857         0.08178         184
# 15        0.27607        177       0.04861         0.08231         177
# 16        0.28084        179       0.05053         0.08691         179
# 17        0.28682        200       0.05446         0.09235         200

# %%
df['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# exponential    18
# Name: count, dtype: int64

# %%
df = apply_seed_info(df)
df.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 9   exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 6   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 11  exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 17  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
# 2   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 10  exponential-0.4-30-RMSE-3-0.1-True-False-False...      exponential    0.4
# 16  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
# 14  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
# 15  exponential-0.5-30-RMSE-3-0.1-True-False-False...      exponential    0.5
# 13  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
# 3   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 5   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 8   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 1   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 4   exponential-0.4-30-MSE-3-0.1-True-False-False-...      exponential    0.4
# 0   exponential-0.5-30-MSE-3-0.1-True-False-False-...      exponential    0.5
# 7   exponential-0.6-30-MSE-3-0.1-True-False-False-...      exponential    0.6
# 12  exponential-0.6-30-RMSE-3-0.1-True-False-False...      exponential    0.6
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 9                30             RMSE                     3           0.1
# 6                30              MSE                     3           0.1
# 11               30             RMSE                     3           0.1
# 17               30             RMSE                     3           0.1
# 2                30              MSE                     3           0.1
# 10               30             RMSE                     3           0.1
# 16               30             RMSE                     3           0.1
# 14               30             RMSE                     3           0.1
# 15               30             RMSE                     3           0.1
# 13               30             RMSE                     3           0.1
# 3                30              MSE                     3           0.1
# 5                30              MSE                     3           0.1
# 8                30              MSE                     3           0.1
# 1                30              MSE                     3           0.1
# 4                30              MSE                     3           0.1
# 0                30              MSE                     3           0.1
# 7                30              MSE                     3           0.1
# 12               30             RMSE                     3           0.1
#
#    use_down_scale use_upscale multi_profile  ...  \
# 9            True       False         False  ...
# 6            True       False         False  ...
# 11           True       False         False  ...
# 17           True       False         False  ...
# 2            True       False         False  ...
# 10           True       False         False  ...
# 16           True       False         False  ...
# 14           True       False         False  ...
# 15           True       False         False  ...
# 13           True       False         False  ...
# 3            True       False         False  ...
# 5            True       False         False  ...
# 8            True       False         False  ...
# 1            True       False         False  ...
# 4            True       False         False  ...
# 0            True       False         False  ...
# 7            True       False         False  ...
# 12           True       False         False  ...
#
#     user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  val_epoch  \
# 9   gemma_short_large_umap_single    1     0.17927        0.28677        200
# 6   gemma_short_large_umap_single    1     0.17904        0.28521        195
# 11  gemma_short_large_umap_single   42     0.17882        0.28477        196
# 17  gemma_short_large_umap_single   42     0.17837        0.28682        200
# 2   gemma_short_large_umap_single   42     0.17791        0.28534        200
# 10  gemma_short_large_umap_single  256     0.17789        0.28521        190
# 16  gemma_short_large_umap_single  256     0.17614        0.28084        179
# 14  gemma_short_large_umap_single   42     0.17592        0.27955        184
# 15  gemma_short_large_umap_single    1     0.17351        0.27607        177
# 13  gemma_short_large_umap_single  256     0.17107        0.27255        199
# 3   gemma_short_large_umap_single    1     0.16993        0.27304        199
# 5   gemma_short_large_umap_single   42     0.16949        0.27344        200
# 8   gemma_short_large_umap_single   42     0.13856        0.23449        200
# 1   gemma_short_large_umap_single  256     0.13015        0.22384        200
# 4   gemma_short_large_umap_single  256     0.04947        0.08910        197
# 0   gemma_short_large_umap_single    1     0.04612        0.09035        199
# 7   gemma_short_large_umap_single  256     0.04562        0.08892        194
# 12  gemma_short_large_umap_single    1     0.04487        0.08705        195
#
#     test_NDCG@10  test_Recall@10  test_epoch  \
# 9        0.05308         0.09038         200
# 6        0.04556         0.07702         195
# 11       0.04642         0.08099         196
# 17       0.05446         0.09235         200
# 2        0.04961         0.08544         200
# 10       0.04894         0.08322         190
# 16       0.05053         0.08691         179
# 14       0.04857         0.08178         184
# 15       0.04861         0.08231         177
# 13       0.04749         0.08124         199
# 3        0.04831         0.08084         199
# 5        0.04615         0.07974         200
# 8        0.04488         0.08049         200
# 1        0.04367         0.08049         200
# 4        0.01862         0.03837         197
# 0        0.01891         0.03956         199
# 7        0.02122         0.04472         194
# 12       0.02017         0.04259         195
#
#                                                params     all_seeds
# 9   (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 6   (exponential, 0.6, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 11  (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 17  (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 2   (exponential, 0.5, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 10  (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 16  (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 14  (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 15  (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 13  (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 3   (exponential, 0.4, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 5   (exponential, 0.4, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 8   (exponential, 0.6, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 1   (exponential, 0.5, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 4   (exponential, 0.4, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 0   (exponential, 0.5, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 7   (exponential, 0.6, 30, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 12  (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
#
# [18 rows x 22 columns]

# %%
df.to_csv('ml20m_llm_all_runs.csv')

# %%
def get_stats_seeds(df_all):
    def aggregate_mean(series):
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        return series.mean()
        # print(df)
        # all_cols = set(df.columns)
        # df_mean = df.mean(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    def aggregate_std(series):
        # print(series)
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        if len(series) == 1:
            return 0
        return series.std()
        # all_cols = set(df.columns)
        # df_mean = df.std(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    
    metric_cols = ["val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10"]
        
    grouped_df = df_all.drop(['config_file', 'all_seeds', 'seed'], axis=1).groupby('params')
    df_mean = grouped_df.agg(aggregate_mean)
    df_std = grouped_df.agg(aggregate_std)
    for col in metric_cols:
        df_mean[col + '__std'] = df_std[col]
    return df_mean


def reorder_cols(df):
    order = ['val_epoch', 'val_epoch__std'] + PARAMS[1:] + ['val_NDCG@10', 'val_NDCG@10__std', 'val_Recall@10', 'val_Recall@10__std', 'test_NDCG@10', 'test_NDCG@10__std', 'test_Recall@10', 'test_Recall@10__std']
    return df[order]


df_all = df[df['all_seeds'].apply(len) == 3]
df_final = get_stats_seeds(df_all)
df_final = reorder_cols(df_final)
df_final.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df_final
# Out:
#                                                      val_epoch  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...  195.333333
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...  185.333333
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...  192.666667
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...  198.666667
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...  196.333333
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...  199.666667
#
#                                                     val_epoch__std  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...        5.033223
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...       12.741010
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...        7.767453
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...        1.527525
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...        3.214550
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...        0.577350
#
#                                                    weighting_scheme  alpha  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...      exponential    0.4
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...      exponential    0.5
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...      exponential    0.6
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...      exponential    0.4
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...      exponential    0.6
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...      exponential    0.5
#
#                                                     fine_tune_epoch  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...             30.0
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...             30.0
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...             30.0
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...             30.0
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...             30.0
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...             30.0
#
#                                                    reconstruct_loss  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...             RMSE
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...             RMSE
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...             RMSE
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...              MSE
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...              MSE
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...              MSE
#
#                                                     reconstruction_layer  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...                   3.0
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...                   3.0
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...                   3.0
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...                   3.0
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...                   3.0
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...                   3.0
#
#                                                     weight_scale  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...           0.1
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...           0.1
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...           0.1
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...           0.1
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...           0.1
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...           True       False
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...           True       False
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...           True       False
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...           True       False
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...           True       False
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...           True       False
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...  ...             True
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...  ...             True
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...  ...             True
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...  ...             True
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...  ...             True
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...  ...             True
#
#                                                     user_profile_embeddings_files  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...    0.178660
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...    0.176007
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...    0.130620
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...    0.129630
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...    0.121073
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...    0.118060
#
#                                                    val_NDCG@10__std  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...         0.000704
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...         0.002433
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...         0.074301
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...         0.069421
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...         0.068407
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...         0.066722
#
#                                                     val_Recall@10  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...       0.285583
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...       0.281243
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...       0.213050
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...       0.211860
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...       0.202873
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...       0.199843
#
#                                                     val_Recall@10__std  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...            0.001051
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...            0.005386
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...            0.109175
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...            0.106313
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...            0.101893
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...            0.099685
#
#                                                     test_NDCG@10  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...      0.049480
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...      0.051200
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...      0.038743
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...      0.037693
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...      0.037220
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...      0.037397
#
#                                                     test_NDCG@10__std  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...           0.003363
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...           0.002982
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...           0.016094
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...           0.016553
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...           0.013861
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...           0.016283
#
#                                                     test_Recall@10  \
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...        0.084863
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...        0.087190
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...        0.068537
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...        0.066317
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...        0.067410
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...        0.068497
#
#                                                     test_Recall@10__std
# params
# (exponential, 0.4, 30, RMSE, 3, 0.1, True, Fals...             0.004906
# (exponential, 0.5, 30, RMSE, 3, 0.1, True, Fals...             0.005026
# (exponential, 0.6, 30, RMSE, 3, 0.1, True, Fals...             0.022472
# (exponential, 0.4, 30, MSE, 3, 0.1, True, False...             0.024209
# (exponential, 0.6, 30, MSE, 3, 0.1, True, False...             0.019727
# (exponential, 0.5, 30, MSE, 3, 0.1, True, False...             0.025182
#
# [6 rows x 22 columns]

# %%
df_final.to_csv('BEAUTY_ALPHA_EXPS.csv')

# %%
df[df['params'] == ('exponential', 0.8, 30, 'MSE', 1, 0.1, 'True', 'False', 'False', 'mean', 'False', 'gemma_short_large_umap_single')]
# Out:
# Empty DataFrame
# Columns: [config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale, use_upscale, multi_profile, multi_profile_aggr_scheme, scale_guide_loss, user_profile_embeddings_files, seed, val_NDCG@10, val_Recall@10, val_epoch, test_NDCG@10, test_Recall@10, test_epoch, params, all_seeds]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['params'][0]
# Out:
# ('mean',
#  0.5,
#  50,
#  'MSE',
#  1,
#  0.1,
#  'True',
#  'False',
#  'False',
#  'mean',
#  'False',
#  'gemma_short_large_umap_single')

# %%
df[df['all_seeds'].apply(len) != 3]
# Out:
# Empty DataFrame
# Columns: [config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale, use_upscale, multi_profile, multi_profile_aggr_scheme, scale_guide_loss, user_profile_embeddings_files, seed, val_NDCG@10, val_Recall@10, val_epoch, test_NDCG@10, test_Recall@10, test_epoch, params, all_seeds]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_final['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# mean           16
# attention      15
# exponential     9
# Name: count, dtype: int64

# %%
df_final[df_final['scale_guide_loss'] == 'False']
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   9.333333        1.527525
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  12.666667        1.527525
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  13.000000        1.732051
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  13.666667        0.577350
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  14.666667        1.154701
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  14.000000        0.000000
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  14.000000        0.000000
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  14.666667        0.577350
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...   6.666667        1.154701
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  11.000000        0.000000
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  16.666667        2.516611
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  10.666667        2.516611
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  15.666667        2.886751
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  16.000000        1.732051
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             mean   0.50
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      exponential   0.80
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      exponential   0.80
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      exponential   0.50
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      exponential   0.80
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             mean   0.65
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             mean   0.80
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      exponential   0.65
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             mean   0.65
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             mean   0.65
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             mean   0.50
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             mean   0.65
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      exponential   0.50
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             mean   0.50
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             mean   0.80
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...              4.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...              8.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              8.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...              8.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...              6.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              8.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              6.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              6.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              4.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              6.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              8.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...              4.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...              8.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...              8.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             RMSE
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             RMSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              MSE
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             RMSE
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             RMSE
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              MSE
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              MSE
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             RMSE
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             RMSE
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             RMSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...                   1.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...                   1.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...                   1.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...                   1.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...                   1.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...                   1.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.1
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.1
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.1
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.1
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.1
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...          False        True
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...          False        True
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...          False        True
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...          False        True
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...          False        True
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...          False        True
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...          False        True
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  ...            False
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  ...            False
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  ...            False
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  ...            False
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  ...            False
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...  ...            False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  ...            False
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  ...            False
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...   gemma_long_large_umap_single
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  gemma_short_large_umap_single
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        gemma_long_large_single
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...   gemma_long_large_umap_single
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...   gemma_long_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099597
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...    0.099523
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099293
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...    0.099367
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...    0.099387
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...    0.099817
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...    0.099327
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...    0.099287
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...    0.099290
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...    0.098963
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...    0.099420
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...    0.098700
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...    0.099557
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...    0.099253
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...    0.099280
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...    0.098933
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...    0.099103
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...    0.099237
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...    0.099320
#
#                                                    val_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000808
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...         0.000072
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000384
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...         0.000376
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...         0.000116
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...         0.000266
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...         0.000539
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...         0.000652
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...         0.000521
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...         0.000100
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...         0.000670
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...         0.000743
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...         0.000778
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...         0.000325
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...         0.000524
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...         0.000314
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...         0.000295
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...         0.000196
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...         0.000223
#
#                                                     val_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183400
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...       0.182587
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183760
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...       0.183277
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...       0.183037
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...       0.183417
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...       0.183563
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...       0.183017
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...       0.183927
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...       0.183003
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...       0.183240
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...       0.183003
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...       0.184073
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...       0.183453
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...       0.183363
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...       0.182423
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...       0.183927
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...       0.183690
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...       0.183363
#
#                                                     val_Recall@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000946
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...            0.000343
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000537
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...            0.000603
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...            0.000872
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...            0.001399
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...            0.000333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...            0.001596
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...            0.000652
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...            0.000907
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...            0.000991
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...            0.001063
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...            0.000845
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...            0.000285
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...            0.000879
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...            0.000815
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...            0.001256
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...            0.000514
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...            0.000926
#
#                                                     test_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059867
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...      0.059717
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059667
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      0.059640
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      0.059383
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      0.059373
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      0.059353
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...      0.059330
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...      0.059287
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      0.059250
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...      0.059233
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...      0.059230
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...      0.059217
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...      0.059010
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...      0.058993
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...      0.058983
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      0.058937
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...      0.058880
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...      0.058810
#
#                                                     test_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000621
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.000998
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000748
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.000927
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.000947
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.001048
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.000945
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.000872
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.001598
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.000990
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.001301
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.000987
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.001076
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.001067
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.001248
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.001705
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.001215
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.001465
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.001323
#
#                                                     test_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.115200
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...        0.114783
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.114967
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...        0.114837
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...        0.114020
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...        0.114633
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...        0.114333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...        0.113890
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...        0.114723
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...        0.113957
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...        0.113177
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        0.114313
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...        0.114250
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...        0.114347
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...        0.113757
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...        0.113810
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...        0.114883
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...        0.113457
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...        0.113713
#
#                                                     test_Recall@10__std
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000375
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             0.001294
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000718
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             0.001643
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             0.000931
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             0.002053
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...             0.000127
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             0.000656
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             0.001650
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...             0.001367
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             0.002264
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             0.001370
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             0.001652
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             0.000874
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             0.001516
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             0.002309
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             0.001557
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             0.001436
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             0.001162
#
# [19 rows x 22 columns]

# %%
df['params'].value_counts()
# Out:
# params
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, False, mean, True, gemma_short_large_umap_single)         3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         3
# (mean, 0.6, 6, RMSE, 2, 0.1, True, False, False, mean, True, gemma_long_large_umap_single)          3
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)    3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)              3
#                                                                                                    ..
# (mean, 0.6, 12, MSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         1
# (mean, 0.7, 6, RMSE, 1, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)         1
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)          1
# (attention, 0.6, 6, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)     1
# (attention, 0.7, 12, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)    1
# Name: count, Length: 558, dtype: int64

# %%
df['']
# Out:
#                                             config_file weighting_scheme  \
# 663   mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean
# 837   exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential
# 779   exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential
# 649   mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean
# 467   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential
# ...                                                 ...              ...
# 876   exponential-0.8-8-RMSE-2-0.1-True-False-False-...      exponential
# 792   exponential-0.8-4-MSE-1-0.1-False-True-False-m...      exponential
# 25    attention-0.65-8-MSE-1-0.1-False-True-False-me...        attention
# 274   attention-0.8-6-MSE-2-0.1-True-False-False-mea...        attention
# 1161  attention-0.5-8-MSE-1-0.1-False-True-False-mea...        attention
#
#       alpha  fine_tune_epoch reconstruct_loss  reconstruction_layer  \
# 663    0.80                6             RMSE                     1
# 837    0.80                8              MSE                     2
# 779    0.65                8             RMSE                     2
# 649    0.80                6              MSE                     2
# 467    0.50                8             RMSE                     2
# ...     ...              ...              ...                   ...
# 876    0.80                8             RMSE                     2
# 792    0.80                4              MSE                     1
# 25     0.65                8              MSE                     1
# 274    0.80                6              MSE                     2
# 1161   0.50                8              MSE                     1
#
#       weight_scale use_down_scale use_upscale multi_profile  ...  \
# 663            0.1          False        True         False  ...
# 837            0.1          False        True         False  ...
# 779            0.1          False        True         False  ...
# 649            0.1          False        True         False  ...
# 467            0.1           True       False         False  ...
# ...            ...            ...         ...           ...  ...
# 876            0.1           True       False         False  ...
# 792            0.1          False        True         False  ...
# 25             0.1          False        True         False  ...
# 274            0.1           True       False         False  ...
# 1161           0.1          False        True         False  ...
#
#       user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  \
# 663   gemma_short_large_umap_single   42     0.09987        0.18422
# 837    gemma_long_large_umap_single   42     0.09898        0.18188
# 779   gemma_short_large_umap_single   42     0.09998        0.18356
# 649    gemma_long_large_umap_single   42     0.09983        0.18389
# 467   gemma_short_large_umap_single   42     0.09985        0.18454
# ...                             ...  ...         ...            ...
# 876         gemma_long_large_single   42     0.09951        0.18465
# 792         gemma_long_large_single   42     0.09851        0.18318
# 25     gemma_long_large_umap_single   42     0.09773        0.18112
# 274        gemma_short_large_single   42     0.09796        0.18210
# 1161   gemma_long_large_umap_single   42     0.09885        0.18253
#
#       val_epoch  test_NDCG@10  test_Recall@10  test_epoch  \
# 663          14       0.06111         0.11661          14
# 837          14       0.06083         0.11617          14
# 779          14       0.06072         0.11579          14
# 649          14       0.06072         0.11615          14
# 467          14       0.06072         0.11703          14
# ...         ...           ...             ...         ...
# 876          19       0.05589         0.10964          19
# 792          11       0.05586         0.10847          11
# 25           18       0.05583         0.10835          18
# 274           7       0.05579         0.10824           7
# 1161         17       0.05526         0.10697          17
#
#                                                  params  all_seeds
# 663   (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...       [42]
# 837   (exponential, 0.8, 8, MSE, 2, 0.1, False, True...       [42]
# 779   (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...       [42]
# 649   (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...       [42]
# 467   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...       [42]
# ...                                                 ...        ...
# 876   (exponential, 0.8, 8, RMSE, 2, 0.1, True, Fals...       [42]
# 792   (exponential, 0.8, 4, MSE, 1, 0.1, False, True...       [42]
# 25    (attention, 0.65, 8, MSE, 1, 0.1, False, True,...       [42]
# 274   (attention, 0.8, 6, MSE, 2, 0.1, True, False, ...       [42]
# 1161  (attention, 0.5, 8, MSE, 1, 0.1, False, True, ...       [42]
#
# [1728 rows x 22 columns]

# %%
df[PARAMS[1:]].to_json('best_ml20m.json', index=False, orient="records")

# %%
df_final[PARAMS[1:]].to_json('best_beauty_3seeds.json', index=False, orient="records")

# %%
results.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_ ...

# %%
results['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml']
# Out:
# {'validation_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.004162330905306972,
#    'NDCG@5': 0.0023390187078764875,
#    'Recall@10': 0.006243496357960458,
#    'NDCG@10': 0.00302255539974203,
#    'Recall@20': 0.010851791288836034,
#    'NDCG@20': 0.004198139363666408,
#    'loss_recsys': np.float64(10.347532872800473),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.004013676230117437,
#    'NDCG@5': 0.0024368647296024288,
#    'Recall@10': 0.008324661810613945,
#    'NDCG@10': 0.003826736836797046,
#    'Recall@20': 0.014122194143005798,
#    'NDCG@20': 0.0052561474396673165,
#    'loss_recsys': np.float64(10.325713298938892),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.006094841682770923,
#    'NDCG@5': 0.003388410317555781,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.004382003442624782,
#    'Recall@20': 0.015014122194143005,
#    'NDCG@20': 0.005846106928100518,
#    'loss_recsys': np.float64(10.315859370761448),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.00475694960606511,
#    'NDCG@5': 0.0024233021388104224,
#    'Recall@10': 0.008919280511372083,
#    'NDCG@10': 0.0037466937619863266,
#    'Recall@20': 0.015608740894901144,
#    'NDCG@20': 0.005444883250261604,
#    'loss_recsys': np.float64(10.304392673351147),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.005351568306823249,
#    'NDCG@5': 0.003198377698354209,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.0043943408066474685,
#    'Recall@20': 0.014568158168574402,
#    'NDCG@20': 0.005749538405717385,
#    'loss_recsys': np.float64(10.319377016138148),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.005648877657202319,
#    'NDCG@5': 0.0037872565967536566,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005442632113875368,
#    'Recall@20': 0.01605470492046975,
#    'NDCG@20': 0.006777092754637059,
#    'loss_recsys': np.float64(10.228386843646014),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0

#    'loss_guide': np.float64(0.0)},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.027352460234874386,
#    'NDCG@5': 0.01618542386958481,
#    'Recall@10': 0.03969079827560577,
#    'NDCG@10': 0.02020389827803692,
#    'Recall@20': 0.05752935929834993,
#    'NDCG@20': 0.024705387746063227,
#    'loss_recsys': np.float64(11.168465543676305),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.026906496209305783,
#    'NDCG@5': 0.01646556425576616,
#    'Recall@10': 0.039244834250037164,
#    'NDCG@10': 0.020470205593094953,
#    'Recall@20': 0.05604281254645459,
#    'NDCG@20': 0.024679021484805407,
#    'loss_recsys': np.float64(11.262380140799063),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.02720380555968485,
#    'NDCG@5': 0.016519092779838616,
#    'Recall@10': 0.03954214360041623,
#    'NDCG@10': 0.020518979186977693,
#    'Recall@20': 0.05366433774342203,
#    'NDCG@20': 0.02405135827732951,
#    'loss_recsys': np.float64(11.435306372465911),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.027947078935632527,
#    'NDCG@5': 0.01738097975330968,
#    'Recall@10': 0.038947524899658095,
#    'NDCG@10': 0.02095301327688371,
#    'Recall@20': 0.05173182696595808,
#    'NDCG@20': 0.02417196843995193,
#    'loss_recsys': np.float64(11.526062541537815),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.026014568158168574,
#    'NDCG@5': 0.016542074335477355,
#    'Recall@10': 0.03537981269510926,
#    'NDCG@10': 0.019553550820444923,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.02317558219001501,
#    'loss_recsys': np.float64(11.65649449383771),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.02423071205589416,
#    'NDCG@5': 0.015859220487606795,
#    'Recall@10': 0.03627174074624647,
#    'NDCG@10': 0.019799808429292996,
#    'Recall@20': 0.05069124423963134,
#    'NDCG@20': 0.02343532319442468,
#    'loss_recsys': np.float64(11.757749239603678),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.025717258807789505,
#    'NDCG@5': 0.01651283913883568,
#    'Recall@10': 0.03716366879738368,
#    'NDCG@10': 0.02013082716570259,
#    'Recall@20': 0.04950200683811506,
#    'NDCG@20': 0.02323738534861304,
#    'loss_recsys': np.float64(11.947628409774214),
#    'loss_guide': np.float64(0.0)}],
#  'test_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.002139927480235392,
#    'NDCG@5': 0.0013538334012237051,
#    'Recall@10': 0.003388218510372704,
#    'NDCG@10': 0.0017610431170978012,
#    'Recall@20': 0.004993164120549248,
#    'NDCG@20': 0.002165665195797907},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.001069963740117696,
#    'NDCG@5': 0.0006361886489577691,
#    'Recall@10': 0.002853236640313856,
#    'NDCG@10': 0.0012341079502590968,
#    'Recall@20': 0.005290376270581942,
#    'NDCG@20': 0.0018409968568660385},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.0015455031801700054,
#    'NDCG@5': 0.0008165547682358466,
#    'Recall@10': 0.003507103370385781,
#    'NDCG@10': 0.001439664780594028,
#    'Recall@20': 0.006954764310765024,
#    'NDCG@20': 0.002298769186171313},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.0023776972002615467,
#    'NDCG@5': 0.0014026731913448166,
#    'Recall@10': 0.004101527670451168,
#    'NDCG@10': 0.0019555992269632205,
#    'Recall@20': 0.006835879450751947,
#    'NDCG@20': 0.0026387664443111684},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.0013671758901503894,
#    'NDCG@5': 0.0007172181997728328,
#    'Recall@10': 0.003150448790346549,
#    'NDCG@10': 0.0013028721633510456,
#    'Recall@20': 0.00671699459073887,
#    'NDCG@20': 0.0022039522710796317},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.0026154669202877014,
#    'NDCG@5': 0.001487013497973625,
#    'Recall@10': 0.004279854960470784,
#    'NDCG@10': 0.0020137893819131528,
#    'Recall@20': 0.007251976460797717,
#    'NDCG@20': 0.002751861097327539},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.003150448790346549,
#    'NDCG@5': 0.001966949736314488,
#    'Recall@10': 0.004577067110503478,
#    'NDCG@10': 0.0024279629756173756,
#    'Recall@20': 0.008559709920941568,
#    'NDCG@20': 0.003421836252807189},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.002318254770255008,
#    'NDCG@5': 0.001675343508882811,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.002225847738659184,
#    'Recall@20': 0.007430303750817334,
#    'NDCG@20': 0.0030913081515921655},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.0027343517803007787,
#    'NDCG@5': 0.0015257141404888019,
#    'Recall@10': 0.004636509540510016,
#    'NDCG@10': 0.002116818478138206,
#    'Recall@20': 0.008143612910895798,
#    'NDCG@20': 0.003003676133016085},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0016414278814032013,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.0020269605539885724,
#    'Recall@20': 0.00802472805088272,
#    'NDCG@20': 0.003022193540214734},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0017859868566651041,
#    'Recall@10': 0.004814836830529632,
#    'NDCG@10': 0.0024061624093819037,
#    'Recall@20': 0.00850026749093503,
#    'NDCG@20': 0.0033377840612771248},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.003744873090411936,
#    'NDCG@5': 0.0021182589243107855,
#    'Recall@10': 0.007251976460797717,
#    'NDCG@10': 0.0032274959887816537,
#    'Recall@20': 0.011412946561255424,
#    'NDCG@20': 0.004260477909596519},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.004101527670451168,
#    'NDCG@5': 0.002598666341567106,
#    'Recall@10': 0.007192534030791179,
#    'NDCG@10': 0.0035955304322993578,
#    'Recall@20': 0.01206681329132735,
#    'NDCG@20': 0.004805631612736497},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.007192534030791179,
#    'NDCG@5': 0.004284443818367116,
#    'Recall@10': 0.011175176841229269,
#    'NDCG@10': 0.005561693731332473,
#    'Recall@20': 0.01700053498187006,
#    'NDCG@20': 0.007036552276919148},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.010818522261190037,
#    'NDCG@5': 0.006017385559856399,
#    'Recall@10': 0.015752243951732747,
#    'NDCG@10': 0.007622415926753642,
#    'Recall@20': 0.021220947512334304,
#    'NDCG@20': 0.008998311353213068},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.011650716281281578,
#    'NDCG@5': 0.006517543634988249,
#    'Recall@10': 0.017119419841883136,
#    'NDCG@10': 0.008282253693749164,
#    'Recall@20': 0.02324199013255662,
#    'NDCG@20': 0.009830076487716423},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.011888486001307734,
#    'NDCG@5': 0.006735338572974523,
#    'Recall@10': 0.016703322831837366,
#    'NDCG@10': 0.008283234498932084,
#    'Recall@20': 0.025144147892765856,
#    'NDCG@20': 0.010398704256787777},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.011947928431314273,
#    'NDCG@5': 0.00666463396881279,
#    'Recall@10': 0.018129941151994292,
#    'NDCG@10': 0.008639935083638146,
#    'Recall@20': 0.02591689948285086,
#    'NDCG@20': 0.010597046951628863},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.012423467871366582,
#    'NDCG@5': 0.006813344336899553,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008713483760822175,
#    'Recall@20': 0.025798014622837782,
#    'NDCG@20': 0.01058971981780322},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.012185698151340426,
#    'NDCG@5': 0.006996251090431883,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008982034806780602,
#    'Recall@20': 0.026095226772870475,
#    'NDCG@20': 0.010960017615107813},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.012364025441360043,
#    'NDCG@5': 0.0068822554357764855,
#    'Recall@10': 0.01949711704214468,
#    'NDCG@10': 0.009193702424131632,
#    'Recall@20': 0.02668965107293586,
#    'NDCG@20': 0.01102183364428713},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.012601795161386197,
#    'NDCG@5': 0.007046747803227453,
#    'Recall@10': 0.017951613861974677,
#    'NDCG@10': 0.008761131902699917,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.01043881323043057},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.011531831421268502,
#    'NDCG@5': 0.006640128844035038,
#    'Recall@10': 0.017535516851928907,
#    'NDCG@10': 0.008585679830839013,
#    'Recall@20': 0.02532247518278547,
#    'NDCG@20': 0.01053402397710971},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.011353504131248885,
#    'NDCG@5': 0.006717526952725617,
#    'Recall@10': 0.018070498721987755,
#    'NDCG@10': 0.008847053447249018,
#    'Recall@20': 0.02550080247280509,
#    'NDCG@20': 0.01071452445750896},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007}]}

# %%
df['config_file']
# Out:
# 426    mean-0.7-12-MSE-1-0.1-True-False-False-mean-Tr...
# 11     attention-0.7-12-MSE-2-0.1-True-False-False-me...
# 88     mean-0.7-6-RMSE-1-0.1-True-False-False-mean-Tr...
# 283    mean-0.5-6-MSE-1-0.1-True-False-False-mean-Tru...
# 373    attention-0.5-12-MSE-1-0.1-True-False-False-me...
#                              ...
# 73     mean-0.7-6-MSE-2-0.1-True-False-False-mean-Tru...
# 257    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 234    mean-0.6-6-MSE-2-0.1-True-False-False-mean-Tru...
# 259    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 2      attention-0.7-12-MSE-2-0.1-False-False-False-m...
# Name: config_file, Length: 558, dtype: object

# %%
PARAMS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PARAMS
#
# NameError: name 'PARAMS' is not defined

# %%
df_final
# Out:
#                                                      val_epoch  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  187.000000
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  196.333333
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  178.000000
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...  174.333333
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  168.000000
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...  178.000000
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  177.000000
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  162.333333
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...  180.666667
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  170.666667
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  188.666667
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  180.000000
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  175.000000
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...  189.000000
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...  184.000000
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  169.666667
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...  193.666667
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  182.333333
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  152.333333
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  188.333333
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  188.000000
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...  190.333333
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  194.000000
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  182.333333
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  193.333333
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...  193.000000
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...  197.333333
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  180.666667
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  180.000000
#
#                                                     val_epoch__std  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...       19.924859
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...        3.785939
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...        1.732051
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...       25.106440
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...       18.248288
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...        6.000000
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       18.520259
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       15.567059
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...       18.036999
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...        7.767453
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       10.408330
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...       27.730849
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...       23.430749
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...       10.816654
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...       21.000000
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...       13.576941
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...        4.041452
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       18.175075
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...       54.243279
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...        8.736895
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...        6.928203
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...       14.224392
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...        6.082763
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       28.041636
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...        8.144528
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...        6.557439
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...        1.154701
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...       30.892286
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       21.377558
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             mean   0.80
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             mean   0.80
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      exponential   0.80
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...      exponential   0.65
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             mean   0.80
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      exponential   0.80
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             mean   0.65
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...      exponential   0.65
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...      exponential   0.80
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      exponential   0.65
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            130.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             30.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             30.0
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...            130.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            130.0
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...            100.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             30.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            100.0
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...            130.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            130.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             30.0
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             30.0
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...             30.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             30.0
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...            100.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             30.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             30.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             30.0
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            130.0
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...            100.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            100.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            100.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            130.0
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...            130.0
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...            130.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            130.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...              MSE
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...              MSE
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...              MSE
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...              MSE
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...              MSE
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...              MSE
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             RMSE
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             RMSE
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...              MSE
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...              MSE
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             RMSE
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...              MSE
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...              MSE
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...              MSE
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...              MSE
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...             RMSE
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...              MSE
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...              MSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...                   1.0
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...                   1.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...                   1.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...                   1.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...                   1.0
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...                   1.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.1
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.1
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.1
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...           0.1
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...           0.1
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.1
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.1
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...           0.1
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...           0.1
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           True       False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           True       False
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           True       False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...           True       False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...           True       False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           True       False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           True       False
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...           True       False
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...           True       False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           True       False
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  ...            False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  ...            False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  ...            False
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...  ...            False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  ...            False
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...  ...            False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  ...            False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  ...            False
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  ...            False
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...  ...            False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  ...             True
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...  ...             True
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  ...             True
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  ...             True
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  ...             True
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  ...             True
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  ...             True
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  ...             True
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...  ...             True
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...  ...             True
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  ...             True
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  ...             True
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  gemma_short_large_umap_single
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  gemma_short_large_umap_single
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...        0.074473
#
#                                                     test_Recall@10__std
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             0.002034
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             0.000868
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             0.003037
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...             0.004700
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             0.003095
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             0.002951
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             0.001945
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             0.005056
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...             0.003748
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             0.002516
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...             0.002456
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...             0.004031
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             0.003653
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             0.003421
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...             0.003071
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             0.006796
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             0.006480
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             0.005375
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             0.002491
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             0.001212
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             0.003472
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...             0.002788
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...             0.003087
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             0.004908
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             0.002609
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...             0.003262
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...             0.004733
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             0.002191
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...             0.005980
#
# [29 rows x 22 columns]

# %%
df_final[6:].to_csv('ml20m_llm_runs_FINAL_4_200_epochs.csv')

# %%
np.corrcoef(df_final['test_NDCG@10'].values[:15], df_final['val_NDCG@10'].values[:15])
# Out:
# array([[ 1.       , -0.5951883],
#        [-0.5951883,  1.       ]])

# %%
df[df['params'] ==('exponential', 0.65, 50, 'MSE', 1, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_short_large_single')]
# Out:
#                                           config_file weighting_scheme  alpha  \
# 12  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
# 13  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
# 14  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 12               50              MSE                     1           0.1
# 13               50              MSE                     1           0.1
# 14               50              MSE                     1           0.1
#
#    use_down_scale use_upscale multi_profile  ...  \
# 12           True       False         False  ...
# 13           True       False         False  ...
# 14           True       False         False  ...
#
#    user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  val_epoch  \
# 12      gemma_short_large_single    1     0.17211        0.27639         98
# 13      gemma_short_large_single  256     0.17094        0.27750        100
# 14      gemma_short_large_single   42     0.17012        0.27362         99
#
#     test_NDCG@10  test_Recall@10  test_epoch  \
# 12       0.04652         0.07940          98
# 13       0.04522         0.07727         100
# 14       0.04753         0.08052          99
#
#                                                params     all_seeds
# 12  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
# 13  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
# 14  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
#
# [3 rows x 22 columns]
