# %%
# %cd ../../../
# Out:
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from collections import defaultdict
import re
import numpy as np
import pandas as pd

def open_text(filename): 
    with open(filename) as f:
        return f.read()


def parse_file_llm(log_data):
    # Regex patterns
    config_pattern = re.compile(r"experiments(.+?\.yaml)")
    epoch_pattern = re.compile(r"Epoch (\d+)/\d+, Loss: ([\d.]+)")
    metrics_pattern = re.compile(r"(Validation|Test) Metrics: ({.+?})")
    
    # Parse the log
    results = defaultdict(lambda: {"validation_metrics": [], "test_metrics": []})
    current_config = None
        
    for line in log_data.splitlines():
        config_match = config_pattern.search(line)
        if config_match:
            current_config = config_match.group(1)
        
        epoch_match = epoch_pattern.search(line)
        if epoch_match:
            epoch_num = int(epoch_match.group(1))
            loss = float(epoch_match.group(2))
        
        metrics_match = metrics_pattern.search(line)
        if metrics_match and current_config:
            metric_type = metrics_match.group(1).lower()  # "validation" or "test"
            metrics = eval(metrics_match.group(2))  # Convert string to dict
            results[current_config][f"{metric_type}_metrics"].append({"epoch": epoch_num, "loss": loss, **metrics})
    return results


def find_max(results, config, metric='NDCG@10'):
    def get_dct_epoch(lst, epoch):
        for x in lst:
            if x['epoch'] == epoch:
                return x
        return lst[-1]
        # raise Exception()
    
    def postprocess(lst):
        res = []
        for dct in lst:
            res.append({
                'NDCG@10': round(dct['NDCG@10'], 5),
                'Recall@10': round(dct['Recall@10'], 5),
                'epoch': dct['epoch']
            })
        return res
    
    best_val_dct = None
    for dct in results[config]['validation_metrics']:
        if best_val_dct is None:
            best_val_dct = dct
        elif dct[metric] > best_val_dct[metric]:
            best_val_dct = dct
    
    best_val_epoch = best_val_dct['epoch']
    
    return {
        'test': postprocess([get_dct_epoch(results[config]['test_metrics'], best_val_epoch)]),
        'validation': postprocess([best_val_dct]),
    }


PARAMS = ["config_file", "weighting_scheme", "alpha", "fine_tune_epoch", 'reconstruct_loss', "reconstruction_layer", 'weight_scale', 'use_down_scale','use_upscale','multi_profile','multi_profile_aggr_scheme','scale_guide_loss','user_profile_embeddings_files']


def create_dataframe(exp_data_with_max_val):
    # List to store extracted experiment data
    data = []
    
    # Parse experiment results
    for config_path, metrics in exp_data_with_max_val.items():
        # Extract config details from the filename
        config_file = config_path.split("/")[-1]  # Get only the filename
        config_name = config_file.replace(".yaml", "").lstrip('sasrec-').split("-")
        
        
        # {weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml
        weighting_scheme = (config_name[0])
        alpha = float(config_name[1])
        fine_tune_epoch = int(config_name[2])
        reconstruct_loss = (config_name[3])
        reconstruction_layer = int(config_name[4])
        weight_scale = float(config_name[5])
        use_down_scale = (config_name[6])
        use_upscale = (config_name[7])
        multi_profile = (config_name[8])
        multi_profile_aggr_scheme = (config_name[9])
        scale_guide_loss = (config_name[10])
        user_profile_embeddings_files = (config_name[11])
        seed = int(config_name[12])
        
        # Extract validation and test metrics
        val_metrics = metrics.get("validation", [{}])[0]
        test_metrics = metrics.get("test", [{}])[0]
    
        # Append extracted values to data list
        data.append([
            config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale,use_upscale,multi_profile,multi_profile_aggr_scheme,scale_guide_loss,user_profile_embeddings_files,seed,
            val_metrics.get("NDCG@10", None), val_metrics.get("Recall@10", None), val_metrics.get("epoch", None),
            test_metrics.get("NDCG@10", None), test_metrics.get("Recall@10", None), test_metrics.get("epoch", None)
        ])
    
    # Create DataFrame
    columns = PARAMS + ['seed',
        "val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10", "test_epoch"
        ]
    
    df = pd.DataFrame(data, columns=columns)
    return df


def apply_seed_info(df):
    df['params'] = df.apply(lambda row: tuple([row[param] for param in PARAMS[1:]]), axis=1)
    params2seeds = {}
    for params, seed in zip(df['params'], df['seed']):
        if params not in params2seeds:
            params2seeds[params] = []
        params2seeds[params].append(seed)
    df['all_seeds'] = df.apply(lambda row: (params2seeds[row['params']]), axis=1)
    return df

# %%
len('{weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml'.split('-'))
# Out:
# 13

# %%
MODEL_NAME = 'sasrec'
DATASET = 'beauty'
EXPERIMENT_NAME = 'BEAUTY_INITIAL_MULTI'
SPLIT_NAME = 'general'
MODE = 'LLM'

local_directory = f"experiments-2_0/results/{MODEL_NAME}/{DATASET}/{EXPERIMENT_NAME}" 

seed_folders = ['single_seed', 'other_seed']

# %%
import os


results = {}
for seed_folder in seed_folders:
    cur_folder = os.path.join(local_directory, seed_folder)
    for file in os.listdir(cur_folder):
        log_data = open_text(f'{cur_folder}/{file}')
        cur_results = parse_file_llm(log_data)
        # if cur_results['simple']['validation_metrics'] == []:
        #     continue
        results.update(cur_results)
    
    
exp_data_with_max_val = {}
for config in results:
    exp_data_with_max_val[config] = find_max(results, config, metric='NDCG@10')
exp_data_with_max_val.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.5-6-RMSE-2-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.5-6-RMSE-2-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-1-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-1-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-1-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-1-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-2-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-2-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-2-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-MSE-2-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-1-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-1-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-1-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-1-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-2-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-2-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/mean-0.6-12-RMSE-2-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-2-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-2-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-2-0.1-True-False-True-mean-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-12-RMSE-2-0.1-True-False-True-mean-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-6-MSE-1-0.1-True-False-True-attention-False-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL_MULTI/single_seed/attention-0.7-6-MSE-1-0.1-True-False-True-attention-True-gemma__large_multiple-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_ ...

# %%
df = create_dataframe(exp_data_with_max_val)
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'ttention' else 'attention')
df
# Out:
#                                            config_file weighting_scheme  \
# 0    mean-0.5-6-RMSE-2-0.1-True-False-True-mean-Fal...             mean
# 1    mean-0.5-6-RMSE-2-0.1-True-False-True-mean-Tru...             mean
# 2    mean-0.6-12-MSE-1-0.1-True-False-True-attentio...             mean
# 3    mean-0.6-12-MSE-1-0.1-True-False-True-attentio...             mean
# 4    mean-0.6-12-MSE-1-0.1-True-False-True-mean-Fal...             mean
# ..                                                 ...              ...
# 267  attention-0.7-6-RMSE-1-0.1-True-False-True-mea...        attention
# 268  attention-0.7-6-RMSE-1-0.1-True-False-True-mea...        attention
# 269  mean-0.5-12-MSE-2-0.1-True-False-True-mean-Fal...             mean
# 270  mean-0.5-12-MSE-2-0.1-True-False-True-mean-Fal...             mean
# 271  mean-0.5-6-MSE-1-0.1-True-False-True-attention...             mean
#
#      alpha  fine_tune_epoch reconstruct_loss  reconstruction_layer  \
# 0      0.5                6             RMSE                     2
# 1      0.5                6             RMSE                     2
# 2      0.6               12              MSE                     1
# 3      0.6               12              MSE                     1
# 4      0.6               12              MSE                     1
# ..     ...              ...              ...                   ...
# 267    0.7                6             RMSE                     1
# 268    0.7                6             RMSE                     1
# 269    0.5               12              MSE                     2
# 270    0.5               12              MSE                     2
# 271    0.5                6              MSE                     1
#
#      weight_scale use_down_scale use_upscale multi_profile  \
# 0             0.1           True       False          True
# 1             0.1           True       False          True
# 2             0.1           True       False          True
# 3             0.1           True       False          True
# 4             0.1           True       False          True
# ..            ...            ...         ...           ...
# 267           0.1           True       False          True
# 268           0.1           True       False          True
# 269           0.1           True       False          True
# 270           0.1           True       False          True
# 271           0.1           True       False          True
#
#     multi_profile_aggr_scheme scale_guide_loss user_profile_embeddings_files  \
# 0                        mean            False         gemma__large_multiple
# 1                        mean             True         gemma__large_multiple
# 2                   attention            False         gemma__large_multiple
# 3                   attention             True         gemma__large_multiple
# 4                        mean            False         gemma__large_multiple
# ..                        ...              ...                           ...
# 267                      mean            False         gemma__large_multiple
# 268                      mean            False         gemma__large_multiple
# 269                      mean            False         gemma__large_multiple
# 270                      mean            False         gemma__large_multiple
# 271                 attention            False         gemma__large_multiple
#
#      seed  val_NDCG@10  val_Recall@10  val_epoch  test_NDCG@10  \
# 0      42      0.02382        0.04816          8       0.01005
# 1      42      0.02138        0.04162         14       0.00910
# 2      42      0.02348        0.04831          7       0.01000
# 3      42      0.02063        0.03761         22       0.00815
# 4      42      0.02337        0.04802          7       0.01000
# ..    ...          ...            ...        ...           ...
# 267     1      0.02325        0.04460         12       0.00976
# 268   256      0.02356        0.04608          9       0.01024
# 269     1      0.02354        0.04787          7       0.00946
# 270   256      0.02416        0.04920          6       0.00964
# 271     1      0.02383        0.04787          7       0.00987
#
#      test_Recall@10  test_epoch
# 0           0.02182           8
# 1           0.01914          14
# 2           0.02146           7
# 3           0.01676          22
# 4           0.02146           7
# ..              ...         ...
# 267         0.01991          12
# 268         0.02182           9
# 269         0.01985           7
# 270         0.02033           6
# 271         0.02104           7
#
# [272 rows x 20 columns]

# %%
df['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# attention    160
# mean         112
# Name: count, dtype: int64

# %%
df = apply_seed_info(df)
df.sort_values(by='test_NDCG@10', ascending=False, inplace=True)

# %%
def get_stats_seeds(df_all):
    def aggregate_mean(series):
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        return series.mean()
        # print(df)
        # all_cols = set(df.columns)
        # df_mean = df.mean(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    def aggregate_std(series):
        # print(series)
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        if len(series) == 1:
            return 0
        return series.std()
        # all_cols = set(df.columns)
        # df_mean = df.std(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    
    metric_cols = ["val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10"]
        
    grouped_df = df_all.drop(['config_file', 'all_seeds', 'seed'], axis=1).groupby('params')
    df_mean = grouped_df.agg(aggregate_mean)
    df_std = grouped_df.agg(aggregate_std)
    for col in metric_cols:
        df_mean[col + '__std'] = df_std[col]
    return df_mean


def reorder_cols(df):
    order = ['val_epoch', 'val_epoch__std'] + PARAMS[1:] + ['val_NDCG@10', 'val_NDCG@10__std', 'val_Recall@10', 'val_Recall@10__std', 'test_NDCG@10', 'test_NDCG@10__std', 'test_Recall@10', 'test_Recall@10__std']
    return df[order]


df_all = df[df['all_seeds'].apply(len) == 3]
df_final = get_stats_seeds(df_all)
df_final = reorder_cols(df_final)
df_final.sort_values(by='test_NDCG@10', ascending=False, inplace=True)
df_final
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...   7.333333        0.577350
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...   8.000000        1.000000
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...   7.333333        0.577350
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...   8.000000        1.000000
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...   8.000000        1.000000
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...   8.000000        1.000000
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...  11.333333        0.577350
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...  11.000000        0.000000
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...  10.000000        3.605551
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...   8.666667        2.081666
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...   8.000000        1.000000
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...   9.000000        2.645751
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...   9.000000        2.645751
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...   9.000000        2.645751
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...  10.333333        1.527525
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...   8.000000        1.000000
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...   8.000000        1.000000
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...   9.666667        2.081666
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...  10.666667        2.309401
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...  10.333333        1.527525
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...   8.666667        2.081666
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...  10.333333        1.527525
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...   7.333333        1.527525
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...   7.333333        1.527525
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...   8.000000        1.000000
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...  11.000000        1.732051
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...  10.666667        2.309401
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...   8.000000        1.000000
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...  10.666667        2.309401
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...   7.333333        1.527525
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...  10.666667        2.309401
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...  10.666667        2.309401
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...  19.000000        2.645751
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...   8.666667        1.154701
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...   9.333333        1.527525
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...   9.333333        0.577350
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...   7.333333        1.527525
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...   9.000000        3.000000
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...   7.333333        1.527525
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...   7.333333        1.527525
#
#                                                    weighting_scheme  alpha  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...        attention    0.6
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...        attention    0.5
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...        attention    0.6
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...        attention    0.5
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        attention    0.7
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...        attention    0.5
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        attention    0.7
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        attention    0.7
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...        attention    0.7
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...        attention    0.5
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...        attention    0.5
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...        attention    0.6
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...        attention    0.7
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...        attention    0.7
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             mean    0.7
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...        attention    0.6
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...        attention    0.6
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...        attention    0.6
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...        attention    0.6
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             mean    0.7
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...        attention    0.7
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...             mean    0.6
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...             mean    0.6
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...             mean    0.6
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...        attention    0.5
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...        attention    0.7
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...        attention    0.7
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...        attention    0.7
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...        attention    0.6
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...             mean    0.5
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...        attention    0.6
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...        attention    0.6
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...        attention    0.7
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...        attention    0.5
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...        attention    0.5
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...        attention    0.6
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...             mean    0.7
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...        attention    0.6
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...             mean    0.5
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...             mean    0.7
#
#                                                     fine_tune_epoch  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...             12.0
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              6.0
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...             12.0
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...              6.0
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...              6.0
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...              6.0
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...              6.0
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             12.0
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...              6.0
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...              6.0
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             12.0
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...             12.0
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...             12.0
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...              6.0
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...              6.0
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...              6.0
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...             12.0
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...             12.0
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...              6.0
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...              6.0
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...             12.0
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...             12.0
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...             12.0
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...             12.0
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...             12.0
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...             12.0
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...             12.0
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...             12.0
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...             12.0
#
#                                                    reconstruct_loss  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...              MSE
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...              MSE
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...             RMSE
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...              MSE
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...              MSE
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...              MSE
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...              MSE
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             RMSE
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...             RMSE
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...             RMSE
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             RMSE
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...              MSE
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...             RMSE
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...              MSE
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...              MSE
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...             RMSE
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...              MSE
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...              MSE
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...              MSE
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...              MSE
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...              MSE
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...              MSE
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...             RMSE
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...             RMSE
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...             RMSE
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...              MSE
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...             RMSE
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...              MSE
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...              MSE
#
#                                                     reconstruction_layer  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...                   2.0
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...                   2.0
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...                   1.0
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...                   1.0
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...                   1.0
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...                   1.0
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...                   1.0
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...                   2.0
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...                   2.0
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...                   2.0
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...                   2.0
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...                   1.0
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...                   2.0
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...                   1.0
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...                   1.0
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...                   2.0
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...                   1.0
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...                   1.0
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...                   1.0
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...                   1.0
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...                   1.0
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...                   2.0
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...                   2.0
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...                   1.0
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...                   1.0
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...                   2.0
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...                   2.0
#
#                                                     weight_scale  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...           0.1
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.1
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...           0.1
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...           0.1
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           0.1
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           0.1
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           0.1
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           0.1
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           0.1
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           0.1
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           0.1
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           0.1
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...           0.1
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           0.1
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           0.1
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...           0.1
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           0.1
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...           0.1
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           0.1
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           0.1
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...           0.1
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...           0.1
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...           0.1
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...           0.1
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...           0.1
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...           0.1
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...           True       False
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           True       False
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...           True       False
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...           True       False
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           True       False
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           True       False
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           True       False
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           True       False
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           True       False
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           True       False
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           True       False
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           True       False
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...           True       False
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           True       False
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           True       False
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...           True       False
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           True       False
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...           True       False
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           True       False
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           True       False
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...           True       False
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...           True       False
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...           True       False
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...           True       False
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...           True       False
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...           True       False
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...           True       False
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...  ...            False
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...  ...            False
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...  ...            False
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...  ...            False
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...  ...            False
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...  ...            False
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...  ...             True
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...  ...             True
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...  ...            False
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...  ...            False
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...  ...            False
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...  ...            False
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...  ...            False
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...  ...            False
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...  ...            False
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...  ...            False
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...  ...            False
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...  ...            False
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...  ...            False
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...  ...            False
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...  ...            False
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...  ...            False
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...  ...            False
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...  ...            False
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...  ...            False
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...  ...            False
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...  ...             True
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...  ...            False
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...  ...            False
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...  ...            False
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...  ...            False
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...  ...            False
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...  ...            False
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...  ...            False
#
#                                                    user_profile_embeddings_files  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...         gemma__large_multiple
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...         gemma__large_multiple
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...         gemma__large_multiple
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...         gemma__large_multiple
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...         gemma__large_multiple
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...         gemma__large_multiple
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...         gemma__large_multiple
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...         gemma__large_multiple
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...         gemma__large_multiple
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...         gemma__large_multiple
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...         gemma__large_multiple
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...         gemma__large_multiple
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...         gemma__large_multiple
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...         gemma__large_multiple
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...         gemma__large_multiple
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...         gemma__large_multiple
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...         gemma__large_multiple
#
#                                                    val_NDCG@10  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...    0.023603
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...    0.023727
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...    0.023627
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...    0.024037
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...    0.023843
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...    0.023883
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...    0.022343
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...    0.022393
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...    0.023297
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...    0.023260
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...    0.023630
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...    0.023490
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...    0.023423
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...    0.023363
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...    0.023810
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...    0.022860
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...    0.023073
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...    0.023540
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...    0.023483
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...    0.023733
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...    0.023413
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...    0.023760
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...    0.023790
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...    0.023787
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...    0.023247
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...    0.023750
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...    0.023710
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...    0.023487
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...    0.023680
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...    0.023960
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...    0.023520
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...    0.023647
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...    0.022973
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...    0.023193
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...    0.023113
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...    0.023077
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...    0.023397
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...    0.023197
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...    0.023703
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...    0.023553
#
#                                                    val_NDCG@10__std  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...         0.000473
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...         0.000560
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...         0.000664
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...         0.000645
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         0.000561
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...         0.000561
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         0.000507
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...         0.000175
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...         0.000241
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...         0.000792
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...         0.000315
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...         0.000671
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...         0.000095
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...         0.000217
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...         0.000453
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...         0.000389
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...         0.000631
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...         0.000973
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...         0.000941
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...         0.000422
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...         0.000107
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...         0.000180
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...         0.000440
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...         0.000295
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...         0.000862
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...         0.000617
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...         0.000389
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...         0.000715
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...         0.000315
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...         0.000279
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...         0.000684
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...         0.000416
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...         0.001235
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...         0.000650
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...         0.000085
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...         0.000575
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...         0.000462
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...         0.000729
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...         0.000401
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...         0.000223
#
#                                                     val_Recall@10  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...       0.046973
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...       0.047023
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...       0.047123
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...       0.047273
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...       0.047173
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...       0.046923
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...       0.044103
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...       0.044697
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...       0.045587
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...       0.045487
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...       0.046630
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...       0.045787
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...       0.045587
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...       0.045487
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...       0.047323
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...       0.045783
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...       0.046130
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...       0.045837
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...       0.045490
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...       0.046923
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...       0.047123
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...       0.047177
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...       0.048263
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...       0.048460
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...       0.045833
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...       0.045240
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...       0.045540
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...       0.046430
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...       0.046037
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...       0.048910
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...       0.044597
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...       0.046183
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...       0.043507
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...       0.046627
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...       0.045340
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...       0.045240
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...       0.047470
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...       0.046430
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...       0.048363
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...       0.048063
#
#                                                     val_Recall@10__std  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...            0.000391
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...            0.001743
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...            0.000831
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...            0.001507
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...            0.001124
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...            0.001411
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...            0.001074
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...            0.000225
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...            0.002276
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...            0.002337
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...            0.000894
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...            0.001964
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...            0.001908
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...            0.002106
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...            0.000854
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...            0.001858
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...            0.002257
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...            0.001710
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...            0.002970
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...            0.001210
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...            0.000830
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...            0.001333
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...            0.001074
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...            0.000974
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...            0.001524
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...            0.000760
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...            0.002030
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...            0.000990
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...            0.001630
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...            0.000890
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...            0.002315
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...            0.001769
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...            0.002493
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...            0.001406
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...            0.001190
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...            0.001239
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...            0.000760
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...            0.001782
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...            0.000728
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...            0.000959
#
#                                                     test_NDCG@10  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...      0.010477
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...      0.010440
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...      0.010440
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...      0.010417
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...      0.010383
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...      0.010363
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...      0.010357
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...      0.010337
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...      0.010323
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...      0.010323
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...      0.010307
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...      0.010293
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...      0.010283
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...      0.010277
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...      0.010237
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...      0.010230
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...      0.010230
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...      0.010230
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...      0.010217
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...      0.010207
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...      0.010203
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...      0.010200
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...      0.010200
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...      0.010187
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...      0.010183
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...      0.010183
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...      0.010180
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...      0.010180
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...      0.010147
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...      0.010143
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...      0.010133
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...      0.010120
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...      0.010113
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...      0.010113
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...      0.010077
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...      0.010050
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...      0.010027
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...      0.009993
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...      0.009927
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...      0.009830
#
#                                                     test_NDCG@10__std  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           0.000266
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...           0.000114
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...           0.000295
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           0.000045
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.000227
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...           0.000042
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.000266
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...           0.000300
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...           0.000313
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           0.000344
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...           0.000208
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           0.000244
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           0.000462
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...           0.000371
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           0.000363
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           0.000286
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...           0.000272
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           0.000417
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...           0.000393
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...           0.000320
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           0.000200
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...           0.000257
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           0.000426
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...           0.000414
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...           0.000397
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           0.000398
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...           0.000476
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...           0.000315
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           0.000380
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...           0.000385
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...           0.000455
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...           0.000376
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...           0.000424
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...           0.000223
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...           0.000400
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...           0.000291
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...           0.000393
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...           0.000425
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...           0.000659
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...           0.000666
#
#                                                     test_Recall@10  \
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...        0.022427
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...        0.022253
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...        0.022367
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...        0.022210
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        0.022230
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...        0.022090
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        0.022013
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...        0.021833
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...        0.021577
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...        0.021993
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...        0.021993
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...        0.021597
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...        0.021673
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...        0.021697
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...        0.021793
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...        0.021637
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...        0.021637
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...        0.021397
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...        0.021123
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...        0.021653
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...        0.021773
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...        0.021557
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...        0.021557
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...        0.021517
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...        0.021937
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...        0.021003
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...        0.021003
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...        0.021753
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...        0.021260
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...        0.021440
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...        0.020940
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...        0.021143
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...        0.020943
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...        0.021617
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...        0.021180
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...        0.021300
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...        0.021140
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...        0.021183
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...        0.021023
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...        0.020667
#
#                                                     test_Recall@10__std
# params
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...             0.000601
# (attention, 0.5, 12, MSE, 2, 0.1, True, False, ...             0.000552
# (attention, 0.6, 6, MSE, 2, 0.1, True, False, T...             0.000705
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...             0.000284
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...             0.000262
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, T...             0.000125
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...             0.000416
# (attention, 0.7, 6, MSE, 2, 0.1, True, False, T...             0.000697
# (attention, 0.7, 12, RMSE, 1, 0.1, True, False,...             0.001055
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...             0.000976
# (attention, 0.5, 6, MSE, 1, 0.1, True, False, T...             0.000410
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...             0.000445
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...             0.001491
# (attention, 0.7, 6, MSE, 1, 0.1, True, False, T...             0.001207
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             0.000852
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...             0.000670
# (attention, 0.6, 6, RMSE, 2, 0.1, True, False, ...             0.000514
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...             0.000463
# (attention, 0.6, 6, RMSE, 1, 0.1, True, False, ...             0.000716
# (mean, 0.7, 12, RMSE, 2, 0.1, True, False, True...             0.000636
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...             0.000552
# (mean, 0.6, 12, RMSE, 2, 0.1, True, False, True...             0.000659
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...             0.000716
# (mean, 0.6, 6, MSE, 1, 0.1, True, False, True, ...             0.000715
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, ...             0.000834
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...             0.000985
# (attention, 0.7, 6, RMSE, 1, 0.1, True, False, ...             0.000768
# (attention, 0.7, 12, MSE, 2, 0.1, True, False, ...             0.000573
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...             0.000800
# (mean, 0.5, 6, MSE, 1, 0.1, True, False, True, ...             0.000604
# (attention, 0.6, 6, MSE, 1, 0.1, True, False, T...             0.001079
# (attention, 0.6, 12, MSE, 1, 0.1, True, False, ...             0.000735
# (attention, 0.7, 12, MSE, 1, 0.1, True, False, ...             0.000348
# (attention, 0.5, 12, RMSE, 1, 0.1, True, False,...             0.000386
# (attention, 0.5, 12, RMSE, 2, 0.1, True, False,...             0.000865
# (attention, 0.6, 12, RMSE, 2, 0.1, True, False,...             0.000713
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, True,...             0.000638
# (attention, 0.6, 12, RMSE, 1, 0.1, True, False,...             0.000895
# (mean, 0.5, 12, MSE, 2, 0.1, True, False, True,...             0.001634
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, True,...             0.001687
#
# [40 rows x 22 columns]

# %%
df_final[PARAMS[1:]].to_json('best_beauty_multi.json', index=False, orient="records")

# %%
results.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_ ...

# %%
results['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml']
# Out:
# {'validation_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.004162330905306972,
#    'NDCG@5': 0.0023390187078764875,
#    'Recall@10': 0.006243496357960458,
#    'NDCG@10': 0.00302255539974203,
#    'Recall@20': 0.010851791288836034,
#    'NDCG@20': 0.004198139363666408,
#    'loss_recsys': np.float64(10.347532872800473),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.004013676230117437,
#    'NDCG@5': 0.0024368647296024288,
#    'Recall@10': 0.008324661810613945,
#    'NDCG@10': 0.003826736836797046,
#    'Recall@20': 0.014122194143005798,
#    'NDCG@20': 0.0052561474396673165,
#    'loss_recsys': np.float64(10.325713298938892),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.006094841682770923,
#    'NDCG@5': 0.003388410317555781,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.004382003442624782,
#    'Recall@20': 0.015014122194143005,
#    'NDCG@20': 0.005846106928100518,
#    'loss_recsys': np.float64(10.315859370761448),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.00475694960606511,
#    'NDCG@5': 0.0024233021388104224,
#    'Recall@10': 0.008919280511372083,
#    'NDCG@10': 0.0037466937619863266,
#    'Recall@20': 0.015608740894901144,
#    'NDCG@20': 0.005444883250261604,
#    'loss_recsys': np.float64(10.304392673351147),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.005351568306823249,
#    'NDCG@5': 0.003198377698354209,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.0043943408066474685,
#    'Recall@20': 0.014568158168574402,
#    'NDCG@20': 0.005749538405717385,
#    'loss_recsys': np.float64(10.319377016138148),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.005648877657202319,
#    'NDCG@5': 0.0037872565967536566,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005442632113875368,
#    'Recall@20': 0.01605470492046975,
#    'NDCG@20': 0.006777092754637059,
#    'loss_recsys': np.float64(10.228386843646014),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.00787869778504534,
#    'NDCG@5': 0.0046932804995630795,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005588280874640481,
#    'Recall@20': 0.018433179723502304,
#    'NDCG@20': 0.0075612680348843865,
#    'loss_recsys': np.float64(10.17817313582809),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.006689460383529062,
#    'NDCG@5': 0.0041596912400265655,
#    'Recall@10': 0.01040582726326743,
#    'NDCG@10': 0.005321938281465431,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007405936319264151,
#    'loss_recsys': np.float64(10.219599264639395),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.005500222982012784,
#    'NDCG@5': 0.0031088033783253297,
#    'Recall@10': 0.011297755314404637,
#    'NDCG@10': 0.004985089569295943,
#    'Recall@20': 0.017838561022744167,
#    'NDCG@20': 0.00663930810328949,
#    'loss_recsys': np.float64(10.194536915531865),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.005202913631633715,
#    'NDCG@5': 0.003397568455595876,
#    'Recall@10': 0.009959863237698825,
#    'NDCG@10': 0.004914059980283862,
#    'Recall@20': 0.018135870373123236,
#    'NDCG@20': 0.006973698958964976,
#    'loss_recsys': np.float64(10.167172855801052),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.0068381150587185965,
#    'NDCG@5': 0.003916981294850848,
#    'Recall@10': 0.011446409989594173,
#    'NDCG@10': 0.005379105533092607,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007205976983741362,
#    'loss_recsys': np.float64(10.186000929938423),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.009216589861751152,
#    'NDCG@5': 0.00536698016561086,
#    'Recall@10': 0.01664932362122789,
#    'NDCG@10': 0.007717170610955234,
#    'Recall@20': 0.025271294782220902,
#    'NDCG@20': 0.009880426186269118,
#    'loss_recsys': np.float64(10.067615509033203),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.010703136613646498,
#    'NDCG@5': 0.0061917896653171526,
#    'Recall@10': 0.015608740894901144,
#    'NDCG@10': 0.007797456503587827,
#    'Recall@20': 0.026163222833358108,
#    'NDCG@20': 0.010465141389670158,
#    'loss_recsys': np.float64(10.02229372660319),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.015311431544522075,
#    'NDCG@5': 0.008807618966761114,
#    'Recall@10': 0.02556860413259997,
#    'NDCG@10': 0.012092302117390957,
#    'Recall@20': 0.037460978147762745,
#    'NDCG@20': 0.01509402483874486,
#    'loss_recsys': np.float64(10.043341000874838),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.02333878400475695,
#    'NDCG@5': 0.013452293225307246,
#    'Recall@10': 0.03478519399435112,
#    'NDCG@10': 0.01718388295588317,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.020940635823487562,
#    'loss_recsys': np.float64(10.394192024513528),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.02556860413259997,
#    'NDCG@5': 0.01467175621573135,
#    'Recall@10': 0.03612308607105694,
#    'NDCG@10': 0.01808131911592638,
#    'Recall@20': 0.052623755017095285,
#    'NDCG@20': 0.02219570412294851,
#    'loss_recsys': np.float64(10.669138625816062),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.027649769585253458,
#    'NDCG@5': 0.01608440494827978,
#    'Recall@10': 0.040285416976363904,
#    'NDCG@10': 0.020169707389790147,
#    'Recall@20': 0.055299539170506916,
#    'NDCG@20': 0.023953926373648043,
#    'loss_recsys': np.float64(10.90925513373481),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.029136316337148804,
#    'NDCG@5': 0.0168769101747808,
#    'Recall@10': 0.040731381001932514,
#    'NDCG@10': 0.020608016688631957,
#    'Recall@20': 0.05589415787126505,
#    'NDCG@20': 0.024402803415633317,
#    'loss_recsys': np.float64(11.069474714773673),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.027352460234874386,
#    'NDCG@5': 0.01618542386958481,
#    'Recall@10': 0.03969079827560577,
#    'NDCG@10': 0.02020389827803692,
#    'Recall@20': 0.05752935929834993,
#    'NDCG@20': 0.024705387746063227,
#    'loss_recsys': np.float64(11.168465543676305),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.026906496209305783,
#    'NDCG@5': 0.01646556425576616,
#    'Recall@10': 0.039244834250037164,
#    'NDCG@10': 0.020470205593094953,
#    'Recall@20': 0.05604281254645459,
#    'NDCG@20': 0.024679021484805407,
#    'loss_recsys': np.float64(11.262380140799063),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.02720380555968485,
#    'NDCG@5': 0.016519092779838616,
#    'Recall@10': 0.03954214360041623,
#    'NDCG@10': 0.020518979186977693,
#    'Recall@20': 0.05366433774342203,
#    'NDCG@20': 0.02405135827732951,
#    'loss_recsys': np.float64(11.435306372465911),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.027947078935632527,
#    'NDCG@5': 0.01738097975330968,
#    'Recall@10': 0.038947524899658095,
#    'NDCG@10': 0.02095301327688371,
#    'Recall@20': 0.05173182696595808,
#    'NDCG@20': 0.02417196843995193,
#    'loss_recsys': np.float64(11.526062541537815),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.026014568158168574,
#    'NDCG@5': 0.016542074335477355,
#    'Recall@10': 0.03537981269510926,
#    'NDCG@10': 0.019553550820444923,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.02317558219001501,
#    'loss_recsys': np.float64(11.65649449383771),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.02423071205589416,
#    'NDCG@5': 0.015859220487606795,
#    'Recall@10': 0.03627174074624647,
#    'NDCG@10': 0.019799808429292996,
#    'Recall@20': 0.05069124423963134,
#    'NDCG@20': 0.02343532319442468,
#    'loss_recsys': np.float64(11.757749239603678),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.025717258807789505,
#    'NDCG@5': 0.01651283913883568,
#    'Recall@10': 0.03716366879738368,
#    'NDCG@10': 0.02013082716570259,
#    'Recall@20': 0.04950200683811506,
#    'NDCG@20': 0.02323738534861304,
#    'loss_recsys': np.float64(11.947628409774214),
#    'loss_guide': np.float64(0.0)}],
#  'test_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.002139927480235392,
#    'NDCG@5': 0.0013538334012237051,
#    'Recall@10': 0.003388218510372704,
#    'NDCG@10': 0.0017610431170978012,
#    'Recall@20': 0.004993164120549248,
#    'NDCG@20': 0.002165665195797907},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.001069963740117696,
#    'NDCG@5': 0.0006361886489577691,
#    'Recall@10': 0.002853236640313856,
#    'NDCG@10': 0.0012341079502590968,
#    'Recall@20': 0.005290376270581942,
#    'NDCG@20': 0.0018409968568660385},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.0015455031801700054,
#    'NDCG@5': 0.0008165547682358466,
#    'Recall@10': 0.003507103370385781,
#    'NDCG@10': 0.001439664780594028,
#    'Recall@20': 0.006954764310765024,
#    'NDCG@20': 0.002298769186171313},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.0023776972002615467,
#    'NDCG@5': 0.0014026731913448166,
#    'Recall@10': 0.004101527670451168,
#    'NDCG@10': 0.0019555992269632205,
#    'Recall@20': 0.006835879450751947,
#    'NDCG@20': 0.0026387664443111684},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.0013671758901503894,
#    'NDCG@5': 0.0007172181997728328,
#    'Recall@10': 0.003150448790346549,
#    'NDCG@10': 0.0013028721633510456,
#    'Recall@20': 0.00671699459073887,
#    'NDCG@20': 0.0022039522710796317},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.0026154669202877014,
#    'NDCG@5': 0.001487013497973625,
#    'Recall@10': 0.004279854960470784,
#    'NDCG@10': 0.0020137893819131528,
#    'Recall@20': 0.007251976460797717,
#    'NDCG@20': 0.002751861097327539},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.003150448790346549,
#    'NDCG@5': 0.001966949736314488,
#    'Recall@10': 0.004577067110503478,
#    'NDCG@10': 0.0024279629756173756,
#    'Recall@20': 0.008559709920941568,
#    'NDCG@20': 0.003421836252807189},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.002318254770255008,
#    'NDCG@5': 0.001675343508882811,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.002225847738659184,
#    'Recall@20': 0.007430303750817334,
#    'NDCG@20': 0.0030913081515921655},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.0027343517803007787,
#    'NDCG@5': 0.0015257141404888019,
#    'Recall@10': 0.004636509540510016,
#    'NDCG@10': 0.002116818478138206,
#    'Recall@20': 0.008143612910895798,
#    'NDCG@20': 0.003003676133016085},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0016414278814032013,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.0020269605539885724,
#    'Recall@20': 0.00802472805088272,
#    'NDCG@20': 0.003022193540214734},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0017859868566651041,
#    'Recall@10': 0.004814836830529632,
#    'NDCG@10': 0.0024061624093819037,
#    'Recall@20': 0.00850026749093503,
#    'NDCG@20': 0.0033377840612771248},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.003744873090411936,
#    'NDCG@5': 0.0021182589243107855,
#    'Recall@10': 0.007251976460797717,
#    'NDCG@10': 0.0032274959887816537,
#    'Recall@20': 0.011412946561255424,
#    'NDCG@20': 0.004260477909596519},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.004101527670451168,
#    'NDCG@5': 0.002598666341567106,
#    'Recall@10': 0.007192534030791179,
#    'NDCG@10': 0.0035955304322993578,
#    'Recall@20': 0.01206681329132735,
#    'NDCG@20': 0.004805631612736497},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.007192534030791179,
#    'NDCG@5': 0.004284443818367116,
#    'Recall@10': 0.011175176841229269,
#    'NDCG@10': 0.005561693731332473,
#    'Recall@20': 0.01700053498187006,
#    'NDCG@20': 0.007036552276919148},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.010818522261190037,
#    'NDCG@5': 0.006017385559856399,
#    'Recall@10': 0.015752243951732747,
#    'NDCG@10': 0.007622415926753642,
#    'Recall@20': 0.021220947512334304,
#    'NDCG@20': 0.008998311353213068},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.011650716281281578,
#    'NDCG@5': 0.006517543634988249,
#    'Recall@10': 0.017119419841883136,
#    'NDCG@10': 0.008282253693749164,
#    'Recall@20': 0.02324199013255662,
#    'NDCG@20': 0.009830076487716423},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.011888486001307734,
#    'NDCG@5': 0.006735338572974523,
#    'Recall@10': 0.016703322831837366,
#    'NDCG@10': 0.008283234498932084,
#    'Recall@20': 0.025144147892765856,
#    'NDCG@20': 0.010398704256787777},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.011947928431314273,
#    'NDCG@5': 0.00666463396881279,
#    'Recall@10': 0.018129941151994292,
#    'NDCG@10': 0.008639935083638146,
#    'Recall@20': 0.02591689948285086,
#    'NDCG@20': 0.010597046951628863},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.012423467871366582,
#    'NDCG@5': 0.006813344336899553,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008713483760822175,
#    'Recall@20': 0.025798014622837782,
#    'NDCG@20': 0.01058971981780322},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.012185698151340426,
#    'NDCG@5': 0.006996251090431883,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008982034806780602,
#    'Recall@20': 0.026095226772870475,
#    'NDCG@20': 0.010960017615107813},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.012364025441360043,
#    'NDCG@5': 0.0068822554357764855,
#    'Recall@10': 0.01949711704214468,
#    'NDCG@10': 0.009193702424131632,
#    'Recall@20': 0.02668965107293586,
#    'NDCG@20': 0.01102183364428713},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.012601795161386197,
#    'NDCG@5': 0.007046747803227453,
#    'Recall@10': 0.017951613861974677,
#    'NDCG@10': 0.008761131902699917,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.01043881323043057},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.011531831421268502,
#    'NDCG@5': 0.006640128844035038,
#    'Recall@10': 0.017535516851928907,
#    'NDCG@10': 0.008585679830839013,
#    'Recall@20': 0.02532247518278547,
#    'NDCG@20': 0.01053402397710971},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.011353504131248885,
#    'NDCG@5': 0.006717526952725617,
#    'Recall@10': 0.018070498721987755,
#    'NDCG@10': 0.008847053447249018,
#    'Recall@20': 0.02550080247280509,
#    'NDCG@20': 0.01071452445750896},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007}]}

# %%
df['config_file']
# Out:
# 426    mean-0.7-12-MSE-1-0.1-True-False-False-mean-Tr...
# 11     attention-0.7-12-MSE-2-0.1-True-False-False-me...
# 88     mean-0.7-6-RMSE-1-0.1-True-False-False-mean-Tr...
# 283    mean-0.5-6-MSE-1-0.1-True-False-False-mean-Tru...
# 373    attention-0.5-12-MSE-1-0.1-True-False-False-me...
#                              ...
# 73     mean-0.7-6-MSE-2-0.1-True-False-False-mean-Tru...
# 257    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 234    mean-0.6-6-MSE-2-0.1-True-False-False-mean-Tru...
# 259    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 2      attention-0.7-12-MSE-2-0.1-False-False-False-m...
# Name: config_file, Length: 558, dtype: object

# %%
PARAMS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PARAMS
#
# NameError: name 'PARAMS' is not defined
