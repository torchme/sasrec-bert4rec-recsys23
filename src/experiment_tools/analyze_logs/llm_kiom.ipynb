# %%
# %cd ../../../
# Out:
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from collections import defaultdict
import re
import numpy as np
import pandas as pd

def open_text(filename): 
    with open(filename) as f:
        return f.read()


def parse_file_llm(log_data):
    # Regex patterns
    config_pattern = re.compile(r"experiments(.+?\.yaml)")
    epoch_pattern = re.compile(r"Epoch (\d+)/\d+, Loss: ([\d.]+)")
    metrics_pattern = re.compile(r"(Validation|Test) Metrics: ({.+?})")
    
    # Parse the log
    results = defaultdict(lambda: {"validation_metrics": [], "test_metrics": []})
    current_config = None
        
    for line in log_data.splitlines():
        config_match = config_pattern.search(line)
        if config_match:
            current_config = config_match.group(1)
        
        epoch_match = epoch_pattern.search(line)
        if epoch_match:
            epoch_num = int(epoch_match.group(1))
            loss = float(epoch_match.group(2))
        
        metrics_match = metrics_pattern.search(line)
        if metrics_match and current_config:
            metric_type = metrics_match.group(1).lower()  # "validation" or "test"
            metrics = eval(metrics_match.group(2))  # Convert string to dict
            results[current_config][f"{metric_type}_metrics"].append({"epoch": epoch_num, "loss": loss, **metrics})
    return results


def find_max(results, config, metric='NDCG@10'):
    def get_dct_epoch(lst, epoch):
        for x in lst:
            if x['epoch'] == epoch:
                return x
        return lst[-1]
        # raise Exception()
    
    def postprocess(lst):
        res = []
        for dct in lst:
            res.append({
                'NDCG@10': round(dct['NDCG@10'], 5),
                'Recall@10': round(dct['Recall@10'], 5),
                'epoch': dct['epoch']
            })
        return res
    
    best_val_dct = None
    for dct in results[config]['validation_metrics']:
        if best_val_dct is None:
            best_val_dct = dct
        elif dct[metric] > best_val_dct[metric]:
            best_val_dct = dct
    
    best_val_epoch = best_val_dct['epoch']
    
    return {
        'test': postprocess([get_dct_epoch(results[config]['test_metrics'], best_val_epoch)]),
        'validation': postprocess([best_val_dct]),
    }


PARAMS = ["config_file", "weighting_scheme", "alpha", "fine_tune_epoch", 'reconstruct_loss', "reconstruction_layer", 'weight_scale', 'use_down_scale','use_upscale','multi_profile','multi_profile_aggr_scheme','scale_guide_loss','user_profile_embeddings_files']


def create_dataframe(exp_data_with_max_val):
    # List to store extracted experiment data
    data = []
    
    # Parse experiment results
    for config_path, metrics in exp_data_with_max_val.items():
        # Extract config details from the filename
        config_file = config_path.split("/")[-1]  # Get only the filename
        config_name = config_file.replace(".yaml", "").lstrip('sasrec-').split("-")
        
        
        # {weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml
        weighting_scheme = (config_name[0])
        alpha = float(config_name[1])
        fine_tune_epoch = int(config_name[2])
        reconstruct_loss = (config_name[3])
        reconstruction_layer = int(config_name[4])
        weight_scale = float(config_name[5])
        use_down_scale = (config_name[6])
        use_upscale = (config_name[7])
        multi_profile = (config_name[8])
        multi_profile_aggr_scheme = (config_name[9])
        scale_guide_loss = (config_name[10])
        user_profile_embeddings_files = (config_name[11])
        seed = int(config_name[12])
        
        # Extract validation and test metrics
        val_metrics = metrics.get("validation", [{}])[0]
        test_metrics = metrics.get("test", [{}])[0]
    
        # Append extracted values to data list
        data.append([
            config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale,use_upscale,multi_profile,multi_profile_aggr_scheme,scale_guide_loss,user_profile_embeddings_files,seed,
            val_metrics.get("NDCG@10", None), val_metrics.get("Recall@10", None), val_metrics.get("epoch", None),
            test_metrics.get("NDCG@10", None), test_metrics.get("Recall@10", None), test_metrics.get("epoch", None)
        ])
    
    # Create DataFrame
    columns = PARAMS + ['seed',
        "val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10", "test_epoch"
        ]
    
    df = pd.DataFrame(data, columns=columns)
    return df


def apply_seed_info(df):
    df['params'] = df.apply(lambda row: tuple([row[param] for param in PARAMS[1:]]), axis=1)
    params2seeds = {}
    for params, seed in zip(df['params'], df['seed']):
        if params not in params2seeds:
            params2seeds[params] = []
        params2seeds[params].append(seed)
    df['all_seeds'] = df.apply(lambda row: (params2seeds[row['params']]), axis=1)
    return df

# %%
len('{weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml'.split('-'))
# Out:
# 13

# %%
MODEL_NAME = 'sasrec'
DATASET = 'kion_en'
EXPERIMENT_NAME = 'KION_NORMAL'
SPLIT_NAME = 'general'
MODE = 'LLM'

local_directory = f"experiments-2_0/results/{MODEL_NAME}/{DATASET}/{EXPERIMENT_NAME}" 

seed_folders = ['other_seed']

# %%
import os


results = {}
for seed_folder in seed_folders:
    cur_folder = os.path.join(local_directory, seed_folder)
    for file in os.listdir(cur_folder):
        log_data = open_text(f'{cur_folder}/{file}')
        cur_results = parse_file_llm(log_data)
        # if cur_results['simple']['validation_metrics'] == []:
        #     continue
        results.update(cur_results)
    
    
exp_data_with_max_val = {}
for config in results:
    exp_data_with_max_val[config] = find_max(results, config, metric='NDCG@10')
exp_data_with_max_val.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-False-True-False-mean-False-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-False-True-False-mean-False-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-False-True-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.5-8-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-6-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-6-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-6-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-1-0.1-False-True-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_long_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_long_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/exponential-0.65-8-RMSE-2-0.1-False-True-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/mean-0.8-6-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/mean-0.8-6-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/kion_en/KION_NORMAL/other_seed/mean-0.8-6-MSE-1-0.1-False-True-False-mean-False-gemma_short_large_umap_single-42.yaml', '- ...

# %%
df = create_dataframe(exp_data_with_max_val)
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'ttention' else 'attention')
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'xponential' else 'exponential')
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 0   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 1   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 2   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 3   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 4   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 5   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 6   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 7   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 8   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 9   exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 10  exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 11  exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 12  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 13  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 14  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 15  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 16  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 17  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 18  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 19  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 20  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 21  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 22  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 23  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 24  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 25  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 26  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 27  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 28  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 29  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 30  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 31  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 32  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 33  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 34  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 35  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 36  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 37  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 38  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 39  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 40  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 41  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 42  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 43  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 44  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 45  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 46  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 47  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 48  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 49  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 50  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 51  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 52  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 53  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 54  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 55  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 56  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 57  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
# 58  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
# 59  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 0                 8             RMSE                     2           0.1
# 1                 8             RMSE                     2           0.1
# 2                 8             RMSE                     2           0.1
# 3                 8             RMSE                     2           0.1
# 4                 8             RMSE                     2           0.1
# 5                 8             RMSE                     2           0.1
# 6                 8             RMSE                     2           0.1
# 7                 8             RMSE                     2           0.1
# 8                 8             RMSE                     2           0.1
# 9                 6             RMSE                     1           0.1
# 10                6             RMSE                     1           0.1
# 11                6             RMSE                     1           0.1
# 12                8              MSE                     1           0.1
# 13                8              MSE                     1           0.1
# 14                8              MSE                     1           0.1
# 15                8             RMSE                     1           0.1
# 16                8             RMSE                     1           0.1
# 17                8             RMSE                     1           0.1
# 18                8             RMSE                     2           0.1
# 19                8             RMSE                     2           0.1
# 20                8             RMSE                     2           0.1
# 21                8             RMSE                     2           0.1
# 22                8             RMSE                     2           0.1
# 23                8             RMSE                     2           0.1
# 24                6              MSE                     1           0.1
# 25                6              MSE                     1           0.1
# 26                6              MSE                     1           0.1
# 27                6              MSE                     2           0.1
# 28                6              MSE                     2           0.1
# 29                6              MSE                     2           0.1
# 30                6             RMSE                     1           0.1
# 31                6             RMSE                     1           0.1
# 32                6             RMSE                     1           0.1
# 33                8              MSE                     1           0.1
# 34                8              MSE                     1           0.1
# 35                8              MSE                     1           0.1
# 36                8             RMSE                     1           0.1
# 37                8             RMSE                     1           0.1
# 38                8             RMSE                     1           0.1
# 39                6              MSE                     2           0.1
# 40                6              MSE                     2           0.1
# 41                6              MSE                     2           0.1
# 42                6              MSE                     2           0.1
# 43                6              MSE                     2           0.1
# 44                6              MSE                     2           0.1
# 45                8             RMSE                     2           0.1
# 46                8             RMSE                     2           0.1
# 47                8             RMSE                     2           0.1
# 48                8              MSE                     2           0.1
# 49                8              MSE                     2           0.1
# 50                8              MSE                     2           0.1
# 51                8             RMSE                     1           0.1
# 52                8             RMSE                     1           0.1
# 53                8             RMSE                     1           0.1
# 54                4             RMSE                     2           0.1
# 55                4             RMSE                     2           0.1
# 56                4             RMSE                     2           0.1
# 57                6              MSE                     1           0.1
# 58                6              MSE                     1           0.1
# 59                6              MSE                     1           0.1
#
#    use_down_scale use_upscale multi_profile multi_profile_aggr_scheme  \
# 0           False        True         False                      mean
# 1           False        True         False                      mean
# 2           False        True         False                      mean
# 3            True       False         False                      mean
# 4            True       False         False                      mean
# 5            True       False         False                      mean
# 6            True       False         False                      mean
# 7            True       False         False                      mean
# 8            True       False         False                      mean
# 9           False        True         False                      mean
# 10          False        True         False                      mean
# 11          False        True         False                      mean
# 12          False        True         False                      mean
# 13          False        True         False                      mean
# 14          False        True         False                      mean
# 15          False        True         False                      mean
# 16          False        True         False                      mean
# 17          False        True         False                      mean
# 18          False        True         False                      mean
# 19          False        True         False                      mean
# 20          False        True         False                      mean
# 21          False        True         False                      mean
# 22          False        True         False                      mean
# 23          False        True         False                      mean
# 24          False        True         False                      mean
# 25          False        True         False                      mean
# 26          False        True         False                      mean
# 27          False        True         False                      mean
# 28          False        True         False                      mean
# 29          False        True         False                      mean
# 30          False        True         False                      mean
# 31          False        True         False                      mean
# 32          False        True         False                      mean
# 33          False        True         False                      mean
# 34          False        True         False                      mean
# 35          False        True         False                      mean
# 36          False        True         False                      mean
# 37          False        True         False                      mean
# 38          False        True         False                      mean
# 39          False        True         False                      mean
# 40          False        True         False                      mean
# 41          False        True         False                      mean
# 42          False        True         False                      mean
# 43          False        True         False                      mean
# 44          False        True         False                      mean
# 45           True       False         False                      mean
# 46           True       False         False                      mean
# 47           True       False         False                      mean
# 48          False        True         False                      mean
# 49          False        True         False                      mean
# 50          False        True         False                      mean
# 51          False        True         False                      mean
# 52          False        True         False                      mean
# 53          False        True         False                      mean
# 54          False        True         False                      mean
# 55          False        True         False                      mean
# 56          False        True         False                      mean
# 57          False        True         False                      mean
# 58          False        True         False                      mean
# 59          False        True         False                      mean
#
#    scale_guide_loss  user_profile_embeddings_files  seed  val_NDCG@10  \
# 0             False  gemma_short_large_umap_single     1      0.09930
# 1             False  gemma_short_large_umap_single   256      0.09982
# 2             False  gemma_short_large_umap_single    42      0.09928
# 3              True   gemma_long_large_umap_single     1      0.09918
# 4              True   gemma_long_large_umap_single   256      0.09940
# 5              True   gemma_long_large_umap_single    42      0.09962
# 6              True  gemma_short_large_umap_single     1      0.09967
# 7              True  gemma_short_large_umap_single   256      0.10006
# 8              True  gemma_short_large_umap_single    42      0.10021
# 9              True  gemma_short_large_umap_single     1      0.09897
# 10             True  gemma_short_large_umap_single   256      0.09914
# 11             True  gemma_short_large_umap_single    42      0.09929
# 12            False  gemma_short_large_umap_single     1      0.09958
# 13            False  gemma_short_large_umap_single   256      0.09920
# 14            False  gemma_short_large_umap_single    42      0.09909
# 15             True  gemma_short_large_umap_single     1      0.09910
# 16             True  gemma_short_large_umap_single   256      0.09864
# 17             True  gemma_short_large_umap_single    42      0.09948
# 18             True   gemma_long_large_umap_single     1      0.09860
# 19             True   gemma_long_large_umap_single   256      0.09943
# 20             True   gemma_long_large_umap_single    42      0.09914
# 21             True  gemma_short_large_umap_single     1      0.10036
# 22             True  gemma_short_large_umap_single   256      0.09921
# 23             True  gemma_short_large_umap_single    42      0.09987
# 24            False  gemma_short_large_umap_single     1      0.09948
# 25            False  gemma_short_large_umap_single   256      0.09846
# 26            False  gemma_short_large_umap_single    42      0.09938
# 27             True   gemma_long_large_umap_single     1      0.09935
# 28             True   gemma_long_large_umap_single   256      0.09983
# 29             True   gemma_long_large_umap_single    42      0.09967
# 30            False  gemma_short_large_umap_single     1      0.09914
# 31            False  gemma_short_large_umap_single   256      0.09927
# 32            False  gemma_short_large_umap_single    42      0.09992
# 33            False  gemma_short_large_umap_single     1      0.09780
# 34            False  gemma_short_large_umap_single   256      0.09775
# 35            False  gemma_short_large_umap_single    42      0.09908
# 36            False  gemma_short_large_umap_single     1      0.09954
# 37            False  gemma_short_large_umap_single   256      0.10002
# 38            False  gemma_short_large_umap_single    42      0.09957
# 39            False   gemma_long_large_umap_single     1      0.09864
# 40            False   gemma_long_large_umap_single   256      0.09942
# 41            False   gemma_long_large_umap_single    42      0.10009
# 42             True  gemma_short_large_umap_single     1      0.09925
# 43             True  gemma_short_large_umap_single   256      0.09976
# 44             True  gemma_short_large_umap_single    42      0.09932
# 45             True  gemma_short_large_umap_single     1      0.09992
# 46             True  gemma_short_large_umap_single   256      0.10024
# 47             True  gemma_short_large_umap_single    42      0.10022
# 48             True   gemma_long_large_umap_single     1      0.09973
# 49             True   gemma_long_large_umap_single   256      0.09908
# 50             True   gemma_long_large_umap_single    42      0.09951
# 51            False  gemma_short_large_umap_single     1      0.09940
# 52            False  gemma_short_large_umap_single   256      0.09967
# 53            False  gemma_short_large_umap_single    42      0.09901
# 54            False   gemma_long_large_umap_single     1      0.09991
# 55            False   gemma_long_large_umap_single   256      0.09978
# 56            False   gemma_long_large_umap_single    42      0.09958
# 57            False   gemma_long_large_umap_single     1      0.09941
# 58            False   gemma_long_large_umap_single   256      0.09926
# 59            False   gemma_long_large_umap_single    42      0.09906
#
#     val_Recall@10  val_epoch  test_NDCG@10  test_Recall@10  test_epoch
# 0         0.18264         16       0.05890         0.11401          16
# 1         0.18416         19       0.05898         0.11414          19
# 2         0.18416         18       0.05939         0.11429          18
# 3         0.18269         17       0.05913         0.11393          17
# 4         0.18373         19       0.05971         0.11567          19
# 5         0.18427         20       0.05932         0.11393          20
# 6         0.18329         17       0.05904         0.11401          17
# 7         0.18427         19       0.05767         0.11245          19
# 8         0.18530         14       0.06063         0.11623          14
# 9         0.18400         20       0.05874         0.11299          20
# 10        0.18253         14       0.05906         0.11399          14
# 11        0.18226         17       0.05950         0.11634          17
# 12        0.18345         20       0.05954         0.11406          20
# 13        0.18220         20       0.05841         0.11324          20
# 14        0.18226         17       0.05828         0.11249          17
# 15        0.18411         20       0.05956         0.11418          20
# 16        0.18210         17       0.05944         0.11571          17
# 17        0.18427         20       0.06024         0.11552          20
# 18        0.18335         19       0.05934         0.11330          19
# 19        0.18329         17       0.05944         0.11424          17
# 20        0.18264         17       0.05925         0.11460          17
# 21        0.18530         20       0.05808         0.11169          20
# 22        0.18449         19       0.05952         0.11489          19
# 23        0.18324         17       0.05889         0.11376          17
# 24        0.18275         20       0.05920         0.11320          20
# 25        0.18177         18       0.05950         0.11496          18
# 26        0.18400         20       0.05989         0.11533          20
# 27        0.18297         20       0.05839         0.11351          20
# 28        0.18269         19       0.05950         0.11535          19
# 29        0.18340         17       0.05968         0.11552          17
# 30        0.18280         19       0.05938         0.11449          19
# 31        0.18280         19       0.05935         0.11481          19
# 32        0.18389         20       0.06029         0.11619          20
# 33        0.18090         20       0.05889         0.11320          20
# 34        0.18084         19       0.05856         0.11385          19
# 35        0.18242         20       0.06043         0.11634          20
# 36        0.18454         20       0.05875         0.11190          20
# 37        0.18367         19       0.05974         0.11475          19
# 38        0.18356         20       0.05996         0.11550          20
# 39        0.18318         19       0.05948         0.11426          19
# 40        0.18367         19       0.05861         0.11265          19
# 41        0.18422         20       0.05994         0.11508          20
# 42        0.18384         20       0.05863         0.11357          20
# 43        0.18422         17       0.05986         0.11558          17
# 44        0.18237         18       0.06011         0.11508          18
# 45        0.18389         17       0.05907         0.11408          17
# 46        0.18623         18       0.06011         0.11531          18
# 47        0.18481         16       0.05982         0.11424          16
# 48        0.18454         20       0.05943         0.11416          20
# 49        0.18443         18       0.05950         0.11383          18
# 50        0.18258         17       0.05841         0.11293          17
# 51        0.18291         20       0.05936         0.11353          20
# 52        0.18297         17       0.05948         0.11481          17
# 53        0.18106         17       0.05857         0.11391          17
# 54        0.18476         17       0.05846         0.11334          17
# 55        0.18427         14       0.05974         0.11542          14
# 56        0.18166         18       0.05865         0.11347          18
# 57        0.18335         19       0.05969         0.11452          19
# 58        0.18258         19       0.05964         0.11565          19
# 59        0.18117         20       0.05894         0.11337          20

# %%
df['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# exponential    30
# mean           30
# Name: count, dtype: int64

# %%
df = apply_seed_info(df)
df.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 21  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 46  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 47  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 8   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 41  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 7   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 37  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 32  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 45  mean-0.65-8-RMSE-2-0.1-True-False-False-mean-T...             mean   0.65
# 54  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 23  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 28  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 1   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 55  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 43  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 48  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 52  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 29  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 6   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 5   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 56  mean-0.5-4-RMSE-2-0.1-False-True-False-mean-Fa...             mean   0.50
# 12  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 38  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 36  mean-0.5-8-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.50
# 50  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 24  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 17  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 19  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 40  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 57  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
# 4   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 51  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 26  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 27  mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean   0.80
# 44  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 0   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 11  exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 2   exponential-0.5-8-RMSE-2-0.1-False-True-False-...      exponential   0.50
# 31  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 58  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
# 42  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Tr...             mean   0.65
# 22  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 13  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 3   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential   0.50
# 30  mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean   0.80
# 20  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 10  exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 15  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 14  exponential-0.65-8-MSE-1-0.1-False-True-False-...      exponential   0.65
# 35  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 49  exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential   0.80
# 59  mean-0.5-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.50
# 53  exponential-0.8-8-RMSE-1-0.1-False-True-False-...      exponential   0.80
# 9   exponential-0.65-6-RMSE-1-0.1-False-True-False...      exponential   0.65
# 39  mean-0.65-6-MSE-2-0.1-False-True-False-mean-Fa...             mean   0.65
# 16  exponential-0.65-8-RMSE-1-0.1-False-True-False...      exponential   0.65
# 18  exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential   0.65
# 25  mean-0.8-6-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 33  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
# 34  mean-0.8-8-MSE-1-0.1-False-True-False-mean-Fal...             mean   0.80
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 21                8             RMSE                     2           0.1
# 46                8             RMSE                     2           0.1
# 47                8             RMSE                     2           0.1
# 8                 8             RMSE                     2           0.1
# 41                6              MSE                     2           0.1
# 7                 8             RMSE                     2           0.1
# 37                8             RMSE                     1           0.1
# 32                6             RMSE                     1           0.1
# 45                8             RMSE                     2           0.1
# 54                4             RMSE                     2           0.1
# 23                8             RMSE                     2           0.1
# 28                6              MSE                     2           0.1
# 1                 8             RMSE                     2           0.1
# 55                4             RMSE                     2           0.1
# 43                6              MSE                     2           0.1
# 48                8              MSE                     2           0.1
# 52                8             RMSE                     1           0.1
# 29                6              MSE                     2           0.1
# 6                 8             RMSE                     2           0.1
# 5                 8             RMSE                     2           0.1
# 56                4             RMSE                     2           0.1
# 12                8              MSE                     1           0.1
# 38                8             RMSE                     1           0.1
# 36                8             RMSE                     1           0.1
# 50                8              MSE                     2           0.1
# 24                6              MSE                     1           0.1
# 17                8             RMSE                     1           0.1
# 19                8             RMSE                     2           0.1
# 40                6              MSE                     2           0.1
# 57                6              MSE                     1           0.1
# 4                 8             RMSE                     2           0.1
# 51                8             RMSE                     1           0.1
# 26                6              MSE                     1           0.1
# 27                6              MSE                     2           0.1
# 44                6              MSE                     2           0.1
# 0                 8             RMSE                     2           0.1
# 11                6             RMSE                     1           0.1
# 2                 8             RMSE                     2           0.1
# 31                6             RMSE                     1           0.1
# 58                6              MSE                     1           0.1
# 42                6              MSE                     2           0.1
# 22                8             RMSE                     2           0.1
# 13                8              MSE                     1           0.1
# 3                 8             RMSE                     2           0.1
# 30                6             RMSE                     1           0.1
# 20                8             RMSE                     2           0.1
# 10                6             RMSE                     1           0.1
# 15                8             RMSE                     1           0.1
# 14                8              MSE                     1           0.1
# 35                8              MSE                     1           0.1
# 49                8              MSE                     2           0.1
# 59                6              MSE                     1           0.1
# 53                8             RMSE                     1           0.1
# 9                 6             RMSE                     1           0.1
# 39                6              MSE                     2           0.1
# 16                8             RMSE                     1           0.1
# 18                8             RMSE                     2           0.1
# 25                6              MSE                     1           0.1
# 33                8              MSE                     1           0.1
# 34                8              MSE                     1           0.1
#
#    use_down_scale use_upscale multi_profile  ...  \
# 21          False        True         False  ...
# 46           True       False         False  ...
# 47           True       False         False  ...
# 8            True       False         False  ...
# 41          False        True         False  ...
# 7            True       False         False  ...
# 37          False        True         False  ...
# 32          False        True         False  ...
# 45           True       False         False  ...
# 54          False        True         False  ...
# 23          False        True         False  ...
# 28          False        True         False  ...
# 1           False        True         False  ...
# 55          False        True         False  ...
# 43          False        True         False  ...
# 48          False        True         False  ...
# 52          False        True         False  ...
# 29          False        True         False  ...
# 6            True       False         False  ...
# 5            True       False         False  ...
# 56          False        True         False  ...
# 12          False        True         False  ...
# 38          False        True         False  ...
# 36          False        True         False  ...
# 50          False        True         False  ...
# 24          False        True         False  ...
# 17          False        True         False  ...
# 19          False        True         False  ...
# 40          False        True         False  ...
# 57          False        True         False  ...
# 4            True       False         False  ...
# 51          False        True         False  ...
# 26          False        True         False  ...
# 27          False        True         False  ...
# 44          False        True         False  ...
# 0           False        True         False  ...
# 11          False        True         False  ...
# 2           False        True         False  ...
# 31          False        True         False  ...
# 58          False        True         False  ...
# 42          False        True         False  ...
# 22          False        True         False  ...
# 13          False        True         False  ...
# 3            True       False         False  ...
# 30          False        True         False  ...
# 20          False        True         False  ...
# 10          False        True         False  ...
# 15          False        True         False  ...
# 14          False        True         False  ...
# 35          False        True         False  ...
# 49          False        True         False  ...
# 59          False        True         False  ...
# 53          False        True         False  ...
# 9           False        True         False  ...
# 39          False        True         False  ...
# 16          False        True         False  ...
# 18          False        True         False  ...
# 25          False        True         False  ...
# 33          False        True         False  ...
# 34          False        True         False  ...
#
#     user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  val_epoch  \
# 21  gemma_short_large_umap_single    1     0.10036        0.18530         20
# 46  gemma_short_large_umap_single  256     0.10024        0.18623         18
# 47  gemma_short_large_umap_single   42     0.10022        0.18481         16
# 8   gemma_short_large_umap_single   42     0.10021        0.18530         14
# 41   gemma_long_large_umap_single   42     0.10009        0.18422         20
# 7   gemma_short_large_umap_single  256     0.10006        0.18427         19
# 37  gemma_short_large_umap_single  256     0.10002        0.18367         19
# 32  gemma_short_large_umap_single   42     0.09992        0.18389         20
# 45  gemma_short_large_umap_single    1     0.09992        0.18389         17
# 54   gemma_long_large_umap_single    1     0.09991        0.18476         17
# 23  gemma_short_large_umap_single   42     0.09987        0.18324         17
# 28   gemma_long_large_umap_single  256     0.09983        0.18269         19
# 1   gemma_short_large_umap_single  256     0.09982        0.18416         19
# 55   gemma_long_large_umap_single  256     0.09978        0.18427         14
# 43  gemma_short_large_umap_single  256     0.09976        0.18422         17
# 48   gemma_long_large_umap_single    1     0.09973        0.18454         20
# 52  gemma_short_large_umap_single  256     0.09967        0.18297         17
# 29   gemma_long_large_umap_single   42     0.09967        0.18340         17
# 6   gemma_short_large_umap_single    1     0.09967        0.18329         17
# 5    gemma_long_large_umap_single   42     0.09962        0.18427         20
# 56   gemma_long_large_umap_single   42     0.09958        0.18166         18
# 12  gemma_short_large_umap_single    1     0.09958        0.18345         20
# 38  gemma_short_large_umap_single   42     0.09957        0.18356         20
# 36  gemma_short_large_umap_single    1     0.09954        0.18454         20
# 50   gemma_long_large_umap_single   42     0.09951        0.18258         17
# 24  gemma_short_large_umap_single    1     0.09948        0.18275         20
# 17  gemma_short_large_umap_single   42     0.09948        0.18427         20
# 19   gemma_long_large_umap_single  256     0.09943        0.18329         17
# 40   gemma_long_large_umap_single  256     0.09942        0.18367         19
# 57   gemma_long_large_umap_single    1     0.09941        0.18335         19
# 4    gemma_long_large_umap_single  256     0.09940        0.18373         19
# 51  gemma_short_large_umap_single    1     0.09940        0.18291         20
# 26  gemma_short_large_umap_single   42     0.09938        0.18400         20
# 27   gemma_long_large_umap_single    1     0.09935        0.18297         20
# 44  gemma_short_large_umap_single   42     0.09932        0.18237         18
# 0   gemma_short_large_umap_single    1     0.09930        0.18264         16
# 11  gemma_short_large_umap_single   42     0.09929        0.18226         17
# 2   gemma_short_large_umap_single   42     0.09928        0.18416         18
# 31  gemma_short_large_umap_single  256     0.09927        0.18280         19
# 58   gemma_long_large_umap_single  256     0.09926        0.18258         19
# 42  gemma_short_large_umap_single    1     0.09925        0.18384         20
# 22  gemma_short_large_umap_single  256     0.09921        0.18449         19
# 13  gemma_short_large_umap_single  256     0.09920        0.18220         20
# 3    gemma_long_large_umap_single    1     0.09918        0.18269         17
# 30  gemma_short_large_umap_single    1     0.09914        0.18280         19
# 20   gemma_long_large_umap_single   42     0.09914        0.18264         17
# 10  gemma_short_large_umap_single  256     0.09914        0.18253         14
# 15  gemma_short_large_umap_single    1     0.09910        0.18411         20
# 14  gemma_short_large_umap_single   42     0.09909        0.18226         17
# 35  gemma_short_large_umap_single   42     0.09908        0.18242         20
# 49   gemma_long_large_umap_single  256     0.09908        0.18443         18
# 59   gemma_long_large_umap_single   42     0.09906        0.18117         20
# 53  gemma_short_large_umap_single   42     0.09901        0.18106         17
# 9   gemma_short_large_umap_single    1     0.09897        0.18400         20
# 39   gemma_long_large_umap_single    1     0.09864        0.18318         19
# 16  gemma_short_large_umap_single  256     0.09864        0.18210         17
# 18   gemma_long_large_umap_single    1     0.09860        0.18335         19
# 25  gemma_short_large_umap_single  256     0.09846        0.18177         18
# 33  gemma_short_large_umap_single    1     0.09780        0.18090         20
# 34  gemma_short_large_umap_single  256     0.09775        0.18084         19
#
#     test_NDCG@10  test_Recall@10  test_epoch  \
# 21       0.05808         0.11169          20
# 46       0.06011         0.11531          18
# 47       0.05982         0.11424          16
# 8        0.06063         0.11623          14
# 41       0.05994         0.11508          20
# 7        0.05767         0.11245          19
# 37       0.05974         0.11475          19
# 32       0.06029         0.11619          20
# 45       0.05907         0.11408          17
# 54       0.05846         0.11334          17
# 23       0.05889         0.11376          17
# 28       0.05950         0.11535          19
# 1        0.05898         0.11414          19
# 55       0.05974         0.11542          14
# 43       0.05986         0.11558          17
# 48       0.05943         0.11416          20
# 52       0.05948         0.11481          17
# 29       0.05968         0.11552          17
# 6        0.05904         0.11401          17
# 5        0.05932         0.11393          20
# 56       0.05865         0.11347          18
# 12       0.05954         0.11406          20
# 38       0.05996         0.11550          20
# 36       0.05875         0.11190          20
# 50       0.05841         0.11293          17
# 24       0.05920         0.11320          20
# 17       0.06024         0.11552          20
# 19       0.05944         0.11424          17
# 40       0.05861         0.11265          19
# 57       0.05969         0.11452          19
# 4        0.05971         0.11567          19
# 51       0.05936         0.11353          20
# 26       0.05989         0.11533          20
# 27       0.05839         0.11351          20
# 44       0.06011         0.11508          18
# 0        0.05890         0.11401          16
# 11       0.05950         0.11634          17
# 2        0.05939         0.11429          18
# 31       0.05935         0.11481          19
# 58       0.05964         0.11565          19
# 42       0.05863         0.11357          20
# 22       0.05952         0.11489          19
# 13       0.05841         0.11324          20
# 3        0.05913         0.11393          17
# 30       0.05938         0.11449          19
# 20       0.05925         0.11460          17
# 10       0.05906         0.11399          14
# 15       0.05956         0.11418          20
# 14       0.05828         0.11249          17
# 35       0.06043         0.11634          20
# 49       0.05950         0.11383          18
# 59       0.05894         0.11337          20
# 53       0.05857         0.11391          17
# 9        0.05874         0.11299          20
# 39       0.05948         0.11426          19
# 16       0.05944         0.11571          17
# 18       0.05934         0.11330          19
# 25       0.05950         0.11496          18
# 33       0.05889         0.11320          20
# 34       0.05856         0.11385          19
#
#                                                params     all_seeds
# 21  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 46  (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fal...  [1, 256, 42]
# 47  (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fal...  [1, 256, 42]
# 8   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 41  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 7   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 37  (mean, 0.5, 8, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 32  (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 45  (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fal...  [1, 256, 42]
# 54  (mean, 0.5, 4, RMSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 23  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 28  (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...  [1, 256, 42]
# 1   (exponential, 0.5, 8, RMSE, 2, 0.1, False, Tru...  [1, 256, 42]
# 55  (mean, 0.5, 4, RMSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 43  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 48  (exponential, 0.8, 8, MSE, 2, 0.1, False, True...  [1, 256, 42]
# 52  (exponential, 0.8, 8, RMSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 29  (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...  [1, 256, 42]
# 6   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 5   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 56  (mean, 0.5, 4, RMSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 12  (exponential, 0.65, 8, MSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 38  (mean, 0.5, 8, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 36  (mean, 0.5, 8, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 50  (exponential, 0.8, 8, MSE, 2, 0.1, False, True...  [1, 256, 42]
# 24  (mean, 0.8, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 17  (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 19  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 40  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 57  (mean, 0.5, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 4   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 51  (exponential, 0.8, 8, RMSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 26  (mean, 0.8, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 27  (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...  [1, 256, 42]
# 44  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 0   (exponential, 0.5, 8, RMSE, 2, 0.1, False, Tru...  [1, 256, 42]
# 11  (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 2   (exponential, 0.5, 8, RMSE, 2, 0.1, False, Tru...  [1, 256, 42]
# 31  (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 58  (mean, 0.5, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 42  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 22  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 13  (exponential, 0.65, 8, MSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 3   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...  [1, 256, 42]
# 30  (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...  [1, 256, 42]
# 20  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 10  (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 15  (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 14  (exponential, 0.65, 8, MSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 35  (mean, 0.8, 8, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 49  (exponential, 0.8, 8, MSE, 2, 0.1, False, True...  [1, 256, 42]
# 59  (mean, 0.5, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 53  (exponential, 0.8, 8, RMSE, 1, 0.1, False, Tru...  [1, 256, 42]
# 9   (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 39  (mean, 0.65, 6, MSE, 2, 0.1, False, True, Fals...  [1, 256, 42]
# 16  (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tr...  [1, 256, 42]
# 18  (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...  [1, 256, 42]
# 25  (mean, 0.8, 6, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 33  (mean, 0.8, 8, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
# 34  (mean, 0.8, 8, MSE, 1, 0.1, False, True, False...  [1, 256, 42]
#
# [60 rows x 22 columns]

# %%
df.to_csv('kion_llm_all_runs.csv')

# %%
def get_stats_seeds(df_all):
    def aggregate_mean(series):
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        return series.mean()
        # print(df)
        # all_cols = set(df.columns)
        # df_mean = df.mean(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    def aggregate_std(series):
        # print(series)
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        if len(series) == 1:
            return 0
        return series.std()
        # all_cols = set(df.columns)
        # df_mean = df.std(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    
    metric_cols = ["val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10"]
        
    grouped_df = df_all.drop(['config_file', 'all_seeds', 'seed'], axis=1).groupby('params')
    df_mean = grouped_df.agg(aggregate_mean)
    df_std = grouped_df.agg(aggregate_std)
    for col in metric_cols:
        df_mean[col + '__std'] = df_std[col]
    return df_mean


def reorder_cols(df):
    order = ['val_epoch', 'val_epoch__std'] + PARAMS[1:] + ['val_NDCG@10', 'val_NDCG@10__std', 'val_Recall@10', 'val_Recall@10__std', 'test_NDCG@10', 'test_NDCG@10__std', 'test_Recall@10', 'test_Recall@10__std']
    return df[order]


df_all = df[df['all_seeds'].apply(len) == 3]
df_final = get_stats_seeds(df_all)
df_final = reorder_cols(df_final)
df_final.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df_final
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...  17.000000        1.000000
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...  16.666667        2.516611
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...  18.666667        1.527525
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...  16.333333        2.081666
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  19.666667        0.577350
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...  18.666667        1.527525
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  17.666667        1.527525
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  18.333333        1.527525
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  19.333333        0.577350
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...  18.333333        1.527525
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...  18.666667        1.527525
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  19.333333        0.577350
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  18.000000        1.732051
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  19.000000        1.732051
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  19.333333        0.577350
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...  17.000000        3.000000
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  19.333333        1.154701
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...  19.000000        1.732051
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...  17.666667        1.154701
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  19.666667        0.577350
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...             mean   0.65
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...      exponential   0.50
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...      exponential   0.65
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             mean   0.50
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             mean   0.50
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...             mean   0.80
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      exponential   0.50
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             mean   0.65
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             mean   0.80
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...      exponential   0.80
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...      exponential   0.50
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             mean   0.65
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      exponential   0.80
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      exponential   0.65
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...      exponential   0.65
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...      exponential   0.65
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...      exponential   0.65
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             mean   0.80
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...              8.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...              8.0
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...              8.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...              4.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...              8.0
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...              6.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...              8.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              6.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...              6.0
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...              8.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...              8.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              6.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...              8.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              8.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...              6.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...              8.0
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...              8.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              8.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...             RMSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...             RMSE
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...             RMSE
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             RMSE
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             RMSE
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...              MSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             RMSE
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              MSE
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             RMSE
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...              MSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...             RMSE
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              MSE
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             RMSE
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              MSE
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...             RMSE
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...             RMSE
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...             RMSE
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              MSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...                   2.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...                   2.0
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...                   2.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...                   2.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...                   2.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...                   1.0
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...                   2.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...                   2.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...                   2.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...                   1.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...                   1.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...                   1.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...                   1.0
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...                   2.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           0.1
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...           0.1
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.1
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.1
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           0.1
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.1
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.1
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.1
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...           0.1
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...           0.1
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...           0.1
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...           True       False
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           True       False
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...          False        True
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...          False        True
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...          False        True
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...          False        True
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...          False        True
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           True       False
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...          False        True
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...          False        True
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...          False        True
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...          False        True
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...          False        True
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...          False        True
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...          False        True
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...  ...             True
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...  ...             True
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...  ...             True
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...  ...             True
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  ...            False
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  ...             True
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  ...            False
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...  ...             True
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...  ...             True
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  ...            False
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  ...            False
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  ...            False
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...  ...             True
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...  ...             True
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...  ...             True
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  ...            False
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...  gemma_short_large_umap_single
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...  gemma_short_large_umap_single
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...   gemma_long_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  gemma_short_large_umap_single
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...   gemma_long_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...   gemma_long_large_umap_single
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...  gemma_short_large_umap_single
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...  gemma_short_large_umap_single
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...   gemma_long_large_umap_single
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...    0.100127
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...    0.099980
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...    0.099813
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...    0.099757
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...    0.099710
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...    0.099617
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...    0.099467
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...    0.099443
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...    0.099443
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...    0.099440
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...    0.099400
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...    0.099383
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...    0.099360
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...    0.099290
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099243
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...    0.099133
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...    0.099107
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...    0.099073
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...    0.099057
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...    0.098210
#
#                                                    val_NDCG@10__std  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...         0.000179
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...         0.000279
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...         0.000577
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...         0.000166
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...         0.000269
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...         0.000244
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...         0.000306
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...         0.000276
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...         0.000418
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...         0.000331
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...         0.000220
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...         0.000726
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...         0.000332
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...         0.000257
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000176
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...         0.000160
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...         0.000562
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...         0.000421
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...         0.000421
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...         0.000754
#
#                                                     val_Recall@10  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...       0.184977
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...       0.184287
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...       0.184343
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...       0.183563
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...       0.183923
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...       0.183020
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...       0.183653
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...       0.183477
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...       0.183163
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...       0.183850
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...       0.183563
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...       0.183690
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...       0.182313
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...       0.182637
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.182367
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...       0.182930
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...       0.182840
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...       0.183493
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...       0.183093
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...       0.181387
#
#                                                     val_Recall@10__std  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...            0.001179
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...            0.001005
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...            0.001038
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...            0.001666
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...            0.000537
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...            0.000358
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...            0.000878
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...            0.000977
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...            0.000629
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...            0.001101
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...            0.000803
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...            0.000520
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...            0.001086
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...            0.000705
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.001106
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...            0.000936
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...            0.001118
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...            0.001209
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...            0.000394
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...            0.000895
#
#                                                     test_NDCG@10  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...      0.059667
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...      0.059113
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...      0.058830
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...      0.058950
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...      0.059483
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...      0.059190
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      0.059090
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...      0.059533
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...      0.059673
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...      0.059113
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...      0.059387
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...      0.059343
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      0.059137
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      0.058743
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059423
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...      0.059100
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...      0.059530
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...      0.059747
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...      0.059343
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...      0.059293
#
#                                                     test_NDCG@10__std  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...           0.000537
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           0.001481
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...           0.000722
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.000691
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.000645
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...           0.000699
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.000263
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.000792
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.000534
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...           0.000610
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...           0.000296
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.000675
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.000494
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.000693
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000419
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...           0.000382
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.000346
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...           0.000431
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...           0.000095
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.000998
#
#                                                     test_Recall@10  \
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...        0.114543
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...        0.114230
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...        0.113447
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...        0.114077
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...        0.114050
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...        0.114793
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...        0.114147
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...        0.114743
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...        0.115163
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...        0.113640
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...        0.114510
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...        0.113997
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...        0.114083
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...        0.113263
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.114513
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...        0.114440
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...        0.114497
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...        0.115137
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...        0.114047
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...        0.114463
#
#                                                     test_Recall@10__std
# params
# (mean, 0.65, 8, RMSE, 2, 0.1, True, False, Fals...             0.000669
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...             0.001900
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...             0.001623
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             0.001165
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             0.001899
# (mean, 0.8, 6, MSE, 2, 0.1, False, True, False,...             0.001115
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             0.000140
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             0.001046
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             0.000903
# (exponential, 0.8, 8, MSE, 2, 0.1, False, True,...             0.000637
# (exponential, 0.5, 8, RMSE, 2, 0.1, True, False...             0.001005
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             0.001236
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             0.000657
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...             0.000785
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.001140
# (exponential, 0.65, 6, RMSE, 1, 0.1, False, Tru...             0.001720
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             0.001138
# (exponential, 0.65, 8, RMSE, 1, 0.1, False, Tru...             0.000834
# (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tru...             0.000671
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             0.001657
#
# [20 rows x 22 columns]

# %%
df_final.to_csv('kion_llm_all_runs_NEW.csv')

# %%
df_final['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# mean           23
# exponential    17
# Name: count, dtype: int64

# %%
df_final[df_final['scale_guide_loss'] == 'False']
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   9.333333        1.527525
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  12.666667        1.527525
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  13.000000        1.732051
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  13.666667        0.577350
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  14.666667        1.154701
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  14.000000        0.000000
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  14.000000        0.000000
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  14.666667        0.577350
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...   6.666667        1.154701
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  11.000000        0.000000
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  16.666667        2.516611
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  10.666667        2.516611
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  15.666667        2.886751
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  16.000000        1.732051
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             mean   0.50
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      exponential   0.80
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      exponential   0.80
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      exponential   0.50
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      exponential   0.80
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             mean   0.65
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             mean   0.80
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      exponential   0.65
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             mean   0.65
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             mean   0.65
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             mean   0.50
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             mean   0.65
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      exponential   0.50
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             mean   0.50
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             mean   0.80
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...              4.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...              8.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              8.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...              8.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...              6.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              8.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              6.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              6.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              4.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              6.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              8.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...              4.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...              8.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...              8.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             RMSE
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             RMSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              MSE
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             RMSE
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             RMSE
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              MSE
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              MSE
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             RMSE
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             RMSE
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             RMSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...                   1.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...                   1.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...                   1.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...                   1.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...                   1.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...                   1.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.1
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.1
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.1
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.1
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.1
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...          False        True
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...          False        True
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...          False        True
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...          False        True
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...          False        True
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...          False        True
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...          False        True
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  ...            False
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  ...            False
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  ...            False
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  ...            False
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  ...            False
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...  ...            False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  ...            False
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  ...            False
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...   gemma_long_large_umap_single
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  gemma_short_large_umap_single
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        gemma_long_large_single
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...   gemma_long_large_umap_single
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...   gemma_long_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099597
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...    0.099523
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099293
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...    0.099367
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...    0.099387
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...    0.099817
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...    0.099327
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...    0.099287
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...    0.099290
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...    0.098963
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...    0.099420
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...    0.098700
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...    0.099557
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...    0.099253
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...    0.099280
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...    0.098933
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...    0.099103
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...    0.099237
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...    0.099320
#
#                                                    val_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000808
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...         0.000072
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000384
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...         0.000376
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...         0.000116
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...         0.000266
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...         0.000539
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...         0.000652
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...         0.000521
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...         0.000100
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...         0.000670
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...         0.000743
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...         0.000778
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...         0.000325
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...         0.000524
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...         0.000314
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...         0.000295
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...         0.000196
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...         0.000223
#
#                                                     val_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183400
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...       0.182587
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183760
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...       0.183277
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...       0.183037
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...       0.183417
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...       0.183563
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...       0.183017
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...       0.183927
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...       0.183003
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...       0.183240
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...       0.183003
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...       0.184073
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...       0.183453
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...       0.183363
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...       0.182423
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...       0.183927
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...       0.183690
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...       0.183363
#
#                                                     val_Recall@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000946
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...            0.000343
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000537
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...            0.000603
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...            0.000872
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...            0.001399
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...            0.000333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...            0.001596
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...            0.000652
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...            0.000907
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...            0.000991
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...            0.001063
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...            0.000845
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...            0.000285
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...            0.000879
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...            0.000815
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...            0.001256
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...            0.000514
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...            0.000926
#
#                                                     test_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059867
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...      0.059717
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059667
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      0.059640
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      0.059383
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      0.059373
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      0.059353
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...      0.059330
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...      0.059287
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      0.059250
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...      0.059233
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...      0.059230
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...      0.059217
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...      0.059010
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...      0.058993
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...      0.058983
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      0.058937
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...      0.058880
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...      0.058810
#
#                                                     test_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000621
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.000998
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000748
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.000927
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.000947
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.001048
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.000945
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.000872
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.001598
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.000990
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.001301
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.000987
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.001076
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.001067
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.001248
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.001705
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.001215
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.001465
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.001323
#
#                                                     test_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.115200
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...        0.114783
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.114967
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...        0.114837
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...        0.114020
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...        0.114633
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...        0.114333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...        0.113890
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...        0.114723
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...        0.113957
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...        0.113177
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        0.114313
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...        0.114250
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...        0.114347
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...        0.113757
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...        0.113810
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...        0.114883
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...        0.113457
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...        0.113713
#
#                                                     test_Recall@10__std
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000375
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             0.001294
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000718
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             0.001643
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             0.000931
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             0.002053
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...             0.000127
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             0.000656
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             0.001650
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...             0.001367
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             0.002264
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             0.001370
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             0.001652
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             0.000874
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             0.001516
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             0.002309
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             0.001557
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             0.001436
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             0.001162
#
# [19 rows x 22 columns]

# %%
df_final2 = df_final.drop([('mean', 0.65, 8, 'RMSE', 2, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_short_large_umap_single'), 
               ('mean', 0.65, 6, 'MSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_long_large_umap_single')], axis=0, inplace=False)

df_final2.to_csv('beauty_llm_all_runs_NORMAL.csv')

# %%
df_final.index
# Out:
# Index([       ('mean', 0.65, 8, 'RMSE', 2, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#         ('exponential', 0.5, 8, 'RMSE', 2, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#               ('mean', 0.8, 6, 'RMSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#        ('exponential', 0.65, 6, 'RMSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#          ('exponential', 0.5, 8, 'RMSE', 2, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_long_large_umap_single'),
#                ('mean', 0.8, 8, 'MSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#                ('mean', 0.5, 4, 'RMSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_long_large_umap_single'),
#        ('exponential', 0.65, 8, 'RMSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#                 ('mean', 0.5, 6, 'MSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_long_large_umap_single'),
#               ('mean', 0.5, 8, 'RMSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#                ('mean', 0.8, 6, 'MSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#         ('exponential', 0.65, 8, 'RMSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_long_large_umap_single'),
#        ('exponential', 0.5, 8, 'RMSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#        ('exponential', 0.65, 8, 'RMSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#        ('exponential', 0.8, 8, 'RMSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#        ('exponential', 0.65, 8, 'MSE', 1, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_short_large_umap_single'),
#                  ('mean', 0.8, 6, 'MSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_long_large_umap_single'),
#           ('exponential', 0.8, 8, 'MSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_long_large_umap_single'),
#                ('mean', 0.65, 6, 'MSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'True', 'gemma_short_large_umap_single'),
#                ('mean', 0.65, 6, 'MSE', 2, 0.1, 'False', 'True', 'False', 'mean', 'False', 'gemma_long_large_umap_single')],
#       dtype='object', name='params')

# %%
df['params'].value_counts()
# Out:
# params
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, False, mean, True, gemma_short_large_umap_single)         3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         3
# (mean, 0.6, 6, RMSE, 2, 0.1, True, False, False, mean, True, gemma_long_large_umap_single)          3
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)    3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)              3
#                                                                                                    ..
# (mean, 0.6, 12, MSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         1
# (mean, 0.7, 6, RMSE, 1, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)         1
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)          1
# (attention, 0.6, 6, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)     1
# (attention, 0.7, 12, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)    1
# Name: count, Length: 558, dtype: int64

# %%
df['']
# Out:
#                                             config_file weighting_scheme  \
# 663   mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean
# 837   exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential
# 779   exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential
# 649   mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean
# 467   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential
# ...                                                 ...              ...
# 876   exponential-0.8-8-RMSE-2-0.1-True-False-False-...      exponential
# 792   exponential-0.8-4-MSE-1-0.1-False-True-False-m...      exponential
# 25    attention-0.65-8-MSE-1-0.1-False-True-False-me...        attention
# 274   attention-0.8-6-MSE-2-0.1-True-False-False-mea...        attention
# 1161  attention-0.5-8-MSE-1-0.1-False-True-False-mea...        attention
#
#       alpha  fine_tune_epoch reconstruct_loss  reconstruction_layer  \
# 663    0.80                6             RMSE                     1
# 837    0.80                8              MSE                     2
# 779    0.65                8             RMSE                     2
# 649    0.80                6              MSE                     2
# 467    0.50                8             RMSE                     2
# ...     ...              ...              ...                   ...
# 876    0.80                8             RMSE                     2
# 792    0.80                4              MSE                     1
# 25     0.65                8              MSE                     1
# 274    0.80                6              MSE                     2
# 1161   0.50                8              MSE                     1
#
#       weight_scale use_down_scale use_upscale multi_profile  ...  \
# 663            0.1          False        True         False  ...
# 837            0.1          False        True         False  ...
# 779            0.1          False        True         False  ...
# 649            0.1          False        True         False  ...
# 467            0.1           True       False         False  ...
# ...            ...            ...         ...           ...  ...
# 876            0.1           True       False         False  ...
# 792            0.1          False        True         False  ...
# 25             0.1          False        True         False  ...
# 274            0.1           True       False         False  ...
# 1161           0.1          False        True         False  ...
#
#       user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  \
# 663   gemma_short_large_umap_single   42     0.09987        0.18422
# 837    gemma_long_large_umap_single   42     0.09898        0.18188
# 779   gemma_short_large_umap_single   42     0.09998        0.18356
# 649    gemma_long_large_umap_single   42     0.09983        0.18389
# 467   gemma_short_large_umap_single   42     0.09985        0.18454
# ...                             ...  ...         ...            ...
# 876         gemma_long_large_single   42     0.09951        0.18465
# 792         gemma_long_large_single   42     0.09851        0.18318
# 25     gemma_long_large_umap_single   42     0.09773        0.18112
# 274        gemma_short_large_single   42     0.09796        0.18210
# 1161   gemma_long_large_umap_single   42     0.09885        0.18253
#
#       val_epoch  test_NDCG@10  test_Recall@10  test_epoch  \
# 663          14       0.06111         0.11661          14
# 837          14       0.06083         0.11617          14
# 779          14       0.06072         0.11579          14
# 649          14       0.06072         0.11615          14
# 467          14       0.06072         0.11703          14
# ...         ...           ...             ...         ...
# 876          19       0.05589         0.10964          19
# 792          11       0.05586         0.10847          11
# 25           18       0.05583         0.10835          18
# 274           7       0.05579         0.10824           7
# 1161         17       0.05526         0.10697          17
#
#                                                  params  all_seeds
# 663   (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...       [42]
# 837   (exponential, 0.8, 8, MSE, 2, 0.1, False, True...       [42]
# 779   (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...       [42]
# 649   (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...       [42]
# 467   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...       [42]
# ...                                                 ...        ...
# 876   (exponential, 0.8, 8, RMSE, 2, 0.1, True, Fals...       [42]
# 792   (exponential, 0.8, 4, MSE, 1, 0.1, False, True...       [42]
# 25    (attention, 0.65, 8, MSE, 1, 0.1, False, True,...       [42]
# 274   (attention, 0.8, 6, MSE, 2, 0.1, True, False, ...       [42]
# 1161  (attention, 0.5, 8, MSE, 1, 0.1, False, True, ...       [42]
#
# [1728 rows x 22 columns]

# %%
df[PARAMS[1:]].to_json('best_kion.json', index=False, orient="records")

# %%
df_final[PARAMS[1:]].to_json('best_beauty_3seeds.json', index=False, orient="records")

# %%
results.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_ ...

# %%
results['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml']
# Out:
# {'validation_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.004162330905306972,
#    'NDCG@5': 0.0023390187078764875,
#    'Recall@10': 0.006243496357960458,
#    'NDCG@10': 0.00302255539974203,
#    'Recall@20': 0.010851791288836034,
#    'NDCG@20': 0.004198139363666408,
#    'loss_recsys': np.float64(10.347532872800473),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.004013676230117437,
#    'NDCG@5': 0.0024368647296024288,
#    'Recall@10': 0.008324661810613945,
#    'NDCG@10': 0.003826736836797046,
#    'Recall@20': 0.014122194143005798,
#    'NDCG@20': 0.0052561474396673165,
#    'loss_recsys': np.float64(10.325713298938892),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.006094841682770923,
#    'NDCG@5': 0.003388410317555781,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.004382003442624782,
#    'Recall@20': 0.015014122194143005,
#    'NDCG@20': 0.005846106928100518,
#    'loss_recsys': np.float64(10.315859370761448),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.00475694960606511,
#    'NDCG@5': 0.0024233021388104224,
#    'Recall@10': 0.008919280511372083,
#    'NDCG@10': 0.0037466937619863266,
#    'Recall@20': 0.015608740894901144,
#    'NDCG@20': 0.005444883250261604,
#    'loss_recsys': np.float64(10.304392673351147),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.005351568306823249,
#    'NDCG@5': 0.003198377698354209,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.0043943408066474685,
#    'Recall@20': 0.014568158168574402,
#    'NDCG@20': 0.005749538405717385,
#    'loss_recsys': np.float64(10.319377016138148),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.005648877657202319,
#    'NDCG@5': 0.0037872565967536566,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005442632113875368,
#    'Recall@20': 0.01605470492046975,
#    'NDCG@20': 0.006777092754637059,
#    'loss_recsys': np.float64(10.228386843646014),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.00787869778504534,
#    'NDCG@5': 0.0046932804995630795,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005588280874640481,
#    'Recall@20': 0.018433179723502304,
#    'NDCG@20': 0.0075612680348843865,
#    'loss_recsys': np.float64(10.17817313582809),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.006689460383529062,
#    'NDCG@5': 0.0041596912400265655,
#    'Recall@10': 0.01040582726326743,
#    'NDCG@10': 0.005321938281465431,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007405936319264151,
#    'loss_recsys': np.float64(10.219599264639395),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.005500222982012784,
#    'NDCG@5': 0.0031088033783253297,
#    'Recall@10': 0.011297755314404637,
#    'NDCG@10': 0.004985089569295943,
#    'Recall@20': 0.017838561022744167,
#    'NDCG@20': 0.00663930810328949,
#    'loss_recsys': np.float64(10.194536915531865),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.005202913631633715,
#    'NDCG@5': 0.003397568455595876,
#    'Recall@10': 0.009959863237698825,
#    'NDCG@10': 0.004914059980283862,
#    'Recall@20': 0.018135870373123236,
#    'NDCG@20': 0.006973698958964976,
#    'loss_recsys': np.float64(10.167172855801052),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.0068381150587185965,
#    'NDCG@5': 0.003916981294850848,
#    'Recall@10': 0.011446409989594173,
#    'NDCG@10': 0.005379105533092607,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007205976983741362,
#    'loss_recsys': np.float64(10.186000929938423),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.009216589861751152,
#    'NDCG@5': 0.00536698016561086,
#    'Recall@10': 0.01664932362122789,
#    'NDCG@10': 0.007717170610955234,
#    'Recall@20': 0.025271294782220902,
#    'NDCG@20': 0.009880426186269118,
#    'loss_recsys': np.float64(10.067615509033203),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.010703136613646498,
#    'NDCG@5': 0.0061917896653171526,
#    'Recall@10': 0.015608740894901144,
#    'NDCG@10': 0.007797456503587827,
#    'Recall@20': 0.026163222833358108,
#    'NDCG@20': 0.010465141389670158,
#    'loss_recsys': np.float64(10.02229372660319),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.015311431544522075,
#    'NDCG@5': 0.008807618966761114,
#    'Recall@10': 0.02556860413259997,
#    'NDCG@10': 0.012092302117390957,
#    'Recall@20': 0.037460978147762745,
#    'NDCG@20': 0.01509402483874486,
#    'loss_recsys': np.float64(10.043341000874838),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.02333878400475695,
#    'NDCG@5': 0.013452293225307246,
#    'Recall@10': 0.03478519399435112,
#    'NDCG@10': 0.01718388295588317,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.020940635823487562,
#    'loss_recsys': np.float64(10.394192024513528),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.02556860413259997,
#    'NDCG@5': 0.01467175621573135,
#    'Recall@10': 0.03612308607105694,
#    'NDCG@10': 0.01808131911592638,
#    'Recall@20': 0.052623755017095285,
#    'NDCG@20': 0.02219570412294851,
#    'loss_recsys': np.float64(10.669138625816062),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.027649769585253458,
#    'NDCG@5': 0.01608440494827978,
#    'Recall@10': 0.040285416976363904,
#    'NDCG@10': 0.020169707389790147,
#    'Recall@20': 0.055299539170506916,
#    'NDCG@20': 0.023953926373648043,
#    'loss_recsys': np.float64(10.90925513373481),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.029136316337148804,
#    'NDCG@5': 0.0168769101747808,
#    'Recall@10': 0.040731381001932514,
#    'NDCG@10': 0.020608016688631957,
#    'Recall@20': 0.05589415787126505,
#    'NDCG@20': 0.024402803415633317,
#    'loss_recsys': np.float64(11.069474714773673),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.027352460234874386,
#    'NDCG@5': 0.01618542386958481,
#    'Recall@10': 0.03969079827560577,
#    'NDCG@10': 0.02020389827803692,
#    'Recall@20': 0.05752935929834993,
#    'NDCG@20': 0.024705387746063227,
#    'loss_recsys': np.float64(11.168465543676305),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.026906496209305783,
#    'NDCG@5': 0.01646556425576616,
#    'Recall@10': 0.039244834250037164,
#    'NDCG@10': 0.020470205593094953,
#    'Recall@20': 0.05604281254645459,
#    'NDCG@20': 0.024679021484805407,
#    'loss_recsys': np.float64(11.262380140799063),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.02720380555968485,
#    'NDCG@5': 0.016519092779838616,
#    'Recall@10': 0.03954214360041623,
#    'NDCG@10': 0.020518979186977693,
#    'Recall@20': 0.05366433774342203,
#    'NDCG@20': 0.02405135827732951,
#    'loss_recsys': np.float64(11.435306372465911),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.027947078935632527,
#    'NDCG@5': 0.01738097975330968,
#    'Recall@10': 0.038947524899658095,
#    'NDCG@10': 0.02095301327688371,
#    'Recall@20': 0.05173182696595808,
#    'NDCG@20': 0.02417196843995193,
#    'loss_recsys': np.float64(11.526062541537815),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.026014568158168574,
#    'NDCG@5': 0.016542074335477355,
#    'Recall@10': 0.03537981269510926,
#    'NDCG@10': 0.019553550820444923,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.02317558219001501,
#    'loss_recsys': np.float64(11.65649449383771),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.02423071205589416,
#    'NDCG@5': 0.015859220487606795,
#    'Recall@10': 0.03627174074624647,
#    'NDCG@10': 0.019799808429292996,
#    'Recall@20': 0.05069124423963134,
#    'NDCG@20': 0.02343532319442468,
#    'loss_recsys': np.float64(11.757749239603678),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.025717258807789505,
#    'NDCG@5': 0.01651283913883568,
#    'Recall@10': 0.03716366879738368,
#    'NDCG@10': 0.02013082716570259,
#    'Recall@20': 0.04950200683811506,
#    'NDCG@20': 0.02323738534861304,
#    'loss_recsys': np.float64(11.947628409774214),
#    'loss_guide': np.float64(0.0)}],
#  'test_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.002139927480235392,
#    'NDCG@5': 0.0013538334012237051,
#    'Recall@10': 0.003388218510372704,
#    'NDCG@10': 0.0017610431170978012,
#    'Recall@20': 0.004993164120549248,
#    'NDCG@20': 0.002165665195797907},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.001069963740117696,
#    'NDCG@5': 0.0006361886489577691,
#    'Recall@10': 0.002853236640313856,
#    'NDCG@10': 0.0012341079502590968,
#    'Recall@20': 0.005290376270581942,
#    'NDCG@20': 0.0018409968568660385},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.0015455031801700054,
#    'NDCG@5': 0.0008165547682358466,
#    'Recall@10': 0.003507103370385781,
#    'NDCG@10': 0.001439664780594028,
#    'Recall@20': 0.006954764310765024,
#    'NDCG@20': 0.002298769186171313},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.0023776972002615467,
#    'NDCG@5': 0.0014026731913448166,
#    'Recall@10': 0.004101527670451168,
#    'NDCG@10': 0.0019555992269632205,
#    'Recall@20': 0.006835879450751947,
#    'NDCG@20': 0.0026387664443111684},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.0013671758901503894,
#    'NDCG@5': 0.0007172181997728328,
#    'Recall@10': 0.003150448790346549,
#    'NDCG@10': 0.0013028721633510456,
#    'Recall@20': 0.00671699459073887,
#    'NDCG@20': 0.0022039522710796317},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.0026154669202877014,
#    'NDCG@5': 0.001487013497973625,
#    'Recall@10': 0.004279854960470784,
#    'NDCG@10': 0.0020137893819131528,
#    'Recall@20': 0.007251976460797717,
#    'NDCG@20': 0.002751861097327539},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.003150448790346549,
#    'NDCG@5': 0.001966949736314488,
#    'Recall@10': 0.004577067110503478,
#    'NDCG@10': 0.0024279629756173756,
#    'Recall@20': 0.008559709920941568,
#    'NDCG@20': 0.003421836252807189},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.002318254770255008,
#    'NDCG@5': 0.001675343508882811,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.002225847738659184,
#    'Recall@20': 0.007430303750817334,
#    'NDCG@20': 0.0030913081515921655},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.0027343517803007787,
#    'NDCG@5': 0.0015257141404888019,
#    'Recall@10': 0.004636509540510016,
#    'NDCG@10': 0.002116818478138206,
#    'Recall@20': 0.008143612910895798,
#    'NDCG@20': 0.003003676133016085},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0016414278814032013,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.0020269605539885724,
#    'Recall@20': 0.00802472805088272,
#    'NDCG@20': 0.003022193540214734},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0017859868566651041,
#    'Recall@10': 0.004814836830529632,
#    'NDCG@10': 0.0024061624093819037,
#    'Recall@20': 0.00850026749093503,
#    'NDCG@20': 0.0033377840612771248},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.003744873090411936,
#    'NDCG@5': 0.0021182589243107855,
#    'Recall@10': 0.007251976460797717,
#    'NDCG@10': 0.0032274959887816537,
#    'Recall@20': 0.011412946561255424,
#    'NDCG@20': 0.004260477909596519},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.004101527670451168,
#    'NDCG@5': 0.002598666341567106,
#    'Recall@10': 0.007192534030791179,
#    'NDCG@10': 0.0035955304322993578,
#    'Recall@20': 0.01206681329132735,
#    'NDCG@20': 0.004805631612736497},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.007192534030791179,
#    'NDCG@5': 0.004284443818367116,
#    'Recall@10': 0.011175176841229269,
#    'NDCG@10': 0.005561693731332473,
#    'Recall@20': 0.01700053498187006,
#    'NDCG@20': 0.007036552276919148},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.010818522261190037,
#    'NDCG@5': 0.006017385559856399,
#    'Recall@10': 0.015752243951732747,
#    'NDCG@10': 0.007622415926753642,
#    'Recall@20': 0.021220947512334304,
#    'NDCG@20': 0.008998311353213068},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.011650716281281578,
#    'NDCG@5': 0.006517543634988249,
#    'Recall@10': 0.017119419841883136,
#    'NDCG@10': 0.008282253693749164,
#    'Recall@20': 0.02324199013255662,
#    'NDCG@20': 0.009830076487716423},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.011888486001307734,
#    'NDCG@5': 0.006735338572974523,
#    'Recall@10': 0.016703322831837366,
#    'NDCG@10': 0.008283234498932084,
#    'Recall@20': 0.025144147892765856,
#    'NDCG@20': 0.010398704256787777},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.011947928431314273,
#    'NDCG@5': 0.00666463396881279,
#    'Recall@10': 0.018129941151994292,
#    'NDCG@10': 0.008639935083638146,
#    'Recall@20': 0.02591689948285086,
#    'NDCG@20': 0.010597046951628863},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.012423467871366582,
#    'NDCG@5': 0.006813344336899553,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008713483760822175,
#    'Recall@20': 0.025798014622837782,
#    'NDCG@20': 0.01058971981780322},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.012185698151340426,
#    'NDCG@5': 0.006996251090431883,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008982034806780602,
#    'Recall@20': 0.026095226772870475,
#    'NDCG@20': 0.010960017615107813},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.012364025441360043,
#    'NDCG@5': 0.0068822554357764855,
#    'Recall@10': 0.01949711704214468,
#    'NDCG@10': 0.009193702424131632,
#    'Recall@20': 0.02668965107293586,
#    'NDCG@20': 0.01102183364428713},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.012601795161386197,
#    'NDCG@5': 0.007046747803227453,
#    'Recall@10': 0.017951613861974677,
#    'NDCG@10': 0.008761131902699917,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.01043881323043057},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.011531831421268502,
#    'NDCG@5': 0.006640128844035038,
#    'Recall@10': 0.017535516851928907,
#    'NDCG@10': 0.008585679830839013,
#    'Recall@20': 0.02532247518278547,
#    'NDCG@20': 0.01053402397710971},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.011353504131248885,
#    'NDCG@5': 0.006717526952725617,
#    'Recall@10': 0.018070498721987755,
#    'NDCG@10': 0.008847053447249018,
#    'Recall@20': 0.02550080247280509,
#    'NDCG@20': 0.01071452445750896},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007}]}

# %%
df['config_file']
# Out:
# 426    mean-0.7-12-MSE-1-0.1-True-False-False-mean-Tr...
# 11     attention-0.7-12-MSE-2-0.1-True-False-False-me...
# 88     mean-0.7-6-RMSE-1-0.1-True-False-False-mean-Tr...
# 283    mean-0.5-6-MSE-1-0.1-True-False-False-mean-Tru...
# 373    attention-0.5-12-MSE-1-0.1-True-False-False-me...
#                              ...
# 73     mean-0.7-6-MSE-2-0.1-True-False-False-mean-Tru...
# 257    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 234    mean-0.6-6-MSE-2-0.1-True-False-False-mean-Tru...
# 259    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 2      attention-0.7-12-MSE-2-0.1-False-False-False-m...
# Name: config_file, Length: 558, dtype: object

# %%
PARAMS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PARAMS
#
# NameError: name 'PARAMS' is not defined

# %%
df_final.to_csv('beauty_llm_runs.csv')

# %%
import numpy as np
np.corrcoef(df_final['test_NDCG@10'].values, df_final['val_NDCG@10'].values)
# Out:
# array([[ 1.        , -0.11176954],
#        [-0.11176954,  1.        ]])
