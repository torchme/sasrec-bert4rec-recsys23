# %%
# %cd ../../../
# Out:
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23
# /Users/nseverin/MyData/Projects/Science/LLM/sasrec-bert4rec-recsys23/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from collections import defaultdict
import re
import numpy as np
import pandas as pd

def open_text(filename): 
    with open(filename) as f:
        return f.read()


def parse_file_llm(log_data):
    # Regex patterns
    config_pattern = re.compile(r"experiments(.+?\.yaml)")
    epoch_pattern = re.compile(r"Epoch: (\d+)/\d+ \| Train Total Loss: ([\d.]+)")
    metrics_pattern = re.compile(r"(Validation|Test) Metrics: ({.+?})")
    
    # Parse the log
    results = defaultdict(lambda: {"validation_metrics": [], "test_metrics": []})
    current_config = None
        
    for line in log_data.splitlines():
        config_match = config_pattern.search(line)
        if config_match:
            current_config = config_match.group(1)
        
        epoch_match = epoch_pattern.search(line)
        if epoch_match:
            print(epoch_match)
            epoch_num = int(epoch_match.group(1))
            loss = float(epoch_match.group(2))
        
        metrics_match = metrics_pattern.search(line)
        if metrics_match and current_config:
            metric_type = metrics_match.group(1).lower()  # "validation" or "test"
            metrics = eval(metrics_match.group(2))  # Convert string to dict
            results[current_config][f"{metric_type}_metrics"].append({"epoch": epoch_num, "loss": loss, **metrics})
    return results


def find_max(results, config, metric='NDCG@10'):
    def get_dct_epoch(lst, epoch):
        for x in lst:
            if x['epoch'] == epoch:
                return x
        return lst[-1]
        # raise Exception()
    
    def postprocess(lst):
        res = []
        for dct in lst:
            res.append({
                'NDCG@10': round(dct['NDCG@10'], 5),
                'Recall@10': round(dct['Recall@10'], 5),
                'epoch': dct['epoch']
            })
        return res
    
    best_val_dct = None
    for dct in results[config]['validation_metrics']:
        if best_val_dct is None:
            best_val_dct = dct
        elif dct[metric] > best_val_dct[metric]:
            best_val_dct = dct
    
    best_val_epoch = best_val_dct['epoch']
    
    return {
        'test': postprocess([get_dct_epoch(results[config]['test_metrics'], best_val_epoch)]),
        'validation': postprocess([best_val_dct]),
    }


PARAMS = ["config_file", "weighting_scheme", "alpha", "fine_tune_epoch", 'reconstruct_loss', "reconstruction_layer", 'weight_scale', 'use_down_scale','use_upscale','multi_profile','multi_profile_aggr_scheme','scale_guide_loss','user_profile_embeddings_files']


def create_dataframe(exp_data_with_max_val):
    # List to store extracted experiment data
    data = []
    
    # Parse experiment results
    for config_path, metrics in exp_data_with_max_val.items():
        # Extract config details from the filename
        config_file = config_path.split("/")[-1]  # Get only the filename
        config_name = config_file.replace(".yaml", "").replace('--1', '-4').lstrip('sasrec-').split("-")
        
        
        # {weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml
        weighting_scheme = (config_name[0])
        alpha = float(config_name[1])
        fine_tune_epoch = int(float(config_name[2]))
        reconstruct_loss = (config_name[3])
        reconstruction_layer = int(config_name[4])
        weight_scale = float(config_name[5])
        use_down_scale = (config_name[6])
        use_upscale = (config_name[7])
        multi_profile = (config_name[8])
        multi_profile_aggr_scheme = (config_name[9])
        scale_guide_loss = (config_name[10])
        user_profile_embeddings_files = (config_name[11])
        seed = int(config_name[12])
        
        # Extract validation and test metrics
        val_metrics = metrics.get("validation", [{}])[0]
        test_metrics = metrics.get("test", [{}])[0]
    
        # Append extracted values to data list
        data.append([
            config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale,use_upscale,multi_profile,multi_profile_aggr_scheme,scale_guide_loss,user_profile_embeddings_files,seed,
            val_metrics.get("NDCG@10", None), val_metrics.get("Recall@10", None), val_metrics.get("epoch", None),
            test_metrics.get("NDCG@10", None), test_metrics.get("Recall@10", None), test_metrics.get("epoch", None)
        ])
    
    # Create DataFrame
    columns = PARAMS + ['seed',
        "val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10", "test_epoch"
        ]
    
    df = pd.DataFrame(data, columns=columns)
    return df


def apply_seed_info(df):
    df['params'] = df.apply(lambda row: tuple([row[param] for param in PARAMS[1:]]), axis=1)
    params2seeds = {}
    for params, seed in zip(df['params'], df['seed']):
        if params not in params2seeds:
            params2seeds[params] = []
        params2seeds[params].append(seed)
    df['all_seeds'] = df.apply(lambda row: (params2seeds[row['params']]), axis=1)
    return df

# %%
len('{weighting_scheme}-{alpha}-{fine_tune_epoch}-{reconstruct_loss}-{reconstruction_layer}-{weight_scale}-{use_down_scale}-{use_upscale}-{multi_profile}-{multi_profile_aggr_scheme}-{scale_guide_loss}-{user_profile_embeddings_files}-{seed}.yaml'.split('-'))
# Out:
# 13

# %%
MODEL_NAME = 'sasrec'
DATASET = 'beauty'
EXPERIMENT_NAME = 'BEAUTY_history_80_20'
SEED_FOLDER = 'other_seed'
SPLIT_NAME = 'history_80_20'
MODE = 'LLM'


local_directory = f"experiments-2_0/results/{MODEL_NAME}/{DATASET}/{EXPERIMENT_NAME}" 

seed_folders = ['other_seed']

# %%
import os


results = {}
for seed_folder in seed_folders:
    cur_folder = os.path.join(local_directory, seed_folder)
    for file in os.listdir(cur_folder):
        log_data = open_text(f'{cur_folder}/{file}')
        cur_results = parse_file_llm(log_data)
        # if cur_results['simple']['validation_metrics'] == []:
        #     continue
        results.update(cur_results)
    
    
exp_data_with_max_val = {}
for config in results:
    exp_data_with_max_val[config] = find_max(results, config, metric='NDCG@10')
exp_data_with_max_val.keys()
# Out:
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7789'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6695'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4863'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3731'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.3016'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.2300'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.1603'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.1176'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.0918'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.0597'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.0239'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0584'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8304'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.5530'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.1413'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.8456'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.6135'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.4026'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.2185'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.0648'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.9396'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.8329'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.7363'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.6518'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.5860'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.5180'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.4558'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.3992'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.3526'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.3060'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7806'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6702'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4917'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4013'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.3362'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.2792'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.2369'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.2045'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.1732'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.1409'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.1133'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0839'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8358'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7319'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6870'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.5970'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.3594'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.1277'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.9668'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.8164'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.6669'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.5217'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.3722'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.2262'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.0998'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.9888'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.8874'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.8012'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.7169'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.6479'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7773'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6748'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4878'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3661'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.2895'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.2130'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.1425'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.0666'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.0077'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.9643'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.9369'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 8.9955'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8320'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.6859'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.3718'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.0745'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.8459'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.6508'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.4566'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.2766'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.1251'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.9960'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.8823'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.7837'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.6957'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.6168'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.5477'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.4889'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.4285'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.3748'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7676'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.5478'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.3107'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.1538'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.0268'>
# <re.Match object; span=(0, 38), match='Epoch: 6/30 | Train Total Loss: 9.9162'>
# <re.Match object; span=(0, 38), match='Epoch: 7/30 | Train Total Loss: 9.8189'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.7439'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.6780'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.6182'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.5702'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.2261'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8748'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.5732'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.1250'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.7845'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.5155'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.2886'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.1111'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.9686'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.8558'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.7555'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.6663'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.5881'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.5224'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.4630'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.4080'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.3564'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.3105'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.2694'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7702'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.5443'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.2834'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.1353'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.0143'>
# <re.Match object; span=(0, 38), match='Epoch: 6/30 | Train Total Loss: 9.9074'>
# <re.Match object; span=(0, 38), match='Epoch: 7/30 | Train Total Loss: 9.8136'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.7290'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.6640'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.6140'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.5725'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.1414'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8465'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.4592'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 6.9727'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.6554'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.4064'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.2037'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.0468'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.9150'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.8013'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.7089'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.6226'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.5458'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.4810'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.4207'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.3725'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.3189'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.2698'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.2344'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7642'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.5466'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.3118'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.1515'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.0258'>
# <re.Match object; span=(0, 38), match='Epoch: 6/30 | Train Total Loss: 9.9153'>
# <re.Match object; span=(0, 38), match='Epoch: 7/30 | Train Total Loss: 9.8280'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.7527'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.6942'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.6403'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.5860'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.2264'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.7849'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.2407'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 6.8005'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.4852'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.2413'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.0645'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 5.9193'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.8059'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.7079'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.6259'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.5533'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.4828'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.4234'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.3701'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.3183'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.2818'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.2360'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.1955'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7829'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7038'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5537'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4669'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4180'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.3697'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3283'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.3042'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.2750'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.2488'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2242'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0778'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8303'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7236'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6424'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.5394'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.3491'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.1107'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.9106'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.7290'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.5570'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.3875'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.2367'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.1080'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.9973'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.9013'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.8105'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.7273'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.6531'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.5889'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7841'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7066'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5689'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5008'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4534'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.4106'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3698'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.3351'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.3048'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.2759'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2521'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0944'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8283'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7180'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6766'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6408'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.5696'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.4110'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.2117'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.0610'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.9360'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.8031'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.6586'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.5131'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.3680'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.2393'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.1228'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.0197'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.9253'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.8434'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7820'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6848'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5228'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4425'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.3846'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.3336'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.2916'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.2580'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.2270'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.1970'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.1716'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.1044'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8331'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7233'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6817'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6388'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.4573'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.1847'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.0023'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.8562'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.7077'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.5406'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.3790'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.2289'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.0999'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.9907'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.8901'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.8046'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.7206'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.6522'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7789'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6882'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5150'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4023'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.3408'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.2773'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.2140'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.1581'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.1315'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.1052'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.0733'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 8.9987'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8255'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7149'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.4898'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.2288'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.0326'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.8615'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.6913'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.5254'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.3659'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.2227'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.0920'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.9779'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.8755'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.7846'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.7034'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.6340'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.5623'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.5007'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7883'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7434'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6483'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5878'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5549'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5259'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.4993'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4712'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4413'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.4153'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.3917'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0452'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8237'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7185'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6789'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6493'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.5965'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.5085'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.4550'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.3200'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.1965'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.0993'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 7.0074'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.9201'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.8356'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.7368'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.6259'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.5139'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.4023'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 6.2935'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7891'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7475'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6557'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5996'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5677'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5401'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.5097'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4806'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4521'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.4242'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.4007'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0439'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8280'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7230'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6834'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6535'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.6338'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.5923'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.5195'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.4673'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.4385'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.4227'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 7.4095'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 7.3796'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 7.2982'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 7.2082'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 7.1485'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 7.1003'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 7.0596'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 7.0155'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7866'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7452'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6619'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.6007'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5707'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5414'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.5174'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4912'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4621'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.4333'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.4073'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0353'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8261'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7241'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6830'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6359'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.5593'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.4921'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.4627'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.4400'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.3678'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.2678'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 7.2039'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 7.1357'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 7.0700'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 7.0164'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.9702'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.9281'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.8695'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 6.7994'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7837'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7110'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5702'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4884'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4436'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.3989'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3609'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.3334'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.3038'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.2788'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2554'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0896'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8330'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7232'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6813'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6203'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.4282'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.2338'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.0986'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.9611'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.8301'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.6927'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.5497'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.4066'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.2767'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.1555'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.0455'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.9441'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.8578'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.7767'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7849'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7138'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5833'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5188'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4750'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.4365'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3971'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.3623'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.3308'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.3025'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2803'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0891'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8291'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7180'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6770'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6450'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.6092'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.5184'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.2988'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.1082'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.9671'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.8362'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.7030'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.5593'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.4296'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.2974'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.1738'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.0629'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.9635'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.8795'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7822'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7143'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5791'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4940'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4541'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.4118'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3729'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.3417'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.3125'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.2837'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2575'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0487'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8244'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7071'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.5752'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.3668'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.2322'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.1431'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.0761'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.0179'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.9433'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.8602'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.7559'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.6336'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.5045'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.3836'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.2609'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.1532'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.0489'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.9533'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7814'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.7077'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5598'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4674'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.4238'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.3778'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.3334'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.2988'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.2724'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.2425'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.2150'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0382'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8208'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.6805'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.4351'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.1932'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.0026'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.8279'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.6590'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.5046'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.3465'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.2013'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.0763'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.9592'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.8574'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.7688'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.6870'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.6201'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.5521'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.4900'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7758'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6396'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4370'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3061'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.2149'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.1227'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.0331'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.9571'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.9029'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.8766'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.8432'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0986'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.7819'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.3097'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 6.9259'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.6392'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.3972'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.2002'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.0475'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.9166'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.8146'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.7203'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.6336'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.5614'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.4984'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.4438'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.3843'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.3366'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.2929'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.2504'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7779'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6392'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4303'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3192'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.2385'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.1653'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.1135'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.0810'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.0441'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.0091'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.9760'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0700'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8288'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.6344'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.3384'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.0865'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.8585'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.6557'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.4557'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.2803'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.1236'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.9944'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.8786'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.7834'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.6979'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.6254'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.5549'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.4930'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.4375'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.3880'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7740'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6452'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4405'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3032'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.2054'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.1085'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.0200'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.9368'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.8615'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.7933'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.7365'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.1096'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.7696'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.2672'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 6.8656'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.5639'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.3145'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.1285'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 5.9779'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.8579'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.7569'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.6681'>
# ...
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.4497'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.3195'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.2184'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.1315'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.0549'>
# <re.Match object; span=(0, 38), match='Epoch: 8/30 | Train Total Loss: 9.9708'>
# <re.Match object; span=(0, 38), match='Epoch: 9/30 | Train Total Loss: 9.8943'>
# <re.Match object; span=(0, 39), match='Epoch: 10/30 | Train Total Loss: 9.8286'>
# <re.Match object; span=(0, 39), match='Epoch: 11/30 | Train Total Loss: 9.7607'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 8.9805'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.7214'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.3104'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 6.9743'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 6.6685'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 6.4031'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 6.2026'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.0420'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 5.9139'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 5.8074'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 5.7138'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 5.6326'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 5.5501'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 5.4864'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 5.4257'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.3677'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.3245'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.2776'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.2315'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7823'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6788'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6100'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5622'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5323'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5067'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.4800'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4519'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4166'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.3852'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.3459'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 8.9571'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8162'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7212'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6820'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6552'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.6376'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.6174'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.5887'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.5210'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.4630'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.4350'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 7.4172'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 7.3976'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 7.3240'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 7.2242'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 7.1284'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 7.0222'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.9252'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 6.8420'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7821'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6856'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6183'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5655'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5364'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5133'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.4881'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4608'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4313'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.3980'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.3652'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0194'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8217'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7239'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6865'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6610'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.6419'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.6217'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.5893'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.5185'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.3958'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.2429'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 7.1443'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 7.0560'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.9663'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.8659'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.7588'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.6399'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.5189'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 6.4023'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7801'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6804'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.6152'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.5683'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.5445'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.5190'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.4977'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.4688'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.4401'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.4084'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.3762'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 9.0048'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.8191'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.7267'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.6868'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.6581'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.6371'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.6211'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 7.6064'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 7.5543'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 7.3397'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 7.1175'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.9754'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.8403'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.6931'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.5431'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 6.3881'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 6.2519'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 6.1270'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 6.0230'>
# <re.Match object; span=(0, 39), match='Epoch: 1/30 | Train Total Loss: 10.7764'>
# <re.Match object; span=(0, 39), match='Epoch: 2/30 | Train Total Loss: 10.6407'>
# <re.Match object; span=(0, 39), match='Epoch: 3/30 | Train Total Loss: 10.5278'>
# <re.Match object; span=(0, 39), match='Epoch: 4/30 | Train Total Loss: 10.4430'>
# <re.Match object; span=(0, 39), match='Epoch: 5/30 | Train Total Loss: 10.3794'>
# <re.Match object; span=(0, 39), match='Epoch: 6/30 | Train Total Loss: 10.3207'>
# <re.Match object; span=(0, 39), match='Epoch: 7/30 | Train Total Loss: 10.2629'>
# <re.Match object; span=(0, 39), match='Epoch: 8/30 | Train Total Loss: 10.2111'>
# <re.Match object; span=(0, 39), match='Epoch: 9/30 | Train Total Loss: 10.1577'>
# <re.Match object; span=(0, 40), match='Epoch: 10/30 | Train Total Loss: 10.1108'>
# <re.Match object; span=(0, 40), match='Epoch: 11/30 | Train Total Loss: 10.0536'>
# <re.Match object; span=(0, 39), match='Epoch: 12/30 | Train Total Loss: 8.9784'>
# <re.Match object; span=(0, 39), match='Epoch: 13/30 | Train Total Loss: 7.7945'>
# <re.Match object; span=(0, 39), match='Epoch: 14/30 | Train Total Loss: 7.6293'>
# <re.Match object; span=(0, 39), match='Epoch: 15/30 | Train Total Loss: 7.4125'>
# <re.Match object; span=(0, 39), match='Epoch: 16/30 | Train Total Loss: 7.2584'>
# <re.Match object; span=(0, 39), match='Epoch: 17/30 | Train Total Loss: 7.1508'>
# <re.Match object; span=(0, 39), match='Epoch: 18/30 | Train Total Loss: 7.0354'>
# <re.Match object; span=(0, 39), match='Epoch: 19/30 | Train Total Loss: 6.9275'>
# <re.Match object; span=(0, 39), match='Epoch: 20/30 | Train Total Loss: 6.8104'>
# <re.Match object; span=(0, 39), match='Epoch: 21/30 | Train Total Loss: 6.6960'>
# <re.Match object; span=(0, 39), match='Epoch: 22/30 | Train Total Loss: 6.5845'>
# <re.Match object; span=(0, 39), match='Epoch: 23/30 | Train Total Loss: 6.4550'>
# <re.Match object; span=(0, 39), match='Epoch: 24/30 | Train Total Loss: 6.3266'>
# <re.Match object; span=(0, 39), match='Epoch: 25/30 | Train Total Loss: 6.2094'>
# <re.Match object; span=(0, 39), match='Epoch: 26/30 | Train Total Loss: 6.1001'>
# <re.Match object; span=(0, 39), match='Epoch: 27/30 | Train Total Loss: 5.9967'>
# <re.Match object; span=(0, 39), match='Epoch: 28/30 | Train Total Loss: 5.9013'>
# <re.Match object; span=(0, 39), match='Epoch: 29/30 | Train Total Loss: 5.8205'>
# <re.Match object; span=(0, 39), match='Epoch: 30/30 | Train Total Loss: 5.7456'>
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.3-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.6-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.4-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-MSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/exponential-0.5-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-1.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/mean-0.5-12-RMSE-3-0.1-True-False-False-mean-True-gemma_short_large_umap_single-256.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_history_80_20/other_seed/mean-0.5-12-RMSE-3-0.1 ...

# %%
df = create_dataframe(exp_data_with_max_val)
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'ttention' else 'attention')
df['weighting_scheme'] = df['weighting_scheme'].apply(lambda x: x if x != 'xponential' else 'exponential')
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 0   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 1   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 2   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 3   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 4   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 5   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 6   exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 7   exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 8   exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 9   exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 10  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
# 11  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
# 12  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
# 13  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 14  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 15  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 16  exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 17  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 18  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 19  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 20  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 21  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 22  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 23  exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 24  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
# 25  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
# 26  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 27  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 28  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 29  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 30  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 31  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 32  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 33  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 34  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 35  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 36  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 37  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 38  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 39  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 40  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 41  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 42  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 43  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 44  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 45  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 46  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 47  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 0                12              MSE                     3           0.1
# 1                12              MSE                     3           0.1
# 2                12              MSE                     3           0.1
# 3                12             RMSE                     3           0.1
# 4                12             RMSE                     3           0.1
# 5                12             RMSE                     3           0.1
# 6                12              MSE                     3           0.1
# 7                12              MSE                     3           0.1
# 8                12             RMSE                     3           0.1
# 9                12             RMSE                     3           0.1
# 10               12              MSE                     3           0.1
# 11               12              MSE                     3           0.1
# 12               12              MSE                     3           0.1
# 13               12             RMSE                     3           0.1
# 14               12             RMSE                     3           0.1
# 15               12             RMSE                     3           0.1
# 16               12              MSE                     3           0.1
# 17               12             RMSE                     3           0.1
# 18               12             RMSE                     3           0.1
# 19               12             RMSE                     3           0.1
# 20               12              MSE                     3           0.1
# 21               12              MSE                     3           0.1
# 22               12              MSE                     3           0.1
# 23               12             RMSE                     3           0.1
# 24               12             RMSE                     3           0.1
# 25               12             RMSE                     3           0.1
# 26               12              MSE                     3           0.1
# 27               12              MSE                     3           0.1
# 28               12              MSE                     3           0.1
# 29               12             RMSE                     3           0.1
# 30               12             RMSE                     3           0.1
# 31               12             RMSE                     3           0.1
# 32               12              MSE                     3           0.1
# 33               12              MSE                     3           0.1
# 34               12              MSE                     3           0.1
# 35               12             RMSE                     3           0.1
# 36               12             RMSE                     3           0.1
# 37               12             RMSE                     3           0.1
# 38               12              MSE                     3           0.1
# 39               12              MSE                     3           0.1
# 40               12              MSE                     3           0.1
# 41               12             RMSE                     3           0.1
# 42               12             RMSE                     3           0.1
# 43               12             RMSE                     3           0.1
# 44               12              MSE                     3           0.1
# 45               12              MSE                     3           0.1
# 46               12              MSE                     3           0.1
# 47               12             RMSE                     3           0.1
#
#    use_down_scale use_upscale multi_profile multi_profile_aggr_scheme  \
# 0            True       False         False                      mean
# 1            True       False         False                      mean
# 2            True       False         False                      mean
# 3            True       False         False                      mean
# 4            True       False         False                      mean
# 5            True       False         False                      mean
# 6            True       False         False                      mean
# 7            True       False         False                      mean
# 8            True       False         False                      mean
# 9            True       False         False                      mean
# 10           True       False         False                      mean
# 11           True       False         False                      mean
# 12           True       False         False                      mean
# 13           True       False         False                      mean
# 14           True       False         False                      mean
# 15           True       False         False                      mean
# 16           True       False         False                      mean
# 17           True       False         False                      mean
# 18           True       False         False                      mean
# 19           True       False         False                      mean
# 20           True       False         False                      mean
# 21           True       False         False                      mean
# 22           True       False         False                      mean
# 23           True       False         False                      mean
# 24           True       False         False                      mean
# 25           True       False         False                      mean
# 26           True       False         False                      mean
# 27           True       False         False                      mean
# 28           True       False         False                      mean
# 29           True       False         False                      mean
# 30           True       False         False                      mean
# 31           True       False         False                      mean
# 32           True       False         False                      mean
# 33           True       False         False                      mean
# 34           True       False         False                      mean
# 35           True       False         False                      mean
# 36           True       False         False                      mean
# 37           True       False         False                      mean
# 38           True       False         False                      mean
# 39           True       False         False                      mean
# 40           True       False         False                      mean
# 41           True       False         False                      mean
# 42           True       False         False                      mean
# 43           True       False         False                      mean
# 44           True       False         False                      mean
# 45           True       False         False                      mean
# 46           True       False         False                      mean
# 47           True       False         False                      mean
#
#    scale_guide_loss  user_profile_embeddings_files  seed  val_NDCG@10  \
# 0              True  gemma_short_large_umap_single     1      0.05008
# 1              True  gemma_short_large_umap_single   256      0.04334
# 2              True  gemma_short_large_umap_single    42      0.04461
# 3              True  gemma_short_large_umap_single     1      0.04880
# 4              True  gemma_short_large_umap_single   256      0.05031
# 5              True  gemma_short_large_umap_single    42      0.04922
# 6              True  gemma_short_large_umap_single     1      0.04165
# 7              True  gemma_short_large_umap_single   256      0.03473
# 8              True  gemma_short_large_umap_single   256      0.04090
# 9              True  gemma_short_large_umap_single    42      0.04258
# 10             True  gemma_short_large_umap_single     1      0.02682
# 11             True  gemma_short_large_umap_single   256      0.00789
# 12             True  gemma_short_large_umap_single    42      0.01211
# 13             True  gemma_short_large_umap_single     1      0.03925
# 14             True  gemma_short_large_umap_single   256      0.04062
# 15             True  gemma_short_large_umap_single    42      0.03576
# 16             True  gemma_short_large_umap_single    42      0.04301
# 17             True  gemma_short_large_umap_single     1      0.04567
# 18             True  gemma_short_large_umap_single   256      0.04332
# 19             True  gemma_short_large_umap_single    42      0.04908
# 20             True  gemma_short_large_umap_single     1      0.03580
# 21             True  gemma_short_large_umap_single   256      0.01768
# 22             True  gemma_short_large_umap_single    42      0.03600
# 23             True  gemma_short_large_umap_single     1      0.04520
# 24             True  gemma_short_large_umap_single   256      0.04860
# 25             True  gemma_short_large_umap_single    42      0.04579
# 26             True  gemma_short_large_umap_single     1      0.02830
# 27             True  gemma_short_large_umap_single   256      0.03823
# 28             True  gemma_short_large_umap_single    42      0.03283
# 29             True  gemma_short_large_umap_single     1      0.02930
# 30             True  gemma_short_large_umap_single   256      0.03203
# 31             True  gemma_short_large_umap_single    42      0.04067
# 32             True  gemma_short_large_umap_single     1      0.04821
# 33             True  gemma_short_large_umap_single   256      0.04568
# 34             True  gemma_short_large_umap_single    42      0.04748
# 35             True  gemma_short_large_umap_single     1      0.04691
# 36             True  gemma_short_large_umap_single   256      0.05154
# 37             True  gemma_short_large_umap_single    42      0.04866
# 38             True  gemma_short_large_umap_single     1      0.04194
# 39             True  gemma_short_large_umap_single   256      0.04749
# 40             True  gemma_short_large_umap_single    42      0.04429
# 41             True  gemma_short_large_umap_single     1      0.04932
# 42             True  gemma_short_large_umap_single   256      0.04919
# 43             True  gemma_short_large_umap_single    42      0.04803
# 44             True  gemma_short_large_umap_single     1      0.00948
# 45             True  gemma_short_large_umap_single   256      0.02389
# 46             True  gemma_short_large_umap_single    42      0.03179
# 47             True  gemma_short_large_umap_single     1      0.03662
#
#     val_Recall@10  val_epoch  test_NDCG@10  test_Recall@10  test_epoch
# 0         0.10017         28       0.01898         0.04083          28
# 1         0.08624         30       0.01499         0.03305          30
# 2         0.09146         29       0.01652         0.03532          29
# 3         0.09408         28       0.01814         0.03889          28
# 4         0.09843         28       0.01943         0.04083          28
# 5         0.09843         30       0.02128         0.04472          30
# 6         0.08537         30       0.01556         0.03208          30
# 7         0.06882         30       0.01213         0.02787          30
# 8         0.08101         29       0.01260         0.02754          29
# 9         0.08449         30       0.01560         0.03338          30
# 10        0.06185         30       0.00828         0.01750          30
# 11        0.01655         29       0.00368         0.00810          29
# 12        0.02962         30       0.00390         0.00843          30
# 13        0.08014         30       0.01243         0.02787          30
# 14        0.08275         30       0.01136         0.02463          30
# 15        0.07230         30       0.01080         0.02528          30
# 16        0.08449         29       0.01743         0.03856          29
# 17        0.09669         30       0.01913         0.03986          30
# 18        0.08711         28       0.01676         0.03435          28
# 19        0.09843         30       0.01974         0.04115          30
# 20        0.07578         30       0.01178         0.02560          30
# 21        0.04007         30       0.00524         0.01102          30
# 22        0.07056         29       0.01123         0.02592          29
# 23        0.09146         30       0.01765         0.03759          30
# 24        0.09843         30       0.01703         0.03597          30
# 25        0.09321         30       0.01972         0.04277          30
# 26        0.05923         30       0.00841         0.01815          30
# 27        0.07753         30       0.00956         0.02041          30
# 28        0.06620         30       0.00900         0.02041          30
# 29        0.05836         30       0.00810         0.01847          30
# 30        0.06359         30       0.00905         0.02041          30
# 31        0.08014         30       0.01843         0.04213          30
# 32        0.09582         30       0.01965         0.04083          30
# 33        0.09582         30       0.01712         0.03629          30
# 34        0.09408         29       0.02006         0.04472          29
# 35        0.09495         29       0.02206         0.04634          29
# 36        0.10105         30       0.01940         0.04115          30
# 37        0.10017         30       0.01977         0.04180          30
# 38        0.08101         30       0.01032         0.02236          30
# 39        0.09146         30       0.01541         0.03402          30
# 40        0.08972         30       0.01940         0.04083          30
# 41        0.09669         30       0.02121         0.04472          30
# 42        0.10017         29       0.01907         0.03986          29
# 43        0.09843         30       0.02019         0.04407          30
# 44        0.02178         30       0.00431         0.00810          30
# 45        0.05052         30       0.00593         0.01361          30
# 46        0.06359         30       0.00966         0.02236          30
# 47        0.07056         30       0.01043         0.02366          30

# %%
df['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# exponential    24
# mean           24
# Name: count, dtype: int64

# %%
df = apply_seed_info(df)
df.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df
# Out:
#                                           config_file weighting_scheme  alpha  \
# 36  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 4   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 0   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 41  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 5   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 42  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 19  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 3   exponential-0.3-12-RMSE-3-0.1-True-False-False...      exponential    0.3
# 37  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 24  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
# 32  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 43  mean-0.4-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.4
# 39  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 34  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 35  mean-0.3-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.3
# 25  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
# 33  mean-0.3-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.3
# 17  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 23  exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 2   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 40  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 1   exponential-0.3-12-MSE-3-0.1-True-False-False-...      exponential    0.3
# 18  exponential-0.4-12-RMSE-3-0.1-True-False-False...      exponential    0.4
# 16  exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 9   exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 38  mean-0.4-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.4
# 6   exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 8   exponential-0.5-12-RMSE-3-0.1-True-False-False...      exponential    0.5
# 31  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 14  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 13  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 27  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 47  mean-0.5-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.5
# 22  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 20  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 15  exponential-0.6-12-RMSE-3-0.1-True-False-False...      exponential    0.6
# 7   exponential-0.4-12-MSE-3-0.1-True-False-False-...      exponential    0.4
# 28  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 30  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 46  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 29  mean-0.6-12-RMSE-3-0.1-True-False-False-mean-T...             mean    0.6
# 26  mean-0.6-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.6
# 10  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
# 45  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 21  exponential-0.5-12-MSE-3-0.1-True-False-False-...      exponential    0.5
# 12  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
# 44  mean-0.5-12-MSE-3-0.1-True-False-False-mean-Tr...             mean    0.5
# 11  exponential-0.6-12-MSE-3-0.1-True-False-False-...      exponential    0.6
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 36               12             RMSE                     3           0.1
# 4                12             RMSE                     3           0.1
# 0                12              MSE                     3           0.1
# 41               12             RMSE                     3           0.1
# 5                12             RMSE                     3           0.1
# 42               12             RMSE                     3           0.1
# 19               12             RMSE                     3           0.1
# 3                12             RMSE                     3           0.1
# 37               12             RMSE                     3           0.1
# 24               12             RMSE                     3           0.1
# 32               12              MSE                     3           0.1
# 43               12             RMSE                     3           0.1
# 39               12              MSE                     3           0.1
# 34               12              MSE                     3           0.1
# 35               12             RMSE                     3           0.1
# 25               12             RMSE                     3           0.1
# 33               12              MSE                     3           0.1
# 17               12             RMSE                     3           0.1
# 23               12             RMSE                     3           0.1
# 2                12              MSE                     3           0.1
# 40               12              MSE                     3           0.1
# 1                12              MSE                     3           0.1
# 18               12             RMSE                     3           0.1
# 16               12              MSE                     3           0.1
# 9                12             RMSE                     3           0.1
# 38               12              MSE                     3           0.1
# 6                12              MSE                     3           0.1
# 8                12             RMSE                     3           0.1
# 31               12             RMSE                     3           0.1
# 14               12             RMSE                     3           0.1
# 13               12             RMSE                     3           0.1
# 27               12              MSE                     3           0.1
# 47               12             RMSE                     3           0.1
# 22               12              MSE                     3           0.1
# 20               12              MSE                     3           0.1
# 15               12             RMSE                     3           0.1
# 7                12              MSE                     3           0.1
# 28               12              MSE                     3           0.1
# 30               12             RMSE                     3           0.1
# 46               12              MSE                     3           0.1
# 29               12             RMSE                     3           0.1
# 26               12              MSE                     3           0.1
# 10               12              MSE                     3           0.1
# 45               12              MSE                     3           0.1
# 21               12              MSE                     3           0.1
# 12               12              MSE                     3           0.1
# 44               12              MSE                     3           0.1
# 11               12              MSE                     3           0.1
#
#    use_down_scale use_upscale multi_profile  ...  \
# 36           True       False         False  ...
# 4            True       False         False  ...
# 0            True       False         False  ...
# 41           True       False         False  ...
# 5            True       False         False  ...
# 42           True       False         False  ...
# 19           True       False         False  ...
# 3            True       False         False  ...
# 37           True       False         False  ...
# 24           True       False         False  ...
# 32           True       False         False  ...
# 43           True       False         False  ...
# 39           True       False         False  ...
# 34           True       False         False  ...
# 35           True       False         False  ...
# 25           True       False         False  ...
# 33           True       False         False  ...
# 17           True       False         False  ...
# 23           True       False         False  ...
# 2            True       False         False  ...
# 40           True       False         False  ...
# 1            True       False         False  ...
# 18           True       False         False  ...
# 16           True       False         False  ...
# 9            True       False         False  ...
# 38           True       False         False  ...
# 6            True       False         False  ...
# 8            True       False         False  ...
# 31           True       False         False  ...
# 14           True       False         False  ...
# 13           True       False         False  ...
# 27           True       False         False  ...
# 47           True       False         False  ...
# 22           True       False         False  ...
# 20           True       False         False  ...
# 15           True       False         False  ...
# 7            True       False         False  ...
# 28           True       False         False  ...
# 30           True       False         False  ...
# 46           True       False         False  ...
# 29           True       False         False  ...
# 26           True       False         False  ...
# 10           True       False         False  ...
# 45           True       False         False  ...
# 21           True       False         False  ...
# 12           True       False         False  ...
# 44           True       False         False  ...
# 11           True       False         False  ...
#
#     user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  val_epoch  \
# 36  gemma_short_large_umap_single  256     0.05154        0.10105         30
# 4   gemma_short_large_umap_single  256     0.05031        0.09843         28
# 0   gemma_short_large_umap_single    1     0.05008        0.10017         28
# 41  gemma_short_large_umap_single    1     0.04932        0.09669         30
# 5   gemma_short_large_umap_single   42     0.04922        0.09843         30
# 42  gemma_short_large_umap_single  256     0.04919        0.10017         29
# 19  gemma_short_large_umap_single   42     0.04908        0.09843         30
# 3   gemma_short_large_umap_single    1     0.04880        0.09408         28
# 37  gemma_short_large_umap_single   42     0.04866        0.10017         30
# 24  gemma_short_large_umap_single  256     0.04860        0.09843         30
# 32  gemma_short_large_umap_single    1     0.04821        0.09582         30
# 43  gemma_short_large_umap_single   42     0.04803        0.09843         30
# 39  gemma_short_large_umap_single  256     0.04749        0.09146         30
# 34  gemma_short_large_umap_single   42     0.04748        0.09408         29
# 35  gemma_short_large_umap_single    1     0.04691        0.09495         29
# 25  gemma_short_large_umap_single   42     0.04579        0.09321         30
# 33  gemma_short_large_umap_single  256     0.04568        0.09582         30
# 17  gemma_short_large_umap_single    1     0.04567        0.09669         30
# 23  gemma_short_large_umap_single    1     0.04520        0.09146         30
# 2   gemma_short_large_umap_single   42     0.04461        0.09146         29
# 40  gemma_short_large_umap_single   42     0.04429        0.08972         30
# 1   gemma_short_large_umap_single  256     0.04334        0.08624         30
# 18  gemma_short_large_umap_single  256     0.04332        0.08711         28
# 16  gemma_short_large_umap_single   42     0.04301        0.08449         29
# 9   gemma_short_large_umap_single   42     0.04258        0.08449         30
# 38  gemma_short_large_umap_single    1     0.04194        0.08101         30
# 6   gemma_short_large_umap_single    1     0.04165        0.08537         30
# 8   gemma_short_large_umap_single  256     0.04090        0.08101         29
# 31  gemma_short_large_umap_single   42     0.04067        0.08014         30
# 14  gemma_short_large_umap_single  256     0.04062        0.08275         30
# 13  gemma_short_large_umap_single    1     0.03925        0.08014         30
# 27  gemma_short_large_umap_single  256     0.03823        0.07753         30
# 47  gemma_short_large_umap_single    1     0.03662        0.07056         30
# 22  gemma_short_large_umap_single   42     0.03600        0.07056         29
# 20  gemma_short_large_umap_single    1     0.03580        0.07578         30
# 15  gemma_short_large_umap_single   42     0.03576        0.07230         30
# 7   gemma_short_large_umap_single  256     0.03473        0.06882         30
# 28  gemma_short_large_umap_single   42     0.03283        0.06620         30
# 30  gemma_short_large_umap_single  256     0.03203        0.06359         30
# 46  gemma_short_large_umap_single   42     0.03179        0.06359         30
# 29  gemma_short_large_umap_single    1     0.02930        0.05836         30
# 26  gemma_short_large_umap_single    1     0.02830        0.05923         30
# 10  gemma_short_large_umap_single    1     0.02682        0.06185         30
# 45  gemma_short_large_umap_single  256     0.02389        0.05052         30
# 21  gemma_short_large_umap_single  256     0.01768        0.04007         30
# 12  gemma_short_large_umap_single   42     0.01211        0.02962         30
# 44  gemma_short_large_umap_single    1     0.00948        0.02178         30
# 11  gemma_short_large_umap_single  256     0.00789        0.01655         29
#
#     test_NDCG@10  test_Recall@10  test_epoch  \
# 36       0.01940         0.04115          30
# 4        0.01943         0.04083          28
# 0        0.01898         0.04083          28
# 41       0.02121         0.04472          30
# 5        0.02128         0.04472          30
# 42       0.01907         0.03986          29
# 19       0.01974         0.04115          30
# 3        0.01814         0.03889          28
# 37       0.01977         0.04180          30
# 24       0.01703         0.03597          30
# 32       0.01965         0.04083          30
# 43       0.02019         0.04407          30
# 39       0.01541         0.03402          30
# 34       0.02006         0.04472          29
# 35       0.02206         0.04634          29
# 25       0.01972         0.04277          30
# 33       0.01712         0.03629          30
# 17       0.01913         0.03986          30
# 23       0.01765         0.03759          30
# 2        0.01652         0.03532          29
# 40       0.01940         0.04083          30
# 1        0.01499         0.03305          30
# 18       0.01676         0.03435          28
# 16       0.01743         0.03856          29
# 9        0.01560         0.03338          30
# 38       0.01032         0.02236          30
# 6        0.01556         0.03208          30
# 8        0.01260         0.02754          29
# 31       0.01843         0.04213          30
# 14       0.01136         0.02463          30
# 13       0.01243         0.02787          30
# 27       0.00956         0.02041          30
# 47       0.01043         0.02366          30
# 22       0.01123         0.02592          29
# 20       0.01178         0.02560          30
# 15       0.01080         0.02528          30
# 7        0.01213         0.02787          30
# 28       0.00900         0.02041          30
# 30       0.00905         0.02041          30
# 46       0.00966         0.02236          30
# 29       0.00810         0.01847          30
# 26       0.00841         0.01815          30
# 10       0.00828         0.01750          30
# 45       0.00593         0.01361          30
# 21       0.00524         0.01102          30
# 12       0.00390         0.00843          30
# 44       0.00431         0.00810          30
# 11       0.00368         0.00810          29
#
#                                                params     all_seeds
# 36  (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 4   (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 0   (exponential, 0.3, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 41  (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 5   (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 42  (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 19  (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 3   (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 37  (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 24  (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fal...  [256, 42, 1]
# 32  (mean, 0.3, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 43  (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 39  (mean, 0.4, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 34  (mean, 0.3, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 35  (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 25  (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fal...  [256, 42, 1]
# 33  (mean, 0.3, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 17  (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 23  (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fal...  [256, 42, 1]
# 2   (exponential, 0.3, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 40  (mean, 0.4, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 1   (exponential, 0.3, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 18  (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 16  (exponential, 0.4, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 9   (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fal...  [256, 42, 1]
# 38  (mean, 0.4, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 6   (exponential, 0.4, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 8   (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fal...  [256, 42, 1]
# 31  (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 14  (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 13  (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 27  (mean, 0.6, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 47  (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fal...  [256, 42, 1]
# 22  (exponential, 0.5, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 20  (exponential, 0.5, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 15  (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fal...  [1, 256, 42]
# 7   (exponential, 0.4, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 28  (mean, 0.6, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 30  (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 46  (mean, 0.5, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 29  (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fal...  [1, 256, 42]
# 26  (mean, 0.6, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 10  (exponential, 0.6, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 45  (mean, 0.5, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 21  (exponential, 0.5, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 12  (exponential, 0.6, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
# 44  (mean, 0.5, 12, MSE, 3, 0.1, True, False, Fals...  [1, 256, 42]
# 11  (exponential, 0.6, 12, MSE, 3, 0.1, True, Fals...  [1, 256, 42]
#
# [48 rows x 22 columns]

# %%
df.to_csv('ml20m_llm_all_runs.csv')

# %%
def get_stats_seeds(df_all):
    def aggregate_mean(series):
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        return series.mean()
        # print(df)
        # all_cols = set(df.columns)
        # df_mean = df.mean(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    def aggregate_std(series):
        # print(series)
        first_elem = list(series)[0]
        if isinstance(first_elem, str) or isinstance(first_elem, bool):
            return first_elem
        if len(series) == 1:
            return 0
        return series.std()
        # all_cols = set(df.columns)
        # df_mean = df.std(numeric_only=True)
        # rest_cols = all_cols - set(df_mean.columns)
        # for col in rest_cols:
        #     df_mean[col] = list(df[col])[0]
        # return df_mean
    
    
    metric_cols = ["val_NDCG@10", "val_Recall@10", "val_epoch", "test_NDCG@10", "test_Recall@10"]
        
    grouped_df = df_all.drop(['config_file', 'all_seeds', 'seed'], axis=1).groupby('params')
    df_mean = grouped_df.agg(aggregate_mean)
    df_std = grouped_df.agg(aggregate_std)
    for col in metric_cols:
        df_mean[col + '__std'] = df_std[col]
    return df_mean


def reorder_cols(df):
    order = ['val_epoch', 'val_epoch__std'] + PARAMS[1:] + ['val_NDCG@10', 'val_NDCG@10__std', 'val_Recall@10', 'val_Recall@10__std', 'test_NDCG@10', 'test_NDCG@10__std', 'test_Recall@10', 'test_Recall@10__std']
    return df[order]


df_all = df[df['all_seeds'].apply(len) == 3]
df_final = get_stats_seeds(df_all)
df_final = reorder_cols(df_final)
df_final.sort_values(by='val_NDCG@10', ascending=False, inplace=True)
df_final
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...  28.666667        1.154701
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...  29.666667        0.577350
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...  29.666667        0.577350
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...  29.666667        0.577350
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...  29.333333        1.154701
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...  29.000000        1.000000
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...  30.000000        0.000000
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...  30.000000        0.000000
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...  29.666667        0.577350
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...  29.666667        0.577350
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...  30.000000        0.000000
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...  30.000000        0.000000
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...  30.000000        0.000000
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...  29.666667        0.577350
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...  30.000000        0.000000
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...  29.666667        0.577350
#
#                                                    weighting_scheme  alpha  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...      exponential    0.3
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...             mean    0.3
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...             mean    0.4
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...             mean    0.3
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...      exponential    0.4
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...      exponential    0.3
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...             mean    0.4
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...             mean    0.5
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...      exponential    0.5
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...      exponential    0.4
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...      exponential    0.6
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...             mean    0.6
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...             mean    0.6
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...      exponential    0.5
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...             mean    0.5
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...      exponential    0.6
#
#                                                     fine_tune_epoch  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...             12.0
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...             12.0
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...             12.0
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...             12.0
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...             12.0
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...             12.0
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...             12.0
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...             12.0
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...             12.0
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...             12.0
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...             12.0
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...             12.0
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...             12.0
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...             12.0
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...             12.0
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...             12.0
#
#                                                    reconstruct_loss  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...             RMSE
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...             RMSE
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...             RMSE
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...              MSE
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...             RMSE
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...              MSE
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...              MSE
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...             RMSE
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...             RMSE
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...              MSE
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...             RMSE
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...             RMSE
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...              MSE
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...              MSE
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...              MSE
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...              MSE
#
#                                                     reconstruction_layer  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...                   3.0
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...                   3.0
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...                   3.0
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...                   3.0
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...                   3.0
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...                   3.0
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...                   3.0
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...                   3.0
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...                   3.0
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...                   3.0
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...                   3.0
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...                   3.0
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...                   3.0
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...                   3.0
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...                   3.0
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...                   3.0
#
#                                                     weight_scale  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...           0.1
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...           0.1
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...           0.1
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...           0.1
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...           0.1
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...           0.1
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...           0.1
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...           0.1
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...           0.1
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...           0.1
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...           0.1
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...           0.1
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...           0.1
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...           0.1
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...           0.1
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...           True       False
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...           True       False
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...           True       False
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...           True       False
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...           True       False
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...           True       False
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...           True       False
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...           True       False
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...           True       False
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...           True       False
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...           True       False
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...           True       False
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...           True       False
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...           True       False
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...           True       False
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...           True       False
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...  ...             True
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...  ...             True
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...  ...             True
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...  ...             True
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...  ...             True
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...  ...             True
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...  ...             True
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...  ...             True
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...  ...             True
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...  ...             True
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...  ...             True
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...  ...             True
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...  ...             True
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...  ...             True
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...  ...             True
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...  ...             True
#
#                                                     user_profile_embeddings_files  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...  gemma_short_large_umap_single
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...  gemma_short_large_umap_single
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...  gemma_short_large_umap_single
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...  gemma_short_large_umap_single
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...  gemma_short_large_umap_single
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...  gemma_short_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...    0.049443
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...    0.049037
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...    0.048847
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...    0.047123
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...    0.046023
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...    0.046010
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...    0.044573
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...    0.043670
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...    0.042893
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...    0.039797
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...    0.038543
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...    0.034000
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...    0.033120
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...    0.029827
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...    0.021720
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...    0.015607
#
#                                                    val_NDCG@10__std  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...         0.000779
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...         0.002338
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...         0.000710
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...         0.001302
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...         0.002896
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...         0.003581
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...         0.002786
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...         0.006265
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...         0.002167
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...         0.004440
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...         0.002506
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...         0.005935
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...         0.004971
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...         0.010520
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...         0.011312
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...         0.009938
#
#                                                     val_Recall@10  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...       0.096980
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...       0.098723
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...       0.098430
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...       0.095240
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...       0.094077
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...       0.092623
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...       0.087397
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...       0.087400
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...       0.085653
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...       0.079560
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...       0.078397
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...       0.067363
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...       0.067653
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...       0.062137
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...       0.045297
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...       0.036007
#
#                                                     val_Recall@10__std  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...            0.002511
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...            0.003297
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...            0.001740
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...            0.001005
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...            0.006096
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...            0.007037
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...            0.005599
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...            0.014816
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...            0.005321
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...            0.009312
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...            0.005439
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...            0.011370
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...            0.009236
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...            0.019288
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...            0.021389
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...            0.023316
#
#                                                     test_NDCG@10  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...      0.019617
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...      0.020410
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...      0.020157
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...      0.018943
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...      0.018543
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...      0.016830
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...      0.015043
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...      0.015727
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...      0.015283
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...      0.015040
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...      0.011530
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...      0.011860
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...      0.008990
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...      0.009417
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...      0.006633
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...      0.005287
#
#                                                     test_NDCG@10__std  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...           0.001578
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...           0.001441
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...           0.001070
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...           0.001592
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...           0.001574
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...           0.002013
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...           0.004551
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...           0.004780
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...           0.002540
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...           0.002688
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...           0.000828
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...           0.005710
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...           0.000575
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...           0.003628
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...           0.002743
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...           0.002595
#
#                                                     test_Recall@10  \
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...        0.041480
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...        0.043097
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...        0.042883
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...        0.040613
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...        0.038453
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...        0.036400
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...        0.032403
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...        0.034133
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...        0.032837
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...        0.032837
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...        0.025927
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...        0.027003
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...        0.019657
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...        0.020847
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...        0.014690
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...        0.011343
#
#                                                     test_Recall@10__std
# params
# (exponential, 0.3, 12, RMSE, 3, 0.1, True, Fals...             0.002969
# (mean, 0.3, 12, RMSE, 3, 0.1, True, False, Fals...             0.002828
# (mean, 0.4, 12, RMSE, 3, 0.1, True, False, Fals...             0.002638
# (mean, 0.3, 12, MSE, 3, 0.1, True, False, False...             0.004219
# (exponential, 0.4, 12, RMSE, 3, 0.1, True, Fals...             0.003612
# (exponential, 0.3, 12, MSE, 3, 0.1, True, False...             0.004001
# (mean, 0.4, 12, MSE, 3, 0.1, True, False, False...             0.009341
# (mean, 0.5, 12, RMSE, 3, 0.1, True, False, Fals...             0.009686
# (exponential, 0.5, 12, RMSE, 3, 0.1, True, Fals...             0.005047
# (exponential, 0.4, 12, MSE, 3, 0.1, True, False...             0.005385
# (exponential, 0.6, 12, RMSE, 3, 0.1, True, Fals...             0.001714
# (mean, 0.6, 12, RMSE, 3, 0.1, True, False, Fals...             0.013136
# (mean, 0.6, 12, MSE, 3, 0.1, True, False, False...             0.001305
# (exponential, 0.5, 12, MSE, 3, 0.1, True, False...             0.008512
# (mean, 0.5, 12, MSE, 3, 0.1, True, False, False...             0.007191
# (exponential, 0.6, 12, MSE, 3, 0.1, True, False...             0.005334
#
# [16 rows x 22 columns]

# %%
df_final.to_csv('BEAUTY_ALPHA_EXPS.csv')

# %%
df[df['params'] == ('exponential', 0.8, 30, 'MSE', 1, 0.1, 'True', 'False', 'False', 'mean', 'False', 'gemma_short_large_umap_single')]
# Out:
# Empty DataFrame
# Columns: [config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale, use_upscale, multi_profile, multi_profile_aggr_scheme, scale_guide_loss, user_profile_embeddings_files, seed, val_NDCG@10, val_Recall@10, val_epoch, test_NDCG@10, test_Recall@10, test_epoch, params, all_seeds]
# Index: []
#
# [0 rows x 22 columns]

# %%
df['params'][0]
# Out:
# ('mean',
#  0.5,
#  50,
#  'MSE',
#  1,
#  0.1,
#  'True',
#  'False',
#  'False',
#  'mean',
#  'False',
#  'gemma_short_large_umap_single')

# %%
df[df['all_seeds'].apply(len) != 3]
# Out:
# Empty DataFrame
# Columns: [config_file, weighting_scheme, alpha, fine_tune_epoch, reconstruct_loss, reconstruction_layer, weight_scale, use_down_scale, use_upscale, multi_profile, multi_profile_aggr_scheme, scale_guide_loss, user_profile_embeddings_files, seed, val_NDCG@10, val_Recall@10, val_epoch, test_NDCG@10, test_Recall@10, test_epoch, params, all_seeds]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_final['weighting_scheme'].value_counts()
# Out:
# weighting_scheme
# mean           16
# attention      15
# exponential     9
# Name: count, dtype: int64

# %%
df_final[df_final['scale_guide_loss'] == 'False']
# Out:
#                                                     val_epoch  val_epoch__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   9.333333        1.527525
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  12.666667        1.527525
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  13.000000        1.732051
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  13.666667        0.577350
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  14.666667        1.154701
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  14.000000        0.000000
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  14.000000        0.000000
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  14.666667        0.577350
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...   6.666667        1.154701
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  11.000000        0.000000
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  14.000000        0.000000
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  14.000000        0.000000
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  16.666667        2.516611
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  10.666667        2.516611
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  15.666667        2.886751
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  16.000000        1.732051
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             mean   0.50
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             mean   0.50
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      exponential   0.80
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      exponential   0.80
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      exponential   0.50
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      exponential   0.80
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             mean   0.65
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             mean   0.80
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      exponential   0.65
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             mean   0.65
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             mean   0.65
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             mean   0.50
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             mean   0.65
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             mean   0.80
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      exponential   0.50
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             mean   0.50
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             mean   0.80
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...              4.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...              8.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...              8.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              8.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...              8.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...              6.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              8.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              6.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              6.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              4.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              6.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              6.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              8.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...              4.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...              8.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...              8.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             RMSE
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             RMSE
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             RMSE
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...              MSE
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             RMSE
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             RMSE
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...              MSE
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...              MSE
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...              MSE
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...              MSE
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...              MSE
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             RMSE
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             RMSE
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             RMSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...                   1.0
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...                   2.0
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...                   1.0
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...                   1.0
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...                   1.0
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...                   1.0
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...                   2.0
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...                   1.0
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...                   1.0
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...                   1.0
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...                   1.0
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.1
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.1
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.1
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.1
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.1
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.1
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.1
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.1
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.1
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.1
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.1
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...          False        True
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...          False        True
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...          False        True
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...          False        True
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...          False        True
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...          False        True
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...          False        True
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...          False        True
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...          False        True
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...          False        True
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...          False        True
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...          False        True
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  ...            False
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  ...            False
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...  ...            False
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  ...            False
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  ...            False
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  ...            False
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...  ...            False
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...  ...            False
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  ...            False
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  ...            False
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...  ...            False
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  ...            False
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...  ...            False
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...   gemma_long_large_umap_single
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...  gemma_short_large_umap_single
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...   gemma_long_large_umap_single
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...  gemma_short_large_umap_single
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...  gemma_short_large_umap_single
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        gemma_long_large_single
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...   gemma_long_large_umap_single
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...  gemma_short_large_umap_single
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...   gemma_long_large_umap_single
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...  gemma_short_large_umap_single
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...   gemma_long_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099597
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...    0.099523
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...    0.099293
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...    0.099367
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...    0.099387
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...    0.099817
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...    0.099327
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...    0.099287
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...    0.099290
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...    0.098963
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...    0.099420
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...    0.098700
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...    0.099557
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...    0.099253
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...    0.099280
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...    0.098933
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...    0.099103
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...    0.099237
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...    0.099320
#
#                                                    val_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000808
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...         0.000072
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...         0.000384
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...         0.000376
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...         0.000116
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...         0.000266
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...         0.000539
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...         0.000652
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...         0.000521
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...         0.000100
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...         0.000670
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...         0.000743
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...         0.000778
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...         0.000325
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...         0.000524
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...         0.000314
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...         0.000295
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...         0.000196
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...         0.000223
#
#                                                     val_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183400
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...       0.182587
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...       0.183760
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...       0.183277
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...       0.183037
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...       0.183417
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...       0.183563
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...       0.183017
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...       0.183927
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...       0.183003
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...       0.183240
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...       0.183003
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...       0.184073
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...       0.183453
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...       0.183363
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...       0.182423
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...       0.183927
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...       0.183690
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...       0.183363
#
#                                                     val_Recall@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000946
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...            0.000343
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...            0.000537
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...            0.000603
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...            0.000872
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...            0.001399
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...            0.000333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...            0.001596
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...            0.000652
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...            0.000907
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...            0.000991
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...            0.001063
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...            0.000845
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...            0.000285
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...            0.000879
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...            0.000815
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...            0.001256
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...            0.000514
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...            0.000926
#
#                                                     test_NDCG@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059867
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...      0.059717
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...      0.059667
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...      0.059640
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...      0.059383
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...      0.059373
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...      0.059353
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...      0.059330
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...      0.059287
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...      0.059250
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...      0.059233
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...      0.059230
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...      0.059217
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...      0.059010
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...      0.058993
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...      0.058983
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...      0.058937
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...      0.058880
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...      0.058810
#
#                                                     test_NDCG@10__std  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000621
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...           0.000998
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...           0.000748
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...           0.000927
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...           0.000947
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...           0.001048
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...           0.000945
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...           0.000872
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...           0.001598
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...           0.000990
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...           0.001301
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...           0.000987
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...           0.001076
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...           0.001067
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...           0.001248
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...           0.001705
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...           0.001215
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...           0.001465
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...           0.001323
#
#                                                     test_Recall@10  \
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.115200
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...        0.114783
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...        0.114967
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...        0.114837
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...        0.114020
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...        0.114633
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...        0.114333
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...        0.113890
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...        0.114723
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...        0.113957
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...        0.113177
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...        0.114313
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...        0.114250
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...        0.114347
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...        0.113757
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...        0.113810
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...        0.114883
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...        0.113457
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...        0.113713
#
#                                                     test_Recall@10__std
# params
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000375
# (mean, 0.5, 4, RMSE, 2, 0.1, False, True, False...             0.001294
# (mean, 0.5, 6, MSE, 1, 0.1, False, True, False,...             0.000718
# (exponential, 0.8, 8, RMSE, 2, 0.1, False, True...             0.001643
# (exponential, 0.8, 8, RMSE, 1, 0.1, False, True...             0.000931
# (exponential, 0.5, 8, RMSE, 2, 0.1, False, True...             0.002053
# (exponential, 0.8, 8, MSE, 1, 0.1, False, True,...             0.000127
# (mean, 0.65, 8, RMSE, 1, 0.1, False, True, Fals...             0.000656
# (mean, 0.8, 6, RMSE, 1, 0.1, False, True, False...             0.001650
# (exponential, 0.65, 8, MSE, 1, 0.1, False, True...             0.001367
# (mean, 0.65, 6, MSE, 2, 0.1, False, True, False...             0.002264
# (mean, 0.65, 6, MSE, 1, 0.1, True, False, False...             0.001370
# (mean, 0.5, 4, MSE, 2, 0.1, False, True, False,...             0.001652
# (mean, 0.65, 6, MSE, 1, 0.1, False, True, False...             0.000874
# (mean, 0.8, 6, MSE, 1, 0.1, False, True, False,...             0.001516
# (mean, 0.8, 8, MSE, 1, 0.1, False, True, False,...             0.002309
# (exponential, 0.5, 4, RMSE, 1, 0.1, False, True...             0.001557
# (mean, 0.5, 8, RMSE, 1, 0.1, False, True, False...             0.001436
# (mean, 0.8, 8, RMSE, 1, 0.1, False, True, False...             0.001162
#
# [19 rows x 22 columns]

# %%
df['params'].value_counts()
# Out:
# params
# (mean, 0.7, 12, MSE, 1, 0.1, True, False, False, mean, True, gemma_short_large_umap_single)         3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         3
# (mean, 0.6, 6, RMSE, 2, 0.1, True, False, False, mean, True, gemma_long_large_umap_single)          3
# (attention, 0.5, 6, RMSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)    3
# (mean, 0.7, 12, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)              3
#                                                                                                    ..
# (mean, 0.6, 12, MSE, 1, 0.1, True, False, False, mean, False, gemma_long_large_umap_single)         1
# (mean, 0.7, 6, RMSE, 1, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)         1
# (attention, 0.5, 6, MSE, 2, 0.1, True, False, False, mean, False, gemma_long_large_single)          1
# (attention, 0.6, 6, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)     1
# (attention, 0.7, 12, MSE, 2, 0.1, False, False, False, mean, True, gemma_long_large_umap_single)    1
# Name: count, Length: 558, dtype: int64

# %%
df['']
# Out:
#                                             config_file weighting_scheme  \
# 663   mean-0.8-6-RMSE-1-0.1-False-True-False-mean-Fa...             mean
# 837   exponential-0.8-8-MSE-2-0.1-False-True-False-m...      exponential
# 779   exponential-0.65-8-RMSE-2-0.1-False-True-False...      exponential
# 649   mean-0.8-6-MSE-2-0.1-False-True-False-mean-Tru...             mean
# 467   exponential-0.5-8-RMSE-2-0.1-True-False-False-...      exponential
# ...                                                 ...              ...
# 876   exponential-0.8-8-RMSE-2-0.1-True-False-False-...      exponential
# 792   exponential-0.8-4-MSE-1-0.1-False-True-False-m...      exponential
# 25    attention-0.65-8-MSE-1-0.1-False-True-False-me...        attention
# 274   attention-0.8-6-MSE-2-0.1-True-False-False-mea...        attention
# 1161  attention-0.5-8-MSE-1-0.1-False-True-False-mea...        attention
#
#       alpha  fine_tune_epoch reconstruct_loss  reconstruction_layer  \
# 663    0.80                6             RMSE                     1
# 837    0.80                8              MSE                     2
# 779    0.65                8             RMSE                     2
# 649    0.80                6              MSE                     2
# 467    0.50                8             RMSE                     2
# ...     ...              ...              ...                   ...
# 876    0.80                8             RMSE                     2
# 792    0.80                4              MSE                     1
# 25     0.65                8              MSE                     1
# 274    0.80                6              MSE                     2
# 1161   0.50                8              MSE                     1
#
#       weight_scale use_down_scale use_upscale multi_profile  ...  \
# 663            0.1          False        True         False  ...
# 837            0.1          False        True         False  ...
# 779            0.1          False        True         False  ...
# 649            0.1          False        True         False  ...
# 467            0.1           True       False         False  ...
# ...            ...            ...         ...           ...  ...
# 876            0.1           True       False         False  ...
# 792            0.1          False        True         False  ...
# 25             0.1          False        True         False  ...
# 274            0.1           True       False         False  ...
# 1161           0.1          False        True         False  ...
#
#       user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  \
# 663   gemma_short_large_umap_single   42     0.09987        0.18422
# 837    gemma_long_large_umap_single   42     0.09898        0.18188
# 779   gemma_short_large_umap_single   42     0.09998        0.18356
# 649    gemma_long_large_umap_single   42     0.09983        0.18389
# 467   gemma_short_large_umap_single   42     0.09985        0.18454
# ...                             ...  ...         ...            ...
# 876         gemma_long_large_single   42     0.09951        0.18465
# 792         gemma_long_large_single   42     0.09851        0.18318
# 25     gemma_long_large_umap_single   42     0.09773        0.18112
# 274        gemma_short_large_single   42     0.09796        0.18210
# 1161   gemma_long_large_umap_single   42     0.09885        0.18253
#
#       val_epoch  test_NDCG@10  test_Recall@10  test_epoch  \
# 663          14       0.06111         0.11661          14
# 837          14       0.06083         0.11617          14
# 779          14       0.06072         0.11579          14
# 649          14       0.06072         0.11615          14
# 467          14       0.06072         0.11703          14
# ...         ...           ...             ...         ...
# 876          19       0.05589         0.10964          19
# 792          11       0.05586         0.10847          11
# 25           18       0.05583         0.10835          18
# 274           7       0.05579         0.10824           7
# 1161         17       0.05526         0.10697          17
#
#                                                  params  all_seeds
# 663   (mean, 0.8, 6, RMSE, 1, 0.1, False, True, Fals...       [42]
# 837   (exponential, 0.8, 8, MSE, 2, 0.1, False, True...       [42]
# 779   (exponential, 0.65, 8, RMSE, 2, 0.1, False, Tr...       [42]
# 649   (mean, 0.8, 6, MSE, 2, 0.1, False, True, False...       [42]
# 467   (exponential, 0.5, 8, RMSE, 2, 0.1, True, Fals...       [42]
# ...                                                 ...        ...
# 876   (exponential, 0.8, 8, RMSE, 2, 0.1, True, Fals...       [42]
# 792   (exponential, 0.8, 4, MSE, 1, 0.1, False, True...       [42]
# 25    (attention, 0.65, 8, MSE, 1, 0.1, False, True,...       [42]
# 274   (attention, 0.8, 6, MSE, 2, 0.1, True, False, ...       [42]
# 1161  (attention, 0.5, 8, MSE, 1, 0.1, False, True, ...       [42]
#
# [1728 rows x 22 columns]

# %%
df[PARAMS[1:]].to_json('best_ml20m.json', index=False, orient="records")

# %%
df_final[PARAMS[1:]].to_json('best_beauty_3seeds.json', index=False, orient="records")

# %%
results.keys()
# Out:
# dict_keys(['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-False-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-False-gemma_short_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-RMSE-1-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_large_umap_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_long_small_single-42.yaml', '-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.5-6-RMSE-2-0.1-True-False-False-mean-True-gemma_short_large_umap_single-42.yaml', '-2_ ...

# %%
results['-2_0/configs/sasrec/beauty/BEAUTY_INITIAL/single_seed/attention-0.7-12-MSE-2-0.1-False-False-False-mean-False-gemma_long_large_umap_single-42.yaml']
# Out:
# {'validation_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.004162330905306972,
#    'NDCG@5': 0.0023390187078764875,
#    'Recall@10': 0.006243496357960458,
#    'NDCG@10': 0.00302255539974203,
#    'Recall@20': 0.010851791288836034,
#    'NDCG@20': 0.004198139363666408,
#    'loss_recsys': np.float64(10.347532872800473),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.004013676230117437,
#    'NDCG@5': 0.0024368647296024288,
#    'Recall@10': 0.008324661810613945,
#    'NDCG@10': 0.003826736836797046,
#    'Recall@20': 0.014122194143005798,
#    'NDCG@20': 0.0052561474396673165,
#    'loss_recsys': np.float64(10.325713298938892),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.006094841682770923,
#    'NDCG@5': 0.003388410317555781,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.004382003442624782,
#    'Recall@20': 0.015014122194143005,
#    'NDCG@20': 0.005846106928100518,
#    'loss_recsys': np.float64(10.315859370761448),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.00475694960606511,
#    'NDCG@5': 0.0024233021388104224,
#    'Recall@10': 0.008919280511372083,
#    'NDCG@10': 0.0037466937619863266,
#    'Recall@20': 0.015608740894901144,
#    'NDCG@20': 0.005444883250261604,
#    'loss_recsys': np.float64(10.304392673351147),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.005351568306823249,
#    'NDCG@5': 0.003198377698354209,
#    'Recall@10': 0.009216589861751152,
#    'NDCG@10': 0.0043943408066474685,
#    'Recall@20': 0.014568158168574402,
#    'NDCG@20': 0.005749538405717385,
#    'loss_recsys': np.float64(10.319377016138148),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.005648877657202319,
#    'NDCG@5': 0.0037872565967536566,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005442632113875368,
#    'Recall@20': 0.01605470492046975,
#    'NDCG@20': 0.006777092754637059,
#    'loss_recsys': np.float64(10.228386843646014),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.00787869778504534,
#    'NDCG@5': 0.0046932804995630795,
#    'Recall@10': 0.010703136613646498,
#    'NDCG@10': 0.005588280874640481,
#    'Recall@20': 0.018433179723502304,
#    'NDCG@20': 0.0075612680348843865,
#    'loss_recsys': np.float64(10.17817313582809),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.006689460383529062,
#    'NDCG@5': 0.0041596912400265655,
#    'Recall@10': 0.01040582726326743,
#    'NDCG@10': 0.005321938281465431,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007405936319264151,
#    'loss_recsys': np.float64(10.219599264639395),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.005500222982012784,
#    'NDCG@5': 0.0031088033783253297,
#    'Recall@10': 0.011297755314404637,
#    'NDCG@10': 0.004985089569295943,
#    'Recall@20': 0.017838561022744167,
#    'NDCG@20': 0.00663930810328949,
#    'loss_recsys': np.float64(10.194536915531865),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.005202913631633715,
#    'NDCG@5': 0.003397568455595876,
#    'Recall@10': 0.009959863237698825,
#    'NDCG@10': 0.004914059980283862,
#    'Recall@20': 0.018135870373123236,
#    'NDCG@20': 0.006973698958964976,
#    'loss_recsys': np.float64(10.167172855801052),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.0068381150587185965,
#    'NDCG@5': 0.003916981294850848,
#    'Recall@10': 0.011446409989594173,
#    'NDCG@10': 0.005379105533092607,
#    'Recall@20': 0.018730489073881373,
#    'NDCG@20': 0.007205976983741362,
#    'loss_recsys': np.float64(10.186000929938423),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.009216589861751152,
#    'NDCG@5': 0.00536698016561086,
#    'Recall@10': 0.01664932362122789,
#    'NDCG@10': 0.007717170610955234,
#    'Recall@20': 0.025271294782220902,
#    'NDCG@20': 0.009880426186269118,
#    'loss_recsys': np.float64(10.067615509033203),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.010703136613646498,
#    'NDCG@5': 0.0061917896653171526,
#    'Recall@10': 0.015608740894901144,
#    'NDCG@10': 0.007797456503587827,
#    'Recall@20': 0.026163222833358108,
#    'NDCG@20': 0.010465141389670158,
#    'loss_recsys': np.float64(10.02229372660319),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.015311431544522075,
#    'NDCG@5': 0.008807618966761114,
#    'Recall@10': 0.02556860413259997,
#    'NDCG@10': 0.012092302117390957,
#    'Recall@20': 0.037460978147762745,
#    'NDCG@20': 0.01509402483874486,
#    'loss_recsys': np.float64(10.043341000874838),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.02333878400475695,
#    'NDCG@5': 0.013452293225307246,
#    'Recall@10': 0.03478519399435112,
#    'NDCG@10': 0.01718388295588317,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.020940635823487562,
#    'loss_recsys': np.float64(10.394192024513528),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.02556860413259997,
#    'NDCG@5': 0.01467175621573135,
#    'Recall@10': 0.03612308607105694,
#    'NDCG@10': 0.01808131911592638,
#    'Recall@20': 0.052623755017095285,
#    'NDCG@20': 0.02219570412294851,
#    'loss_recsys': np.float64(10.669138625816062),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.027649769585253458,
#    'NDCG@5': 0.01608440494827978,
#    'Recall@10': 0.040285416976363904,
#    'NDCG@10': 0.020169707389790147,
#    'Recall@20': 0.055299539170506916,
#    'NDCG@20': 0.023953926373648043,
#    'loss_recsys': np.float64(10.90925513373481),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.029136316337148804,
#    'NDCG@5': 0.0168769101747808,
#    'Recall@10': 0.040731381001932514,
#    'NDCG@10': 0.020608016688631957,
#    'Recall@20': 0.05589415787126505,
#    'NDCG@20': 0.024402803415633317,
#    'loss_recsys': np.float64(11.069474714773673),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.027352460234874386,
#    'NDCG@5': 0.01618542386958481,
#    'Recall@10': 0.03969079827560577,
#    'NDCG@10': 0.02020389827803692,
#    'Recall@20': 0.05752935929834993,
#    'NDCG@20': 0.024705387746063227,
#    'loss_recsys': np.float64(11.168465543676305),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.026906496209305783,
#    'NDCG@5': 0.01646556425576616,
#    'Recall@10': 0.039244834250037164,
#    'NDCG@10': 0.020470205593094953,
#    'Recall@20': 0.05604281254645459,
#    'NDCG@20': 0.024679021484805407,
#    'loss_recsys': np.float64(11.262380140799063),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.02720380555968485,
#    'NDCG@5': 0.016519092779838616,
#    'Recall@10': 0.03954214360041623,
#    'NDCG@10': 0.020518979186977693,
#    'Recall@20': 0.05366433774342203,
#    'NDCG@20': 0.02405135827732951,
#    'loss_recsys': np.float64(11.435306372465911),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.027947078935632527,
#    'NDCG@5': 0.01738097975330968,
#    'Recall@10': 0.038947524899658095,
#    'NDCG@10': 0.02095301327688371,
#    'Recall@20': 0.05173182696595808,
#    'NDCG@20': 0.02417196843995193,
#    'loss_recsys': np.float64(11.526062541537815),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.026014568158168574,
#    'NDCG@5': 0.016542074335477355,
#    'Recall@10': 0.03537981269510926,
#    'NDCG@10': 0.019553550820444923,
#    'Recall@20': 0.049799316188494126,
#    'NDCG@20': 0.02317558219001501,
#    'loss_recsys': np.float64(11.65649449383771),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.02423071205589416,
#    'NDCG@5': 0.015859220487606795,
#    'Recall@10': 0.03627174074624647,
#    'NDCG@10': 0.019799808429292996,
#    'Recall@20': 0.05069124423963134,
#    'NDCG@20': 0.02343532319442468,
#    'loss_recsys': np.float64(11.757749239603678),
#    'loss_guide': np.float64(0.0)},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.025717258807789505,
#    'NDCG@5': 0.01651283913883568,
#    'Recall@10': 0.03716366879738368,
#    'NDCG@10': 0.02013082716570259,
#    'Recall@20': 0.04950200683811506,
#    'NDCG@20': 0.02323738534861304,
#    'loss_recsys': np.float64(11.947628409774214),
#    'loss_guide': np.float64(0.0)}],
#  'test_metrics': [{'epoch': 1,
#    'loss': 10.828,
#    'Recall@5': 0.002139927480235392,
#    'NDCG@5': 0.0013538334012237051,
#    'Recall@10': 0.003388218510372704,
#    'NDCG@10': 0.0017610431170978012,
#    'Recall@20': 0.004993164120549248,
#    'NDCG@20': 0.002165665195797907},
#   {'epoch': 2,
#    'loss': 5.2138,
#    'Recall@5': 0.001069963740117696,
#    'NDCG@5': 0.0006361886489577691,
#    'Recall@10': 0.002853236640313856,
#    'NDCG@10': 0.0012341079502590968,
#    'Recall@20': 0.005290376270581942,
#    'NDCG@20': 0.0018409968568660385},
#   {'epoch': 3,
#    'loss': 4.8,
#    'Recall@5': 0.0015455031801700054,
#    'NDCG@5': 0.0008165547682358466,
#    'Recall@10': 0.003507103370385781,
#    'NDCG@10': 0.001439664780594028,
#    'Recall@20': 0.006954764310765024,
#    'NDCG@20': 0.002298769186171313},
#   {'epoch': 4,
#    'loss': 4.7397,
#    'Recall@5': 0.0023776972002615467,
#    'NDCG@5': 0.0014026731913448166,
#    'Recall@10': 0.004101527670451168,
#    'NDCG@10': 0.0019555992269632205,
#    'Recall@20': 0.006835879450751947,
#    'NDCG@20': 0.0026387664443111684},
#   {'epoch': 5,
#    'loss': 4.695,
#    'Recall@5': 0.0013671758901503894,
#    'NDCG@5': 0.0007172181997728328,
#    'Recall@10': 0.003150448790346549,
#    'NDCG@10': 0.0013028721633510456,
#    'Recall@20': 0.00671699459073887,
#    'NDCG@20': 0.0022039522710796317},
#   {'epoch': 6,
#    'loss': 4.6524,
#    'Recall@5': 0.0026154669202877014,
#    'NDCG@5': 0.001487013497973625,
#    'Recall@10': 0.004279854960470784,
#    'NDCG@10': 0.0020137893819131528,
#    'Recall@20': 0.007251976460797717,
#    'NDCG@20': 0.002751861097327539},
#   {'epoch': 7,
#    'loss': 4.6229,
#    'Recall@5': 0.003150448790346549,
#    'NDCG@5': 0.001966949736314488,
#    'Recall@10': 0.004577067110503478,
#    'NDCG@10': 0.0024279629756173756,
#    'Recall@20': 0.008559709920941568,
#    'NDCG@20': 0.003421836252807189},
#   {'epoch': 8,
#    'loss': 4.5812,
#    'Recall@5': 0.002318254770255008,
#    'NDCG@5': 0.001675343508882811,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.002225847738659184,
#    'Recall@20': 0.007430303750817334,
#    'NDCG@20': 0.0030913081515921655},
#   {'epoch': 9,
#    'loss': 4.5482,
#    'Recall@5': 0.0027343517803007787,
#    'NDCG@5': 0.0015257141404888019,
#    'Recall@10': 0.004636509540510016,
#    'NDCG@10': 0.002116818478138206,
#    'Recall@20': 0.008143612910895798,
#    'NDCG@20': 0.003003676133016085},
#   {'epoch': 10,
#    'loss': 4.5036,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0016414278814032013,
#    'Recall@10': 0.004042085240444629,
#    'NDCG@10': 0.0020269605539885724,
#    'Recall@20': 0.00802472805088272,
#    'NDCG@20': 0.003022193540214734},
#   {'epoch': 11,
#    'loss': 4.4673,
#    'Recall@5': 0.002853236640313856,
#    'NDCG@5': 0.0017859868566651041,
#    'Recall@10': 0.004814836830529632,
#    'NDCG@10': 0.0024061624093819037,
#    'Recall@20': 0.00850026749093503,
#    'NDCG@20': 0.0033377840612771248},
#   {'epoch': 12,
#    'loss': 9.6252,
#    'Recall@5': 0.003744873090411936,
#    'NDCG@5': 0.0021182589243107855,
#    'Recall@10': 0.007251976460797717,
#    'NDCG@10': 0.0032274959887816537,
#    'Recall@20': 0.011412946561255424,
#    'NDCG@20': 0.004260477909596519},
#   {'epoch': 13,
#    'loss': 9.347,
#    'Recall@5': 0.004101527670451168,
#    'NDCG@5': 0.002598666341567106,
#    'Recall@10': 0.007192534030791179,
#    'NDCG@10': 0.0035955304322993578,
#    'Recall@20': 0.01206681329132735,
#    'NDCG@20': 0.004805631612736497},
#   {'epoch': 14,
#    'loss': 8.8615,
#    'Recall@5': 0.007192534030791179,
#    'NDCG@5': 0.004284443818367116,
#    'Recall@10': 0.011175176841229269,
#    'NDCG@10': 0.005561693731332473,
#    'Recall@20': 0.01700053498187006,
#    'NDCG@20': 0.007036552276919148},
#   {'epoch': 15,
#    'loss': 8.0721,
#    'Recall@5': 0.010818522261190037,
#    'NDCG@5': 0.006017385559856399,
#    'Recall@10': 0.015752243951732747,
#    'NDCG@10': 0.007622415926753642,
#    'Recall@20': 0.021220947512334304,
#    'NDCG@20': 0.008998311353213068},
#   {'epoch': 16,
#    'loss': 7.3992,
#    'Recall@5': 0.011650716281281578,
#    'NDCG@5': 0.006517543634988249,
#    'Recall@10': 0.017119419841883136,
#    'NDCG@10': 0.008282253693749164,
#    'Recall@20': 0.02324199013255662,
#    'NDCG@20': 0.009830076487716423},
#   {'epoch': 17,
#    'loss': 6.8963,
#    'Recall@5': 0.011888486001307734,
#    'NDCG@5': 0.006735338572974523,
#    'Recall@10': 0.016703322831837366,
#    'NDCG@10': 0.008283234498932084,
#    'Recall@20': 0.025144147892765856,
#    'NDCG@20': 0.010398704256787777},
#   {'epoch': 18,
#    'loss': 6.5189,
#    'Recall@5': 0.011947928431314273,
#    'NDCG@5': 0.00666463396881279,
#    'Recall@10': 0.018129941151994292,
#    'NDCG@10': 0.008639935083638146,
#    'Recall@20': 0.02591689948285086,
#    'NDCG@20': 0.010597046951628863},
#   {'epoch': 19,
#    'loss': 6.2105,
#    'Recall@5': 0.012423467871366582,
#    'NDCG@5': 0.006813344336899553,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008713483760822175,
#    'Recall@20': 0.025798014622837782,
#    'NDCG@20': 0.01058971981780322},
#   {'epoch': 20,
#    'loss': 5.9424,
#    'Recall@5': 0.012185698151340426,
#    'NDCG@5': 0.006996251090431883,
#    'Recall@10': 0.01830826844201391,
#    'NDCG@10': 0.008982034806780602,
#    'Recall@20': 0.026095226772870475,
#    'NDCG@20': 0.010960017615107813},
#   {'epoch': 21,
#    'loss': 5.707,
#    'Recall@5': 0.012364025441360043,
#    'NDCG@5': 0.0068822554357764855,
#    'Recall@10': 0.01949711704214468,
#    'NDCG@10': 0.009193702424131632,
#    'Recall@20': 0.02668965107293586,
#    'NDCG@20': 0.01102183364428713},
#   {'epoch': 22,
#    'loss': 5.4828,
#    'Recall@5': 0.012601795161386197,
#    'NDCG@5': 0.007046747803227453,
#    'Recall@10': 0.017951613861974677,
#    'NDCG@10': 0.008761131902699917,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.01043881323043057},
#   {'epoch': 23,
#    'loss': 5.2784,
#    'Recall@5': 0.011531831421268502,
#    'NDCG@5': 0.006640128844035038,
#    'Recall@10': 0.017535516851928907,
#    'NDCG@10': 0.008585679830839013,
#    'Recall@20': 0.02532247518278547,
#    'NDCG@20': 0.01053402397710971},
#   {'epoch': 24,
#    'loss': 5.0785,
#    'Recall@5': 0.011353504131248885,
#    'NDCG@5': 0.006717526952725617,
#    'Recall@10': 0.018070498721987755,
#    'NDCG@10': 0.008847053447249018,
#    'Recall@20': 0.02550080247280509,
#    'NDCG@20': 0.01071452445750896},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007},
#   {'epoch': 25,
#    'loss': 4.8979,
#    'Recall@5': 0.010759079831183498,
#    'NDCG@5': 0.00667477159468093,
#    'Recall@10': 0.017357189561909292,
#    'NDCG@10': 0.008792345233871433,
#    'Recall@20': 0.024668608452713545,
#    'NDCG@20': 0.010625335327377007}]}

# %%
df['config_file']
# Out:
# 426    mean-0.7-12-MSE-1-0.1-True-False-False-mean-Tr...
# 11     attention-0.7-12-MSE-2-0.1-True-False-False-me...
# 88     mean-0.7-6-RMSE-1-0.1-True-False-False-mean-Tr...
# 283    mean-0.5-6-MSE-1-0.1-True-False-False-mean-Tru...
# 373    attention-0.5-12-MSE-1-0.1-True-False-False-me...
#                              ...
# 73     mean-0.7-6-MSE-2-0.1-True-False-False-mean-Tru...
# 257    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 234    mean-0.6-6-MSE-2-0.1-True-False-False-mean-Tru...
# 259    mean-0.7-12-MSE-2-0.1-True-False-False-mean-Tr...
# 2      attention-0.7-12-MSE-2-0.1-False-False-False-m...
# Name: config_file, Length: 558, dtype: object

# %%
PARAMS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PARAMS
#
# NameError: name 'PARAMS' is not defined

# %%
df_final
# Out:
#                                                      val_epoch  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  187.000000
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  196.333333
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  178.000000
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...  174.333333
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  168.000000
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...  178.000000
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  177.000000
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  162.333333
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...  180.666667
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  170.666667
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  188.666667
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  180.000000
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  175.000000
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...  189.000000
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...  184.000000
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  169.666667
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...  193.666667
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  182.333333
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  152.333333
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  188.333333
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  188.000000
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...  190.333333
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  194.000000
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  182.333333
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  193.333333
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...  193.000000
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...  197.333333
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  180.666667
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  180.000000
#
#                                                     val_epoch__std  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...       19.924859
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...        3.785939
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...        1.732051
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...       25.106440
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...       18.248288
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...        6.000000
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       18.520259
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       15.567059
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...       18.036999
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...        7.767453
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       10.408330
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...       27.730849
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...       23.430749
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...       10.816654
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...       21.000000
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...       13.576941
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...        4.041452
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       18.175075
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...       54.243279
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...        8.736895
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...        6.928203
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...       14.224392
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...        6.082763
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       28.041636
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...        8.144528
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...        6.557439
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...        1.154701
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...       30.892286
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       21.377558
#
#                                                    weighting_scheme  alpha  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             mean   0.80
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             mean   0.80
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      exponential   0.80
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...      exponential   0.65
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             mean   0.80
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      exponential   0.80
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             mean   0.65
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             mean   0.65
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      exponential   0.65
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             mean   0.65
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             mean   0.80
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...      exponential   0.65
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...      exponential   0.80
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      exponential   0.80
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      exponential   0.65
#
#                                                     fine_tune_epoch  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            130.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             30.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             30.0
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...            130.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            130.0
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...            100.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             30.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            100.0
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...            130.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            130.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             30.0
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             30.0
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...             30.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             30.0
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...            100.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             30.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             30.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             30.0
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            130.0
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...            100.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            100.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            100.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            130.0
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...            130.0
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...            130.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            100.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            130.0
#
#                                                    reconstruct_loss  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...              MSE
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...              MSE
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...              MSE
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...              MSE
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...              MSE
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...              MSE
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             RMSE
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             RMSE
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...              MSE
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...              MSE
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...              MSE
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             RMSE
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             RMSE
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             RMSE
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...              MSE
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...              MSE
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...              MSE
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...              MSE
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...             RMSE
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...              MSE
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             RMSE
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...              MSE
#
#                                                     reconstruction_layer  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...                   1.0
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...                   1.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...                   1.0
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...                   1.0
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...                   1.0
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...                   1.0
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...                   1.0
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...                   1.0
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...                   1.0
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...                   1.0
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...                   1.0
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...                   1.0
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...                   1.0
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...                   1.0
#
#                                                     weight_scale  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.1
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.1
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.1
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...           0.1
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.1
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...           0.1
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.1
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.1
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.1
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.1
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.1
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.1
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...           0.1
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...           0.1
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.1
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.1
#
#                                                    use_down_scale use_upscale  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           True       False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           True       False
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           True       False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...           True       False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           True       False
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...           True       False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           True       False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           True       False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           True       False
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           True       False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           True       False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           True       False
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...           True       False
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...           True       False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           True       False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           True       False
#
#                                                     ... scale_guide_loss  \
# params                                              ...
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  ...            False
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  ...            False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  ...            False
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...  ...            False
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  ...            False
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...  ...            False
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  ...            False
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  ...            False
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  ...            False
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  ...            False
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...  ...            False
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  ...             True
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...  ...             True
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  ...             True
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  ...             True
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  ...             True
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  ...             True
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  ...             True
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  ...             True
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  ...             True
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...  ...             True
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...  ...             True
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  ...             True
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  ...             True
#
#                                                     user_profile_embeddings_files  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  gemma_short_large_umap_single
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  gemma_short_large_umap_single
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  gemma_short_large_umap_single
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...  gemma_short_large_umap_single
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...  gemma_short_large_umap_single
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...  gemma_short_large_umap_single
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...  gemma_short_large_umap_single
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...  gemma_short_large_umap_single
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...  gemma_short_large_umap_single
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...  gemma_short_large_umap_single
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...  gemma_short_large_umap_single
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...  gemma_short_large_umap_single
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...  gemma_short_large_umap_single
#
#                                                    val_NDCG@10  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...    0.181537
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...    0.181477
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...    0.181333
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...    0.181070
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...    0.181033
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...    0.180920
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...    0.180740
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...    0.180707
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...    0.180600
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...    0.180590
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...    0.180450
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...    0.180307
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...    0.180277
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...    0.180113
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...    0.179957
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...    0.179950
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...    0.179633
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...    0.179390
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...    0.179373
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...    0.179217
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...    0.178640
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...    0.177667
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...    0.177557
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...    0.177333
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...    0.176153
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...    0.175863
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...    0.175573
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...    0.174910
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...    0.174303
#
#                                                    val_NDCG@10__std  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...         0.000266
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...         0.001445
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...         0.001285
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...         0.000131
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...         0.000687
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...         0.000560
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...         0.000197
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...         0.000315
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...         0.000620
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...         0.000679
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...         0.000756
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...         0.001079
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...         0.001638
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...         0.000765
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...         0.001066
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...         0.000615
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...         0.000973
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...         0.000210
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...         0.002993
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...         0.001154
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...         0.001434
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...         0.000779
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...         0.000764
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...         0.001436
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...         0.000705
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...         0.001230
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...         0.001028
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...         0.002458
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...         0.002491
#
#                                                     val_Recall@10  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...       0.288197
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...       0.287293
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...       0.288867
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...       0.287900
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...       0.287797
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...       0.286803
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       0.287647
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       0.286637
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...       0.287590
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...       0.286117
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       0.285760
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...       0.285403
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...       0.288093
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...       0.285687
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...       0.286890
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...       0.285673
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...       0.286297
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...       0.286130
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...       0.285180
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...       0.285197
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...       0.284230
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...       0.283460
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...       0.283500
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...       0.282257
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...       0.282760
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...       0.281587
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...       0.282017
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...       0.280103
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...       0.278687
#
#                                                     val_Recall@10__std  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            0.001323
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...            0.003120
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...            0.002677
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...            0.001914
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            0.000582
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...            0.001107
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...            0.001047
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            0.001048
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...            0.000052
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            0.000657
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            0.001187
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            0.000570
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...            0.002374
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...            0.000491
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...            0.000089
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...            0.001490
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...            0.002124
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...            0.000582
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...            0.003584
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...            0.002604
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...            0.001478
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...            0.001101
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...            0.001780
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...            0.001192
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...            0.001106
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...            0.001876
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...            0.001222
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...            0.003478
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...            0.003073
#
#                                                     test_NDCG@10  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...      0.042590
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...      0.042173
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...      0.041200
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...      0.042580
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...      0.041260
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...      0.040950
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      0.047890
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...      0.042893
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...      0.045393
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      0.044977
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      0.045390
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      0.046657
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      0.050097
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...      0.045320
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...      0.047063
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...      0.045290
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...      0.045220
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...      0.049733
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...      0.049217
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...      0.049587
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...      0.043933
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...      0.045730
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...      0.045813
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...      0.042210
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...      0.044627
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...      0.045287
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...      0.045367
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...      0.048367
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...      0.043840
#
#                                                     test_NDCG@10__std  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.000977
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.000328
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.001629
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...           0.002975
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.001527
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...           0.001562
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.000676
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.003585
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...           0.002886
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.002299
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.002133
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.002337
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.002141
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...           0.002238
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...           0.001707
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...           0.004719
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...           0.003727
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...           0.003504
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...           0.001561
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...           0.000303
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...           0.002002
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...           0.001665
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...           0.001197
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...           0.002982
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...           0.001681
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...           0.001739
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...           0.002871
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...           0.001172
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...           0.003516
#
#                                                     test_Recall@10  \
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...        0.073347
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...        0.073280
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...        0.071700
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...        0.074620
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...        0.071750
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...        0.070580
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...        0.081850
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...        0.074783
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...        0.078397
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...        0.077530
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...        0.077883
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...        0.079547
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...        0.085503
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...        0.077990
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...        0.080110
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...        0.077800
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...        0.076843
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...        0.084183
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...        0.083933
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...        0.083957
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...        0.074933
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...        0.078253
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...        0.077697
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...        0.073757
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...        0.076820
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...        0.077877
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...        0.077093
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...        0.082457
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...        0.074473
#
#                                                     test_Recall@10__std
# params
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             0.002034
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             0.000868
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             0.003037
# (mean, 0.65, 130, MSE, 1, 0.1, True, False, Fal...             0.004700
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             0.003095
# (mean, 0.8, 100, RMSE, 1, 0.1, True, False, Fal...             0.002951
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             0.001945
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             0.005056
# (exponential, 0.8, 130, RMSE, 1, 0.1, True, Fal...             0.003748
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             0.002516
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...             0.002456
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...             0.004031
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             0.003653
# (mean, 0.8, 30, RMSE, 1, 0.1, True, False, Fals...             0.003421
# (exponential, 0.65, 30, MSE, 1, 0.1, True, Fals...             0.003071
# (mean, 0.8, 30, MSE, 1, 0.1, True, False, False...             0.006796
# (mean, 0.65, 100, RMSE, 1, 0.1, True, False, Fa...             0.006480
# (exponential, 0.8, 30, MSE, 1, 0.1, True, False...             0.005375
# (mean, 0.65, 30, RMSE, 1, 0.1, True, False, Fal...             0.002491
# (exponential, 0.65, 30, RMSE, 1, 0.1, True, Fal...             0.001212
# (mean, 0.65, 130, RMSE, 1, 0.1, True, False, Fa...             0.003472
# (mean, 0.8, 100, MSE, 1, 0.1, True, False, Fals...             0.002788
# (exponential, 0.65, 100, MSE, 1, 0.1, True, Fal...             0.003087
# (mean, 0.65, 100, MSE, 1, 0.1, True, False, Fal...             0.004908
# (mean, 0.8, 130, MSE, 1, 0.1, True, False, Fals...             0.002609
# (exponential, 0.65, 130, RMSE, 1, 0.1, True, Fa...             0.003262
# (exponential, 0.8, 130, MSE, 1, 0.1, True, Fals...             0.004733
# (exponential, 0.8, 100, RMSE, 1, 0.1, True, Fal...             0.002191
# (exponential, 0.65, 130, MSE, 1, 0.1, True, Fal...             0.005980
#
# [29 rows x 22 columns]

# %%
df_final[6:].to_csv('ml20m_llm_runs_FINAL_4_200_epochs.csv')

# %%
np.corrcoef(df_final['test_NDCG@10'].values[:15], df_final['val_NDCG@10'].values[:15])
# Out:
# array([[ 1.       , -0.5951883],
#        [-0.5951883,  1.       ]])

# %%
df[df['params'] ==('exponential', 0.65, 50, 'MSE', 1, 0.1, 'True', 'False', 'False', 'mean', 'True', 'gemma_short_large_single')]
# Out:
#                                           config_file weighting_scheme  alpha  \
# 12  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
# 13  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
# 14  exponential-0.65-50-MSE-1-0.1-True-False-False...      exponential   0.65
#
#     fine_tune_epoch reconstruct_loss  reconstruction_layer  weight_scale  \
# 12               50              MSE                     1           0.1
# 13               50              MSE                     1           0.1
# 14               50              MSE                     1           0.1
#
#    use_down_scale use_upscale multi_profile  ...  \
# 12           True       False         False  ...
# 13           True       False         False  ...
# 14           True       False         False  ...
#
#    user_profile_embeddings_files seed val_NDCG@10  val_Recall@10  val_epoch  \
# 12      gemma_short_large_single    1     0.17211        0.27639         98
# 13      gemma_short_large_single  256     0.17094        0.27750        100
# 14      gemma_short_large_single   42     0.17012        0.27362         99
#
#     test_NDCG@10  test_Recall@10  test_epoch  \
# 12       0.04652         0.07940          98
# 13       0.04522         0.07727         100
# 14       0.04753         0.08052          99
#
#                                                params     all_seeds
# 12  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
# 13  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
# 14  (exponential, 0.65, 50, MSE, 1, 0.1, True, Fal...  [1, 256, 42]
#
# [3 rows x 22 columns]
